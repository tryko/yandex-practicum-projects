# %% [markdown]
# ## To the reviewer
# Hi:), My name is Yoad,<br>
# I would like to thank you for taking the time to go over my project.<br>
# I hope that you'll find it interesting and clear, and I'm looking forward to read your comments.

# %% [markdown]
# <hr style="border: 2px solid green;" />
#
# Hello, Yoad!🤚
#
# My name is Kseniya. I reviewed your second project and I'm glad to see you again 😊
#
# ✏️You can find my comments in <font color='green'>green</font>, <font color='orange'>yellow</font> or <font color='red'>red</font> boxes like this:
#
# <div style="border:solid green 2px; padding: 20px"> <b>Success:</b><br>
#     I'm using green color if everything is done perfectly.</div>
# <br>
# <div style="border:solid orange 2px; padding: 20px"> <b>Remarks:</b><br>
#     if I can give some recommendations</div>
# <br>
# <div style="border:solid red 2px; padding: 20px"> <b>Needs fixing:</b><br>
#     if the block requires some corrections. Work can't be accepted with the red comments</div>
#
# Further in the file you can see my comments, try to take them into account when performing the next tasks. **Please, don't delete them.** :)
#
# Let's work on the project in dialogue: if you change something in the project or respond to my comments, write about it. It will be easier for me to track the changes if you highlight your comments:
#
# <div class="alert alert-info" style="border:solid blue 2px; padding: 20px"> <b>Student comment:</b> In the blue boxes you can leave comments and ask questions.</div>
#
#
# <hr style="border: 2px solid green;" />

# %% [markdown]
# ### <font color='orange'>General feedback</font>

# %% [markdown]
# <div style="border:solid red 2px; padding: 20px"> <b>Needs fixing :</b><br>
#   Thank you for sending your project🙂. You've done a really good job on it!
#     I especially  liked  Z-score calculations, chart styling and your out-of-box approach.
#
# However,  I've found some tiny mistakes in your project. They'll be easy to fix. One more time and you'll have it! :)
# </div>

# %% [markdown]
# <div style="border:solid orange 2px; padding: 20px"> <b>Remarks:</b><br>
#     There are some comments for further improvement. They don't mean that you did anything wrong, but they're things we wanted to point out that can help you further develop your skills.
#
# And also I leave several links that can help you to make your further projects even better:
#
# *  Some information about T-test:
#
#    <a>https://towardsdatascience.com/inferential-statistics-series-t-test-using-numpy-2718f8f9bf2f</a>
#
#
# * Statistical Tests:
#
#      <a>https://towardsdatascience.com/what-are-the-commonly-used-statistical-tests-in-data-science-a95cfc2e6b5e</a>
#
#     https://medium.com/swlh/which-statistical-test-to-use-follow-this-cheat-sheet-92c9a26f6811
#
#
# * Markdown Guide
#
#      <a> https://medium.com/analytics-vidhya/the-ultimate-markdown-guide-for-jupyter-notebook-d5e5abf728fd </a>
#
# </div>

# %% [markdown]
# <div class="alert alert-info" style="border:solid blue 2px; padding: 20px"> <b>Student comment:</b> Hi Kseniya! I'm glad to see you again:)<br>
# Thank you for your comments and remarks.<br>
# I was interested in reading "Some information about T-test". I feel I have some misunderstandings about statistics and tests. <br>
# However, it appears that the publisher has removed the article.
# </div>

# %% [markdown]
# <div style="border:solid red 2px; padding: 20px"> <b>Needs fixing V2:</b><br>
#      I really appreciate the corrections you sent in! Thanks for taking the time to do so. I really like that you worked even on "improve comments".  However, I have a few tiny corrections to help you with.Could you take a second glance at it? One more time and you'll have it! 🙂
#
# Here is the alternative link about T-test:
#
# https://machinelearningmastery.com/how-to-code-the-students-t-test-from-scratch-in-python/</div>

# %% [markdown]
# ----

# %% [markdown]
# # Research on trends in the gaming industry.
#
# Ice is a world-renowned online gaming store that provides hundreds of thousands of gamers around the globe with their most wanted games.
#
# For Ice to develop successful advertising campaigns in 2017, we need to examine the current trends in the gaming industry and forecast how 2017 is likely to unfold.

# %% [markdown]
# ## Decription of the data
# ##### The `games.csv`  data:
#  * `Name` — Game title.
#  * `Platform` — Gaming platform.
#  * `Year_of_Release` — Game's year of release.
#  * `Genre` — Game genre.
#  * `NA_sales` — North American sales in USD million.
#  * `EU_sales` — sales in Europe in USD million.
#  * `JP_sales` — sales in Japan in USD million.
#  * `Other_sales` — sales in other countries in USD million
#  * `Critic_Score` — Score of game critics (maximum of 100)
#  * `User_Score` — User's game score (maximum of 10)
#  * `Rating (ESRB)` — Rating of the appropriate audience.

# %% [markdown]
# ----

# %% [markdown]
# ## Tables Of Contents
# <a class="anchor" id="table_of_contents"></a><br>
# - [**1. First Look at The Data**](#chapter1)<br>
#  - [Games data](#chapter2)<br>
#  - [Conclusion](#chapter3)<br>
# - [**2. Data Preprocessing**](#chapter4)<br>
#  - [- Missing Values](#chapter5)<br>
#    - [Critics Score](#chapter6)<br>
#    - [Rating](#chapter7)<br>
#    - [User Score](#chapter8)<br>
#    - [Year of Release](#chapter9)<br>
#    - [Name](#chapter10)<br>
#    - [Genre](#chapter11)<br>
#  - [Duplicated Values](#chapter12)<br>
#  - [Changing Data Types](#chapter13)<br>
#  - [Calculating total sales for each title](#chapter14)<br>
#  - [Conclusion](#chapter15)<br>
# - [**3. Analyzing The Data**](#chapter16)<br>
#    - [Game releases per year](#chapter17)<br>
#    - [Sales by platform](#chapter18)<br>
#    - [Determining period of data for prognosis](#chapter19)<br>
#    - [Sales by platform after 2013](#chapter20)<br>
#    - [Global sales by platform](#chapter21)<br>
#    - [How reviews affect sales of PS4](#chapter22)<br>
#    - [How reviews affect sales of other popular platforms](#chapter23)<br>
#    - [Distribution of games by genre](#chapter24)<br>
# - [**4. User Profile For Each Region**](#chapter25)<br>
#    - [Top 5 platforms per region](#chapter26)<br>
#       - [Conclusion](#chapter36)<br>
#    - [Top five genres per region](#chapter27)<br>
#       - [Conclusion](#chapter37)<br>
#    - [ESRB rating affect on sales per region](#chapter28)<br>
#       - [Conclusion](#chapter38)<br>
#    - [Profiling Conclusion](#chapter29)<br>
# - [**5. Hypotheses Testing**](#chapter31)<br>
#    - [XOne - PC user score](#chapter32)<br>
#    - [Action - Sports genres user score](#chapter33)<br>
# - [**6. Overall Conclusion**](#chapter34)<br>
# - [**Project completion checklist**](#chapter35)<br>

# %% [markdown]
# <div style="border:solid green 2px; padding: 20px"> <b>Success:</b><br>
#     Excellent work! Thank you for writing a detailed description of the project, the project plan, and what tasks you are going to accomplish in the process. It's great that you also have a description of the data 👍</div>

# %% [markdown]
# ----

# %% [markdown]
# ## 1. First Look at The Data
# <a class="anchor" id="chapter1"></a>
# [Go back to the Table of Contents](#table_of_contents)

# %% [markdown]
# ### Please Note:
# **There are some libraries that are not updated on the platform, particularly Matplotlib and Seaborn.
# In order for the code to run properly, remove the # sign in the following commands and execute them, then restart the kernel.
# Thank you.**

# %%
# !pip install numpy --upgrade --no-warn-script-location

# %%
# !pip install pandas --upgrade

# %%
# !pip install matplotlib --upgrade

# %%
# !pip install seaborn --upgrade

# %%
# !pip install -Uq sidetable
# !pip install -q squarify

# %%
# Importing pandas libarary.
import pandas as pd

# Importing NumPy library.
import numpy as np

# Importing matplotlib libarary.
import matplotlib.pyplot as plt

# Importing seaborn library.
import seaborn as sns

# Importing reduce function.
from functools import reduce

# Importaing satistics library.
from scipy import stats as st

# Importing sidetable
import sidetable

# Importing squarify
import squarify
# Out:
# /opt/conda/lib/python3.7/site-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
# By using try-except method, the data can load on the platform,
# as well as my local computer.

try:
    # Loading the data in the .csv files into a variable (locally)
    df = pd.read_csv('games.csv')
    
except:   
    # Loading the data in the .csv files into a variable (platform)
    df = pd.read_csv('/datasets/games.csv')

# %% [markdown]
# <div style="border:solid green 2px; padding: 20px"> <b>Success:</b><br>
#     You're using try-except method correctly and import all libraries at the beginning of your project.  Great job!
#  </div>

# %% [markdown]
# ### Games data
# <a class="anchor" id="chapter2"></a>
# [Go back to the Table of Contents](#table_of_contents)

# %% [markdown]
# The first thing we need to do is look at the entire data set and see if there are any missing values, as well as the types of data.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16715 entries, 0 to 16714
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Name             16713 non-null  object
#  1   Platform         16715 non-null  object
#  2   Year_of_Release  16446 non-null  float64
#  3   Genre            16713 non-null  object
#  4   NA_sales         16715 non-null  float64
#  5   EU_sales         16715 non-null  float64
#  6   JP_sales         16715 non-null  float64
#  7   Other_sales      16715 non-null  float64
#  8   Critic_Score     8137 non-null   float64
#  9   User_Score       10014 non-null  object
#  10  Rating           9949 non-null   object
# dtypes: float64(6), object(5)
# memory usage: 1.4+ MB

# %% [markdown]
# - We can see that we have some missing values, we'll take a closer look later on.
# - we have some data types that needs changing,
#   - Year_of_Release, to integer.
#   - User_Score should be numeric we should check why its object type.

# %% [markdown]
# Printing 10 rows randomly from the dataset to examine the data.

# %%
df.sample(10)
# Out:
#                                            Name Platform  Year_of_Release  \
# 6924                  Pro Evolution Soccer 2014     X360           2013.0
# 11165                  Knights in the Nightmare      PSP           2010.0
# 10652                              Bullet Witch     X360           2006.0
# 11483        Jikkyou Powerful Major League 2009      PS2           2009.0
# 13455  Sesame Street: Elmo's A-to-Zoo Adventure       PC           2010.0
# 14104            Secret Files 2: Puritas Cordis       PC           2009.0
# 10302                         Yamaha Supercross       DS           2009.0
# 2624   Marvel vs. Capcom: Clash of Super Heroes       PS           1999.0
# 9354    Destroy All Humans! Big Willy Unleashed      Wii           2008.0
# 1559          Metal Gear Solid V: Ground Zeroes      PS4           2014.0
#
#               Genre  NA_sales  EU_sales  JP_sales  Other_sales  Critic_Score  \
# ...

# %% [markdown]
# Using describe() we can now get even more detailed information about our data.

# %%
df.describe().T
# Out:
#                    count         mean        std     min     25%      50%  \
# Year_of_Release  16446.0  2006.484616   5.877050  1980.0  2003.0  2007.00
# NA_sales         16715.0     0.263377   0.813604     0.0     0.0     0.08
# EU_sales         16715.0     0.145060   0.503339     0.0     0.0     0.02
# JP_sales         16715.0     0.077617   0.308853     0.0     0.0     0.00
# Other_sales      16715.0     0.047342   0.186731     0.0     0.0     0.01
# Critic_Score      8137.0    68.967679  13.938165    13.0    60.0    71.00
#
#                      75%      max
# Year_of_Release  2010.00  2016.00
# NA_sales            0.24    41.36
# EU_sales            0.11    28.96
# JP_sales            0.04    10.22
# Other_sales         0.03    10.57
# Critic_Score       79.00    98.00

# %% [markdown]
# - Our data contains games from 1980 - 2016,
#   - the mean of years is lower than the median which means we have slightly more games that were released before 2007, we should check if they are relevent for our study.
# - Slaes in all regions have a mean that is higher than the median, which indicates that there are some big numbers up top.
# - 'Critic_Score' ,missing about 50% of the data, and we have more low scoring because the mean is lower than the median.

# %% [markdown]
# Using describe() on object type to see more detailed information about our data.

# %%
df.describe(include='object').T
# Out:
#             count unique                          top  freq
# Name        16713  11559  Need for Speed: Most Wanted    12
# Platform    16715     31                          PS2  2161
# Genre       16713     12                       Action  3369
# User_Score  10014     96                          tbd  2424
# Rating       9949      8                            E  3990

# %% [markdown]
# - Looks like we have 2 missing games titles and genres
# - 31 unique platforms (I wonder if they are all stil relevent)
#     - PS2 is the most mentioned platform, and it is not that relevent any,ore for example.
# - the most frequent value in 'User_Score' is "tbd" (to be determined) which explains why its object type instead of numeric.

# %% [markdown]
# Looking at the freqency of mentioned platforms in the data.

# %%
df.stb.freq(['Platform'], style=True, cum_cols=False)
# Out:
# <style type="text/css">
# </style>
# <table id="T_1e544_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Platform</th>
#       <th class="col_heading level0 col1" >count</th>
#       <th class="col_heading level0 col2" >percent</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1e544_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_1e544_row0_col0" class="data row0 col0" >PS2</td>
#       <td id="T_1e544_row0_col1" class="data row0 col1" >2,161</td>
#       <td id="T_1e544_row0_col2" class="data row0 col2" >12.93%</td>
#     </tr>
#     <tr>
#       <th id="T_1e544_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_1e544_row1_col0" class="data row1 col0" >DS</td>
#       <td id="T_1e544_row1_col1" class="data row1 col1" >2,151</td>
#       <td id="T_1e544_row1_col2" class="data row1 col2" >12.87%</td>
#     </tr>
#     <tr>
# ...

# %% [markdown]
# PS2 and DS are the most mentioned, but they are not as relevant any more; I wonder how the data will turn out in terms of describing the trends we're after.

# %% [markdown]
# Let's utilize the sidetable library to see the distribution of missing values accross the data.

# %%
df.stb.missing(style=True)
# Out:
# <style type="text/css">
# </style>
# <table id="T_9ad85_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >missing</th>
#       <th class="col_heading level0 col1" >total</th>
#       <th class="col_heading level0 col2" >percent</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9ad85_level0_row0" class="row_heading level0 row0" >Critic_Score</th>
#       <td id="T_9ad85_row0_col0" class="data row0 col0" >8,578</td>
#       <td id="T_9ad85_row0_col1" class="data row0 col1" >16,715</td>
#       <td id="T_9ad85_row0_col2" class="data row0 col2" >51.32%</td>
#     </tr>
#     <tr>
#       <th id="T_9ad85_level0_row1" class="row_heading level0 row1" >Rating</th>
#       <td id="T_9ad85_row1_col0" class="data row1 col0" >6,766</td>
#       <td id="T_9ad85_row1_col1" class="data row1 col1" >16,715</td>
#       <td id="T_9ad85_row1_col2" class="data row1 col2" >40.48%</td>
#     </tr>
#     <tr>
# ...

# %% [markdown]
# <div style="border:solid green 2px; padding: 20px"> <b>Success:</b><br>
#     Wow, great! 👏 👏 👏  </div>
# <br>

# %% [markdown]
# - 'Critic_Score' missing more than 50% of values!
# - Followed by 'Rating' and 'User_Score' that miss about 40%!<br>
#
# It's very good information about the status of our data and we'll decide what to do with these later

# %% [markdown]
# I want to take a look at 'User_score' to see the games with "tbd".<br>
# It would be logical to see that the most recent games have "tbd" in user score because they are new, let's see if its true.

# %%
df[df['User_Score']=="tbd"]['Year_of_Release'].value_counts()
# Out:
# 2009.0    405
# 2010.0    331
# 2008.0    326
# 2011.0    217
# 2002.0    192
# 2007.0    192
# 2006.0    124
# 2005.0    121
# 2004.0    107
# 2003.0     95
# 2001.0     82
# 2000.0     43
# 2015.0     38
# 2016.0     34
# 2012.0     24
# 2014.0     21
# 2013.0     15
# 1999.0      8
# 1997.0      1
# Name: Year_of_Release, dtype: int64

# %% [markdown]
# Interesting, We see that we have older games with "tbd" as their users score.<br>
# That's a signal that indicates that the data is probably not updated.

# %% [markdown]
# ### Conclusion
# <a class="anchor" id="chapter3"></a>
# [Go back to the Table of Contents](#table_of_contents)

# %% [markdown]
# At first glance, it is evident that,
# - It seems that there are a lot of missing values in some columns and we need to decide what the best course of action will be for us, 'Critical_Score', for example, missing about 50% of the data.
# - We have some data types that need to be changed, such as 'Year_of_Release' and possibly 'User_Score'.
# - We might have more game titles before 2007, and most of them might not be relevant to our research.
# - Each region's mean in Sales is higher than its median, which suggests that there might be some big numbers up top.
# - Some old platforms contain a lot of data, and we need to determine whether it is useful to our research.
# - The data we have at hand most probably isn't updated, and some key columns missing data for fairly old games.

# %% [markdown]
# <div style="border:solid green 2px; padding: 20px"> <b>Success:</b><br>
#
#    I like that you use a variety of methods, including `head()`, `info()`, `value_counts()`, `missing()`  and  `describe()` when studying general information in tables. Well done! And thanks for detailed conclusions :)</div>

# %% [markdown]
# ----

# %% [markdown]
# ## 2. Data Preprocessing
# <a class="anchor" id="chapter4"></a>
# [Go back to the Table of Contents](#table_of_contents)

# %% [markdown]
# Lowering case for columns names.

# %%
df.columns = [x.lower() for x in df.columns]

# %% [markdown]
# <div style="border:solid green 2px; padding: 20px"> <b>Success:</b><br>
#     Very well that you converted the columns to lower case using <code>str.lower()</code></div>

# %% [markdown]
# ### Missing Values
# <a class="anchor" id="chapter5"></a>
# [Go back to the Table of Contents](#table_of_contents)

# %% [markdown]
# #### Critics Score
# <a class="anchor" id="chapter6"></a>
# [Go back to the Table of Contents](#table_of_contents)

# %% [markdown]
# Because each game is unique, regardless of genre, platform, or year, it is impossible to predict critics score.<br>
# Even though we could find the average ratio between the critics and users column it wouldn't be right because the way a game is accepted by users could differ greatly from how it is accepted by critics, and vice versa.<br>
# Plus, it means that we would try to fill 50% of the data based on the other 50% of the data.<br>
#
# In order to work with this data, we will need to slice and filter it later without these missing values.

# %% [markdown]
# #### Rating
# <a class="anchor" id="chapter7"></a>
# [Go back to the Table of Contents](#table_of_contents)

# %%
df[df['rating'].isna()].head()
# Out:
#                         name platform  year_of_release         genre  \
# 1          Super Mario Bros.      NES           1985.0      Platform
# 4   Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing
# 5                     Tetris       GB           1989.0        Puzzle
# 9                  Duck Hunt      NES           1984.0       Shooter
# 10                Nintendogs       DS           2005.0    Simulation
#
#     na_sales  eu_sales  jp_sales  other_sales  critic_score user_score rating
# 1      29.08      3.58      6.81         0.77           NaN        NaN    NaN
# 4      11.27      8.89     10.22         1.00           NaN        NaN    NaN
# 5      23.20      2.26      4.22         0.58           NaN        NaN    NaN
# 9      26.93      0.63      0.28         0.47           NaN        NaN    NaN
# 10      9.05     10.95      1.93         2.74           NaN        NaN    NaN

# %%
df[df['rating'].isna() & df['user_score'].isna() & df['critic_score'].isna()]
# Out:
#                                 name platform  year_of_release         genre  \
# 1                  Super Mario Bros.      NES           1985.0      Platform
# 4           Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing
# 5                             Tetris       GB           1989.0        Puzzle
# 9                          Duck Hunt      NES           1984.0       Shooter
# 10                        Nintendogs       DS           2005.0    Simulation
# ...                              ...      ...              ...           ...
# 16710  Samurai Warriors: Sanada Maru      PS3           2016.0        Action
# 16711               LMA Manager 2007     X360           2006.0        Sports
# 16712        Haitaka no Psychedelica      PSV           2016.0     Adventure
# 16713               Spirits & Spells      GBA           2003.0      Platform
# 16714            Winning Post 8 2016      PSV           2016.0    Simulation
#
# ...

# %% [markdown]
# Most of the missing values in 'rating' are also missing in 'user_score' and 'critic_score', but in 'critic_score' we have rows with information in the other columns (about 2,000 rows or so).

# %% [markdown]
# There is no way to guess the rating for each game without checking it's real rating online or in other databases, for now lets leave it as it is.

# %% [markdown]
# <div style="border:solid green 2px; padding: 20px"> <b>Success:</b><br>
#    Yes, agree. It's a very reasonable point 👍 </div>
# <br>

# %% [markdown]
# #### User Score
# <a class="anchor" id="chapter8"></a>
# [Go back to the Table of Contents](#table_of_contents)

# %% [markdown]
# Because each game is unique, regardless of genre, platform, or year, it is impossible to predict users score.<br>
# Even though we could find the average ratio between the critics and users column it wouldn't be right because the way a game is accepted by users could differ greatly from how it is accepted by critics, and vice versa.<br>
# Plus, it means that we would try to fill 50% of the data based on the other 50% of the data.<br>
#
# In order to work with this data, we will need to slice and filter it later without these missing values.

# %% [markdown]
# Let's replace all "tbd" values with NaN so we could convert it later to float.<br>
# "tbd" and NaN in this case are the same as we probably won't see any update to this data, and we know that the older games must have user score by now.

# %%
df['user_score'] = df['user_score'].replace(to_replace='tbd', value='NaN')

# %%
print('Number of rows wher user score is tbd:', df.query('user_score == "tbd"')['user_score'].sum())
# Out:
# Number of rows wher user score is tbd: 0

# %% [markdown]
# Success.

# %% [markdown]
# <div style="border:solid green 2px; padding: 20px"> <b>Success:</b><br>
#     Well, it's all good here🙂 </div>

# %% [markdown]
# #### Year of Release
# <a class="anchor" id="chapter9"></a>
# [Go back to the Table of Contents](#table_of_contents)

# %% [markdown]
# Let's look at year of release.

# %%
df[df['year_of_release'].isna()].head()
# Out:
#                            name platform  year_of_release     genre  na_sales  \
# 183             Madden NFL 2004      PS2              NaN    Sports      4.26
# 377            FIFA Soccer 2004      PS2              NaN    Sports      0.59
# 456  LEGO Batman: The Videogame      Wii              NaN    Action      1.80
# 475  wwe Smackdown vs. Raw 2006      PS2              NaN  Fighting      1.57
# 609              Space Invaders     2600              NaN   Shooter      2.36
#
#      eu_sales  jp_sales  other_sales  critic_score user_score rating
# 183      0.26      0.01         0.71          94.0        8.5      E
# 377      2.36      0.04         0.51          84.0        6.4      E
# 456      0.97      0.00         0.29          74.0        7.9   E10+
# 475      1.02      0.00         0.41           NaN        NaN    NaN
# 609      0.14      0.00         0.03           NaN        NaN    NaN

# %% [markdown]
# We can see that sports title have the year of the season in their names, in my experiance they release them. the year before.<br>
# Let's take a look at on title with the year included in the name.

# %%
df.query('name == "FIFA Soccer 2004"')
# Out:
#                    name platform  year_of_release   genre  na_sales  eu_sales  \
# 377    FIFA Soccer 2004      PS2              NaN  Sports      0.59      2.36
# 2606   FIFA Soccer 2004       XB           2003.0  Sports      0.24      0.49
# 12029  FIFA Soccer 2004       GC           2003.0  Sports      0.05      0.01
# 13086  FIFA Soccer 2004      GBA           2003.0  Sports      0.04      0.01
#
#        jp_sales  other_sales  critic_score user_score rating
# 377        0.04         0.51          84.0        6.4      E
# 2606       0.00         0.05          82.0        8.2      E
# 12029      0.00         0.00          83.0        6.2      E
# 13086      0.00         0.00          82.0        7.9      E

# %% [markdown]
# year of release missing values account for about 1.5% of the data, keeping that in mind, <br>
# There are titles with year in their names, as well as titles in which one platform lacks the value of year of release, but the other platform does.<br>
# Considering the time it would take to fill back that data, and the likelihood that all of it cannot be restored, it is still less than 1.5% of the data, so our energies should be allocated elsewhere.<br>
#
# We'll leave it as is.

# %% [markdown]
# #### Name
# <a class="anchor" id="chapter10"></a>
# [Go back to the Table of Contents](#table_of_contents)

# %%
df[df['name'].isna()]
# Out:
#       name platform  year_of_release genre  na_sales  eu_sales  jp_sales  \
# 659    NaN      GEN           1993.0   NaN      1.78      0.53      0.00
# 14244  NaN      GEN           1993.0   NaN      0.00      0.00      0.03
#
#        other_sales  critic_score user_score rating
# 659           0.08           NaN        NaN    NaN
# 14244         0.00           NaN        NaN    NaN

# %% [markdown]
# We have tow rows were the title of the game is not specified, and except for year of release and sales we don't have any other information.<br>
# We'll keep these lines for their sales inforamtion for 1993.

# %% [markdown]
# <div style="border:solid orange 2px; padding: 20px"> <b>Remarks:</b><br>
#
#    Lines with gaps in the `name` and `year_of_release` are best deleted. We know almost nothing about these games.</div>

# %% [markdown]
# <div class="alert alert-info" style="border:solid blue 2px; padding: 20px"> <b>Student comment:</b> I thought that too when dealing with the mising values, however I saw that in rows that are missing years we can use the sales and genres.<br>
#     Same with missing names and genres we can use the years and sales so I decided to leave them in.
# </div>

# %% [markdown]
# <div style="border:solid green 2px; padding: 20px"> <b>Success V2:</b><br>
#     Ok, I see, let it be :)</div>

# %% [markdown]
# #### Genre
# <a class="anchor" id="chapter11"></a>
# [Go back to the Table of Contents](#table_of_contents)

# %%
df[df['genre'].isna()]
# Out:
#       name platform  year_of_release genre  na_sales  eu_sales  jp_sales  \
# 659    NaN      GEN           1993.0   NaN      1.78      0.53      0.00
# 14244  NaN      GEN           1993.0   NaN      0.00      0.00      0.03
#
#        other_sales  critic_score user_score rating
# 659           0.08           NaN        NaN    NaN
# 14244         0.00           NaN        NaN    NaN

# %% [markdown]
# these are the same titles we had thier names missing.

# %% [markdown]
# #### Conclusion

# %% [markdown]
# - The data is not updated as we can see that old titles still have "tbd" in user score.
# - We replaced "tbd" with NaN, so we could later convert the column to float.
# - Most of the missing data can't be recovered by the data we currently have, for example, critic score miss about 50%, we can't base our missing values recovery based on the other 50%.
# - We'll need to filter the nulls from each column according to our specific need at each step of the study to retain as much information as we can.

# %% [markdown]
# <div style="border:solid green 2px; padding: 20px"> <b>Success:</b><br>
#     Thanks for the detailed conclusions!</div>

# %% [markdown]
# ### Duplicated Values
# <a class="anchor" id="chapter12"></a>
# [Go back to the Table of Contents](#table_of_contents)

# %% [markdown]
# Looking for duplicated rows in the data sets.

# %%
print('Number of duplicated rows in the data:', df.duplicated().sum())
# Out:
# Number of duplicated rows in the data: 0

# %% [markdown]
# #### Conclusion

# %% [markdown]
# No duplicated rows.

# %% [markdown]
# <div style="border:solid green 2px; padding: 20px"> <b>Success:</b><br>
#     It's great that you checked for duplicates in the dataset and made sure there were none.</div>

# %% [markdown]
# ### Changing Data Types
# <a class="anchor" id="chapter13"></a>
# [Go back to the Table of Contents](#table_of_contents)

# %% [markdown]
# There are two changes that we need to make in order to easily work with the data:<br>
# - We need to change year of release to integer.
# - We need to change user score to float.<br>
# #- We will change rating, platform and genre to category.

# %% [markdown]
# Changing year of release to integer.

# %%
df.sample()
# Out:
#              name platform  year_of_release   genre  na_sales  eu_sales  \
# 15230  GT Legends       PC           2005.0  Racing       0.0      0.02
#
#        jp_sales  other_sales  critic_score user_score rating
# 15230       0.0          0.0          84.0        8.6      E

# %%
df['year_of_release'] = df['year_of_release'].fillna(0).astype('int')

# %% [markdown]
# Let's convert user score to float.

# %%
df['user_score'] = df['user_score'].astype('float')

# %%
#df['platform'] = df['platform'].astype('category')
#df['genre'] = df['genre'].astype('category')
#df['rating'] = df['rating'].astype('category')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16715 entries, 0 to 16714
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   name             16713 non-null  object
#  1   platform         16715 non-null  object
#  2   year_of_release  16715 non-null  int64
#  3   genre            16713 non-null  object
#  4   na_sales         16715 non-null  float64
#  5   eu_sales         16715 non-null  float64
#  6   jp_sales         16715 non-null  float64
#  7   other_sales      16715 non-null  float64
#  8   critic_score     8137 non-null   float64
#  9   user_score       7590 non-null   float64
#  10  rating           9949 non-null   object
# dtypes: float64(6), int64(1), object(4)
# memory usage: 1.4+ MB

# %% [markdown]
# Success.

# %% [markdown]
# ##### Conclusion

# %% [markdown]
# Successfully converted year of release to integer by filling nulls with 0, and user score to float.

# %% [markdown]
# <div style="border:solid orange 2px; padding: 20px"> <b>Remarks:</b><br>
#
#    It is worth converting the data in the rating, genre, and platform columns to the category type. This will reduce the amount of memory required to store the table by more than 2 times. You can verify this with the command `games.info(memory_usage='deep')` - the necessary information will be in the last line.</div>

# %% [markdown]
# <div class="alert alert-info" style="border:solid blue 2px; padding: 20px"> <b>Student comment:</b><br>
#     When I changed type to category, new categories that didn't appear before in the data appeared, and all my filtering went haywire as it included all the categories even if they didn't meet the conditions. <br>
#     I see how it improves memory usage on large data frames but it made more errors in my code than it helped.<br>
#     Was there a reason why it acted the way it did?
# </div>

# %% [markdown]
# <div style="border:solid green 2px; padding: 20px"> <b>Success V2:</b><br>
#     Yes, it happens. Only by experimentation can you determine what may be the real cause. Maybe the libraries are not updated, maybe there are version conflicts, I do not know ...
# </div>

# %% [markdown]
# #### Calculating total sales for each title:
# <a class="anchor" id="chapter14"></a>
# [Go back to the Table of Contents](#table_of_contents)

# %% [markdown]
# Let's calculate the total sale for each title (game) and put it in a new column.

# %%
df['total_sales'] = df[['na_sales', 'eu_sales', 'jp_sales', 'other_sales']].sum(axis=1)

# %%
df.sample()
# Out:
#                     name platform  year_of_release   genre  na_sales  \
# 6108  The Golden Compass      PS3             2007  Action      0.14
#
#       eu_sales  jp_sales  other_sales  critic_score  user_score rating  \
# 6108       0.1       0.0         0.05          40.0         4.8   E10+
#
#       total_sales
# 6108         0.29

# %% [markdown]
# Success.

# %% [markdown]
# ### Conclusion
# <a class="anchor" id="chapter15"></a>
# [Go back to the Table of Contents](#table_of_contents)

# %% [markdown]
# Our data pre processing ensures that we the technical needs in place in order for us to study the data.<br>
#
# - We changed data types for two columns, 'year_of_release' (int) and 'user_score' (float).
# - We determined that the data is not updated and there is little to be done with the missing values we have. we'll need to filter the data for each step will take during the research.
# - We added a 'total_sales' column, that clacults the sales of all regions for each title.

# %% [markdown]
# <div style="border:solid green 2px; padding: 20px"> <b>Success:</b><br>
# Yes, absolutely correct. Good job! :)
#     </div>

# %% [markdown]
# ----

# %% [markdown]
# ## 3. Analyzing The Data
# <a class="anchor" id="chapter16"></a>
# [Go back to the Table of Contents](#table_of_contents)

# %% [markdown]
# ### Game releases per year
# <a class="anchor" id="chapter17"></a>
# [Go back to the Table of Contents](#table_of_contents)

# %% [markdown]
# We'll group the data by 'year_of_release' and count how many game titles were released that year.<br>
# Then, we'll plot a graph to visualize the data.

# %%
df.head()
# Out:
#                        name platform  year_of_release         genre  na_sales  \
# 0                Wii Sports      Wii             2006        Sports     41.36
# 1         Super Mario Bros.      NES             1985      Platform     29.08
# 2            Mario Kart Wii      Wii             2008        Racing     15.68
# 3         Wii Sports Resort      Wii             2009        Sports     15.61
# 4  Pokemon Red/Pokemon Blue       GB             1996  Role-Playing     11.27
#
#    eu_sales  jp_sales  other_sales  critic_score  user_score rating  \
# 0     28.96      3.77         8.45          76.0         8.0      E
# 1      3.58      6.81         0.77           NaN         NaN    NaN
# 2     12.76      3.79         3.29          82.0         8.3      E
# 3     10.93      3.28         2.95          80.0         8.0      E
# 4      8.89     10.22         1.00           NaN         NaN    NaN
#
#    total_sales
# 0        82.54
# 1        40.24
# 2        35.52
# 3        32.77
# ...

# %%
games_per_year = df.groupby(['year_of_release'])['name'].count().reset_index() # Grouping by year of release.
games_per_year = games_per_year[games_per_year['year_of_release'] != 0]        # Filtering null years (which were filled with 0)

# %%
fig, ax = plt.subplots(figsize=(14,10))
ax.vlines(x=games_per_year['year_of_release'] , 
          ymin=0, ymax=games_per_year['name'], color='purple', alpha=0.7, linewidth=2);
ax.scatter(x=games_per_year['year_of_release'], 
           y=games_per_year['name'], s=75, color='black', alpha=0.7);

ax.set_title('Lollypop for games released per year', fontdict={'size':20});
ax.set_ylabel('Number of games', size=16);
ax.set_xlabel('Years', size=16);
ax.set_xticks(games_per_year['year_of_release']);
ax.set_xticklabels(games_per_year['year_of_release'], rotation=45);
plt.tick_params(axis='both', which='major', labelsize=12)
for row in games_per_year.itertuples():
    ax.text(row.year_of_release, row.name+30, s=round(row.name,2))

# %% [markdown]
# ##### Conclusion
#
# According to the data we have, in 2002 there was a large increase in game releases that continued through 2009 and then began to decline.<br>
# Based on the fact that the gaming industry is only growing over time, we can deduce that the data is not updated (which we discovered earlier in our study).<br>
#
# As part of our research, and given the amount of data we have, it would be wise to consider data from 2002 and beyond only.<br>
# 1. Data from more than 15 years ago will be irrelevant to today's business and industry (assuming it is now 2017, yes?).
# 2. In any case, there is not much data prior to 2002.
#
# As a result, data spanning 2002 and beyond is important for our research.

# %% [markdown]
# <div style="border:solid green 2px; padding: 20px"> <b>Success:</b><br>
#     I like that you use a variety of charts in your research.</div>

# %% [markdown]
# <s><div style="border:solid red 2px; padding: 20px"> <b>Needs fixing:</b><br>
#     Please, add y-axes caption to your chart.</div>

# %% [markdown]
# <div class="alert alert-info" style="border:solid blue 2px; padding: 20px"> <b>Student comment:</b> DONE!<br>
# For some reason when I tried that dusring the project it didn't let assign a title to X axis🤔.
# </div>

# %% [markdown]
# ### Sales by platform
# <a class="anchor" id="chapter18"></a>
# [Go back to the Table of Contents](#table_of_contents)

# %% [markdown]
# - Here we will examine the differences in sales from different platforms.
# - We will identify the platforms with the highest total sales.
# - We will take a closer look at how these platforms have performed over time.
# - We'll identify the platforms that were previously successful but now have no sales.
# - We'll determine the general time it takes for a platform to fade and for a new one to arrive.

# %% [markdown]
# To determine which platform is most profitable, we need to:
# 1. Group by platform and sort by their 'total_sales'.
# 2. Calculate the z-score of total sales of each platform, which indicates how far the data is from the average total sales.
# 3. After that, we will color code z-scores above and below the mean in order to make plotting the graph easier.
# 4. We will plot a horizontal line graph representing each platform, based on its z-score and color coded accordingly.

# %% [markdown]
# Grouping the data by platform and sorting by 'total_sales'.

# %%
sales_per_platform = df[['platform', 'total_sales']].groupby(['platform']).sum().sort_values(by='total_sales').reset_index()

# %% [markdown]
# Calculating the z-score of total sales for each platform.

# %%
sales_per_platform['sales_z'] = (sales_per_platform['total_sales']-
                                 sales_per_platform['total_sales'].mean()) / sales_per_platform['total_sales'].std()

# %% [markdown]
# With the z-score, we know that if the data is normally distributed (statistically speaking), then the three-sigma rule holds true and 99.7% of the data will fall within this range.<br>
# Accordingly, the nearer to a value +3 it gets, the higher it is distributed in relation to the rest of the data, and vice versa.<br>
# This is how we'll evaluate the success of each platform.

# %% [markdown]
# Color coding the platforms, z-score above the mean is green, and below will be red.

# %%
sales_per_platform['color'] = ['red' if x<0 else 'green' for x in sales_per_platform['sales_z']]

# %% [markdown]
# Plotting the graph.

# %%
plt.figure(figsize=(12,12))
plt.hlines(y=sales_per_platform['platform'], 
           xmin=0, xmax=sales_per_platform['sales_z'], 
           color= sales_per_platform['color'], alpha=0.4, linewidth=10);
plt.title( 'Platform Sales Z-Score, Comparing Average Platform Sales' , size = 16 )
plt.ylabel('Platform', size=14);
plt.xlabel('Z-Score', size=14);
plt.tick_params(axis='both', which='major', labelsize=12)

# %% [markdown]
# <s><div style="border:solid red 2px; padding: 20px"> <b>Needs fixing:</b><br>
#     Could you please add y-axes caption to your plot?</div>

# %% [markdown]
# <div class="alert alert-info" style="border:solid blue 2px; padding: 20px"> <b>Student comment:</b> DONE!<br>
# For some reason when I tried that dusring the project it didn't let assign a title to X axis🤔.
# </div>

# %% [markdown]
# This graph illustrates the market dominance of 6 consoles.
# PS2 is above 2.5 in z-score, indicating it is highly distributed in comparison to the rest of the platforms,<br>
# After that, the Xbox 360, PlayStation 3, etc.

# %% [markdown]
# <div style="border:solid green 2px; padding: 20px"> <b>Success:</b><br>
#    Wow, it's really great that you use the z-score for the determining of the most dominant platforms for the whole period 👏 👏 👏   </div>

# %% [markdown]
# We'll pass these console to a list.

# %%
lead_platforms = sales_per_platform['platform'].tail()

# %% [markdown]
# We've filtered the data by the list of popular consoles we've found.<br>
# Then, removing outliers that existed in the data, such as null years that were filled with 0 and there was one game from 1985 on a console that only came out in 2004, probably a mistake in the data.

# %%
lead_platforms_data = df.query('platform in @lead_platforms')
lead_platforms_data = lead_platforms_data.query('year_of_release != (0, 1985)')

# %% [markdown]
# With a pivot table, we'll group the data according to platform and the year of release (of each game), and then sum up all the revenue from those years per platform.

# %%
lead_platforms_data_grouped = lead_platforms_data.pivot_table(index=['platform', 'year_of_release'],  values=['total_sales'], aggfunc='sum')
lead_platforms_data_grouped.reset_index(inplace=True)

# %% [markdown]
# Let's visualize how the different popular platforms performed in terms of revenue per year by plotting a line graph.

# %%
fig, ax = plt.subplots(figsize=(14,7))
sns.set_style("whitegrid")
sns.lineplot(data=lead_platforms_data_grouped, 
             x="year_of_release", 
             y="total_sales", 
             hue="platform",
            linewidth= 3)
ax.set_title( 'Platform Sales (in mil.) Over The Years' , size = 24 )
ax.set_xticks(lead_platforms_data_grouped['year_of_release'].unique());
ax.legend(fontsize = 14)
plt.xlabel('Year', size=16);
plt.ylabel('Number of sales in mil.', size=16);
plt.xticks(rotation=45);
ax.tick_params(axis='both', which='major', labelsize=14)
sns.despine()

# %% [markdown]
# Another way to visualize each platform's market capitalization is to use a tree graph, such as Squarify.

# %% [markdown]
# <div style="border:solid green 2px; padding: 20px"> <b>Success:</b><br>
#     Well done!</div>

# %% [markdown]
# #### Tree Map

# %% [markdown]
# We will slice the data to suit our needs, taking only platform names and total sales (over 1 million, anything below would be difficult to see in the graph because it is too small).

# %%
sales_per_platform_tree = sales_per_platform[['platform', 'total_sales']]
sales_per_platform_tree = sales_per_platform_tree[sales_per_platform_tree['total_sales'] > 1]

# %% [markdown]
# The size of the boxes in side the graph would be detrmined by total sales.

# %%
sizes = sales_per_platform_tree['total_sales'].values.tolist()

# %% [markdown]
# And the labels would be the name of the platform and total sales rounded up.

# %%
labels = sales_per_platform_tree.apply(lambda x: str(x[0])+ "\n" + "$" + str(round(x[1])),axis=1)

# %%
plt.figure(figsize=(15,9))
plt.title('Tree Map for Platform Market Share in $ mil. ', size=20)
squarify.plot(sizes=sizes, label=labels, alpha=0.5);

# %% [markdown]
# <div style="border:solid orange 2px; padding: 20px"> <b>Remarks:</b><br>
#     And you forgot to add the title to your plot :)</div>

# %% [markdown]
# <div class="alert alert-info" style="border:solid blue 2px; padding: 20px"> <b>Student comment V2:</b> DONE!<br>
# </div>

# %% [markdown]
# **Conclusion**<br>
#
# The graph shows that there are a number of consoles that were very popular but no longer exist.<br>
# If we take the PS brand as an example,<br>
# - we can see that the first console was released in 1994, and stopped selling games around 2003.
# - PS already got its next generation console, the PS2, in 2000. It was the most popular console in the world according to our data, until it stopped selling around 2011.
# - PS3 was released in 2006 (5 years before PS2 stopped selling) and stopped selling around 2016.<br>
#
# The PS4 is not shown in this graph since there wasn't enough data available for us to consider it as a popular console. However, I know from personal experience that it continues the PS trend.<br>
#
# **The general trend with consoles is that they have a lifespan of about 10 years, and then in the 7th year, we'll see a new generation that picks up sales once more.**<br>
#
# Additionally, we cannot really say what caused the decline in sales, one reason could be that a new generation of the console will be out within two years after that previous console's mid-life cycle ends,<br>
# Which means that, after the midway point, developers would focus on creating games for the upcoming console,  where the attention will be, since attention = money. <br>
#
# That alone does not explain why sales declined, but it might explain why the console became obsolete.
#
# We can say that almost all the popular consoles that we have in our data are no longer selling, which means it's time for new consoles to emerge and take their places. I would say that the PS4 will replace the PS3, and the new Xbox One will replace the Xbox 360.

# %% [markdown]
# <div style="border:solid green 2px; padding: 20px"> <b>Success:</b><br>
#    Thanks a lot for the detailed explanation of the charts,  logical conclusions and out-of-the-box approach!😊</div>

# %% [markdown]
# ### Determining period of data for prognosis
# <a class="anchor" id="chapter19"></a>
# [Go back to the Table of Contents](#table_of_contents)

# %% [markdown]
# Our results indicate that there are only two relevant platforms based on our data: Xbox and PS. <br>
# In terms of total sales, these are the leading platforms, and as we can see in the graph, their sales are declining for X360 and PS3 models, which means new consoles will soon be taking their place.<br>
#
# Gaming consoles have a lifespan of roughly 10 years and a new generation of consoles emerges every 7 years.<br>
# Based on the graph, we see that both the Xbox 360 and PlayStation 3 are about to turn ten,
# **focusing on 2013 and beyond for our prognosis would be a wise move, as these years will mark both the introduction of new console generations and the latest gaming trends.**

# %% [markdown]
# <div style="border:solid green 2px; padding: 20px"> <b>Success V2:</b><br>
#     Ok, typical lifespan you determine correctly.  Thank you for in-depth analysis! </div>

# %% [markdown]
# ### Sales by platform after 2013
# <a class="anchor" id="chapter20"></a>
# [Go back to the Table of Contents](#table_of_contents)

# %% [markdown]
# - Here we will examine the differences in sales from different platforms after 2013.
# - We will identify the platforms with the highest total sales.
# - We will take a closer look at which platforms are growing or shrinking in market cap.
# - We'll select a few promising platforms for our prognosis

# %% [markdown]
# To determine which platform is most profitable after 2013, we need to:
# 1. Filter the data to have only 2013 and beyond.
# 2. Group by platform and sort by their 'total_sales'.
# 3. Calculate the z-score of total sales of each platform, which indicates how far the data is from the average total sales.
# 4. After that, we will color code z-scores above and below the mean in order to make plotting the graph easier.
# 5. We will plot a horizontal line graph representing each platform, based on its z-score of total sales and color coded accordingly.

# %% [markdown]
# Filtering the data by year 2013 and beyond.

# %%
df_2013 = df.query('year_of_release >= 2013')

# %% [markdown]
# Grouping the data by platform and sorting by 'total_sales'.

# %%
sales_per_platform_2013 = df_2013[['platform', 'total_sales']].groupby(['platform']).sum().sort_values(by='total_sales').reset_index()

# %% [markdown]
# Calculating the z-score of total sales for each platform.

# %%
sales_per_platform_2013['sales_z'] = (sales_per_platform_2013['total_sales']-
                                 sales_per_platform_2013['total_sales'].mean()) / sales_per_platform_2013['total_sales'].std()

# %% [markdown]
# With the z-score, we know that if the data is normally distributed (statistically speaking), then the three-sigma rule holds true and 99.7% of the data will fall within this range.<br>
# Accordingly, the nearer to a value +3 it gets, the higher it is distributed in relation to the rest of the data, and vice versa.<br>
# This is how we'll evaluate the success of each platform.

# %% [markdown]
# Color coding the platforms, z-score above the mean is green, and below will be red.

# %%
sales_per_platform_2013['color'] = ['red' if x<0 else 'green' for x in sales_per_platform_2013['sales_z']]

# %% [markdown]
# Plotting the graph.

# %%
plt.figure(figsize=(12,6))
plt.title( 'Platform Sales Z-Score, Comparing Average Platform Sales' , size = 16 )
plt.hlines(y=sales_per_platform_2013['platform'], 
           xmin=0, xmax=sales_per_platform_2013['sales_z'], 
           color= sales_per_platform_2013['color'], alpha=0.4, linewidth=10);
plt.ylabel('Platform', size=14);
plt.xlabel('Z-Score', size=14);
plt.tick_params(axis='both', which='major', labelsize=12)

# %% [markdown]
# This graph illustrates the market dominance of 5 consoles.
# PS4 is above 2 in z-score, indicating it is highly distributed in comparison to the rest of the platforms.<br>
# After that, the PS3, XOne, etc.

# %% [markdown]
# We'll pass these console to a list.

# %%
lead_platforms_2013 = sales_per_platform_2013['platform'].tail()

# %% [markdown]
# We've filtered the data by the list of popular consoles we've found.<br>
# Then, removing outliers that existed in the data, such as null years that were filled with 0.

# %%
lead_platforms_2013_data = df.query('platform in @lead_platforms_2013')
lead_platforms_2013_data = lead_platforms_2013_data.query('year_of_release >= 2013')

# %% [markdown]
# With a pivot table, we'll group the data according to platform and the year of release (of each game), and then sum up all the revenue from those years per platform.

# %%
lead_platforms_2013_data_grouped = lead_platforms_2013_data.pivot_table(index=['platform', 'year_of_release'],  values=['total_sales'], aggfunc='sum')
lead_platforms_2013_data_grouped.reset_index(inplace=True)

# %% [markdown]
# Let's visualize how the different popular platforms performed in terms of revenue per year by plotting a line graph.

# %%
fig, ax = plt.subplots(figsize=(16,8))
sns.set_style("whitegrid")
sns.lineplot(data=lead_platforms_2013_data_grouped, 
             x="year_of_release", 
             y="total_sales", 
             hue="platform",
            linewidth= 2.5)
ax.set_title( 'Platform Sales (in mil.) Over The Years (after 2013)' , size = 24 )
ax.set_xticks(lead_platforms_2013_data_grouped['year_of_release'].unique());
ax.legend(fontsize = 14)
plt.xlabel('Year', size=20);
plt.ylabel('Number of sales in mil.', size=20);
plt.xticks(rotation=45);
ax.tick_params(axis='both', which='major', labelsize=14)
sns.despine()

# %% [markdown]
# **Conclusion**<br>
#
# It shows that there are a number of consoles that were very popular but are nearing the end of their life cycle, and we can also see the emergence of a new generation of consoles.<br>
#
# As predicted in the previous graph, the trend of PS and Xbox brands is continuing with the new generation of consoles.<br>
#
# Additionally, we can see that the DS brand is shrinking.<br>
#
# Because the data is not updated, the trends of PS and Xbox might actually look quite different, and they may be growing despite the decline in sales that we see.<br>
#
# Let us continue with the assumption that the new generation of PS and Xbox will be the most profitable.

# %% [markdown]
# <div style="border:solid green 2px; padding: 20px"> <b>Success:</b><br>
#     As always, brilliant analysis and conclusions :)</div>

# %% [markdown]
# <div class="alert alert-info" style="border:solid blue 2px; padding: 20px"> <b>Student comment:</b> Thank you! ☺️
# </div>

# %% [markdown]
# ### Global sales by platform
# <a class="anchor" id="chapter21"></a>
# [Go back to the Table of Contents](#table_of_contents)

# %% [markdown]
# We will calculate sales worldwide and plot box plots to see how the different platforms performed.<br>
# After adding up the total sales for each platform, we'll plot another graph showing average sales for each platform.

# %% [markdown]
# For us to be able to do so we'll need to:
# 1. Group the data by platform and year of release, to see the total sales for each year.
# 2. We will create a list of ordered platforms by the total sales, which we will pass to the boxplot, so the data will be organized.
# 3. Steps 1-3 will be repeated with the average of total sales per year.

# %% [markdown]
# Grouping the data by platform and year of release and **summing** total sales.<br>
# Creating a list of ordered platforms by total sales.

# %%
df_box_grouped = lead_platforms_2013_data.groupby(['platform','year_of_release'])['total_sales'].sum().reset_index()
df_box_ordered = df_box_grouped.groupby(['platform'])['total_sales'].sum().sort_values().reset_index()['platform']

# %%
df_box = lead_platforms_2013_data.query('platform in @df_box_ordered')[['platform', 'year_of_release','total_sales']]

# %% [markdown]
# Grouping the data by platform and year of release and calculating **mean** of total sales.<br>
# Creating a list of ordered platforms by total sales.

# %%
df_box_grouped_mean = lead_platforms_2013_data.groupby(['platform','year_of_release'])['total_sales'].mean().reset_index()
df_box_ordered_mean = df_box_grouped_mean.groupby(['platform'])['total_sales'].sum().sort_values().reset_index()['platform']

# %%
df_box_ordered_mean
# Out:
# 0     PS3
# 1     3DS
# 2    X360
# 3    XOne
# 4     PS4
# Name: platform, dtype: object

# %% [markdown]
# Plotting box plot with our grouped data.

# %%
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(14,7))
fig.suptitle('Total and Average of Global Sales by Platform', size=24)
sns.boxplot(ax=axes[0], x='platform',y='total_sales',
            data=df_box,
            order=df_box_ordered);
axes[0].set_ylim([0, 1.75])
axes[0].set_title( 'Total of Global Sales (in mil.) by Platform' , size = 16 )
axes[0].set_xlabel('Platform', size=16);
axes[0].set_ylabel('Total sales in mil.', size=16);
axes[0].tick_params(axis='both', which='major', labelsize=13)

sns.boxplot(ax=axes[1], x='platform', y='total_sales', 
            data=df_box_grouped_mean, 
            order=df_box_ordered_mean);
axes[1].set_ylim([0, 1.75])
axes[1].set_title( 'Average of Global Sales (in mil.) by Platform' , size = 16 )
axes[1].set_xlabel('Platform', size=16);
axes[1].set_ylabel('Total sales in mil.', size=16);
axes[1].tick_params(axis='both', which='major', labelsize=12)

plt.show()

# %% [markdown]
# **Conclusion**<br>
#
# From the graphs above, it is apparent that PS4 has both the most and the average number of sales compared to other platforms.
#
# **PS4**<br>
# - Total sales, Sales (summed) of PS4 games are the highest compared to other platforms. It is apparent that the median line is close to the Q1 line of the box plot, which indicates that the data is skewed to the right, concentrated around 0.2 and below with a long tail of values as sales rise. Furthermore, we also have some very concentrated outliers (filtered out) above 1.7 mil. PlayStation 4 is the second most widely distributed platform in terms of sales.
# - Average Sales, we see that sales are balanced between low and high sales, but still there is a skew to the left as the Q1 sales are larger than the Q3 sales, implying that even on average we tend to see higher sales.
#
#
# **XOne**<br>
# - Total Sales, XOne comes in 3rd in total sales (summed). XOne's sales pattern appears to be similar to PS4's. There is less spread in terms of sales, and the median is a bit higher than PS4, and we can see that the maximum point is lower. We also have outliers that are filtered out around 1.6.
# - Average sales, things become more interesting when we examine averages, XOne has ranked second in terms of average revenues relative to other leading platforms in recent years. Most of the average sales are over 0.8 million, and the graph is heavily skewed to the left.<br>
#
#
# **X360**<br>
# - Total Sales, Overall, X360 is the last platform in terms of total sales (summed), its pattern is a combination of XOne and PS4, we can see that its median value is higher than both previous platforms, and its distribution of sales values is the greatest. Outliers start at a higher point, meaning that there are some big titles for this platform.
# - Average sales, the picture is a bit different as X360 is 3rd place in average sales, skewed to the right but scoring higher than 3DS and PS3, which are the least profitable platforms on average.<br>
#
#
# **3DS**<br>
# - Total Sales, The 3DS is in 4th place in terms of total sales (summed). The median sits around 0.1, and the outliers are around 0.7 and above. There is the same right skewness seen across all platforms, but there is some difference in the way the values are distributed, probably because of the platform's nature and its unique titles. The game is at the end of its lifecycle, and its target audience could be completely different.
# - Average Sales, 3DS is in the 4th place, less skewed to the right but still mostly uniformly spread with it's minimum value aound the median of PS3.<br>
#
#
# **PS3**<br>
# - Total Sales, The PS3 came in 2nd overall in terms of sales (summed), with a strong skew towards the right. It's less spread than the other big platforms and the median is below 0.2, indicating a very high outlier count if it's the 2nd place in total sales summed, as we can see from the graph.
# - Average Sales, PlayStation 3 is in last place, skewed still rightward but not as significantly as in total sales, with its median under 0.4 in average sales.

# %% [markdown]
# <S><div style="border:solid red 2px; padding: 20px"> <b>Needs fixing:</b><br>
#    Here is an important point: after grouping the data, the boxplots for each platform essentially include a few points, i.e. the global sales data for each platform over 4 years, which is 4 points. Here it is important to plot the global sales data for the most prospective platforms without using grouping to see the variability in total sales. You will have outliers on the graph, it's important to limit them by using the `ylim()` parameter in the graph construction.
# </div>

# %% [markdown]
# <div style="border:solid orange 2px; padding: 20px"> <b>Remarks V2:</b><br>
#     Thank you so much for the corrections, now boxplots look great. But could you please describe what you see in the first chart and write the interpretation ?</div>

# %% [markdown]
# <div class="alert alert-info" style="border:solid blue 2px; padding: 20px"> <b>Student comment V2:</b> DONE!<br>
# </div>

# %% [markdown]
# <s><div style="border:solid orange 2px; padding: 20px"> <b>Remarks:</b><br>
#     In fact, the PS3 and X360 platforms are at the end of their lifespan and are "dying out".  Please pay attention to the WiiU platform, in fact, it can be considered perspective as well.</div>

# %% [markdown]
# <div class="alert alert-info" style="border:solid blue 2px; padding: 20px"> <b>Student comment:</b> DONE!<br>
# Although the WiiU can be considered a profitable platform, even though PS3 and X360 are dying consoles, WiiU didn't sell as much, and its Z-score is below average.<br>
#     In light of all that, and knowing that Nintendo announced the Switch console in 2016 (not included in the data), which eventually replaced the WiiU, I decided not to include it.
# </div>

# %% [markdown]
# <div style="border:solid green 2px; padding: 20px"> <b>Success V2:</b><br>
#     Ok, I see. Thanks for the explanations :)</div>
# <br>

# %% [markdown]
# <div style="border:solid green 2px; padding: 20px"> <b>Success:</b><br>
#   👍 </div>
# <br>

# %% [markdown]
# ### How reviews affects sales of PS4
# <a class="anchor" id="chapter22"></a>
# [Go back to the Table of Contents](#table_of_contents)

# %% [markdown]
# We'll take a look at how user score affect sales on one popular and current platform, compared to critic score.

# %%
df_score_effect = lead_platforms_2013_data.query('platform == "PS4"').copy(deep=True)
#df_score_effect = df_score_effect.query('year_of_release != 0')
df_score_effect = df_score_effect[df_score_effect.notna().all(axis=1)]
df_score_effect['user_score'] = (df_score_effect['user_score'] * 10)

# %%
df_score_effect
# Out:
#                                         name platform  year_of_release  \
# 42                        Grand Theft Auto V      PS4             2014
# 77                                   FIFA 16      PS4             2015
# 92            Call of Duty: Advanced Warfare      PS4             2014
# 94                                   FIFA 17      PS4             2016
# 105                                Fallout 4      PS4             2015
# ...                                      ...      ...              ...
# 16135                Super Stardust Ultra VR      PS4             2016
# 16486                     Super Dungeon Bros      PS4             2016
# 16499  Sherlock Holmes: The Devil's Daughter      PS4             2016
# 16526                             Dungeons 2      PS4             2016
# 16530                Carmageddon: Max Damage      PS4             2016
#
#               genre  na_sales  eu_sales  jp_sales  other_sales  critic_score  \
# ...

# %%
fig, axes = plt.subplots(1, 2, figsize=(16,8), sharex=True)
fig.suptitle('How User / Critic Score Affect Sales on PS4', size=24)
sns.set_style("whitegrid")
sns.scatterplot(ax=axes[0], x=df_score_effect['user_score'], y=df_score_effect['total_sales']);
axes[0].set_title('User Score' , size = 18 );
axes[0].set_xlabel('Score', size=14);
axes[0].set_ylabel('Total sales in mil.', size=14);
axes[0].tick_params(axis='both', which='major', labelsize=14)

sns.scatterplot(ax=axes[1], x=df_score_effect['critic_score'], y=df_score_effect['total_sales']);
axes[1].set_title('Critic Score' , size = 18 );
axes[1].set_xlabel('Score', size=14);
axes[1].set_ylabel('Total sales in mil.', size=14);
axes[1].tick_params(axis='both', which='major', labelsize=14)
sns.despine()

# %% [markdown]
# Based on the scatter plots between reviews and sales for PS4:
# 1. As we can see, user_score is more widely distributed on the graph, with most values concentrated around 50-90 in score and close to 0 in sales. There are some sparse plots in the center of the graph, leaning slightly to the right.<br>
#
#
# 2. The critic_score graph on the other hand shows that despite the concentration around 50-90 on the score axis, and between 0-1 on the sales axis, there is a tendency to skew to the left and slightly upward.

# %%
score_corr = df_score_effect[['critic_score', 'user_score', 'total_sales']].corr()
score_corr
# Out:
#               critic_score  user_score  total_sales
# critic_score      1.000000    0.572802     0.403573
# user_score        0.572802    1.000000    -0.030888
# total_sales       0.403573   -0.030888     1.000000

# %% [markdown]
# According to the correlation between reviews and sales for PS4:
# 1. A very weak negative correlation (-0.03) exists between user_score and sales, vitually almost no correlation at all.<br> User scores probably arrive later in terms of sales, since it takes time for the game to be played and reviewed, so by the time the game is reviewed, it could mean that most users have already played it.<br>
#
#
# 2. There is a medium positive correlation (0.40) between critic score and sales, when sales rise, critic score goes up, and vice versa, but not by a large margin. It makes sense, since usually critics get early access to games so they can play and review them. The game gets reviews from critics by the time it is on the market, and I would guess that the score affects to some extent whether a gamer would like to play it. Alternatively, there may be cases where critic scores aren't that important, and gamers simply want to play the game, and that is why we tend to see a medium correlation between sales and critic scores.<br>
#
# * It is also interesting to see that there is a medium correlation between critic score and user score, the trends of both are generally the same, but there is a difference in how each of them reacts to new games.

# %% [markdown]
# **Conclusion**<br>
#
# There seem to be no strong correlation, positive or negative, between reviews and sales.<br>
# It seems as though gamers just want to play and enjoy games and generally don't really care much for reviews.

# %% [markdown]
# <div style="border:solid green 2px; padding: 20px"> <b>Success:</b><br>
#     Yes, absolutely correct. It's great that you are making assumptions and explaining your conclusions in detail :)</div>

# %% [markdown]
# ### How reviews affect sales of other popular platforms
# <a class="anchor" id="chapter23"></a>
# [Go back to the Table of Contents](#table_of_contents)

# %% [markdown]
# On the other popular platforms we will use the same methods that were used with PS4 to see if there are similar or different trends.

# %% [markdown]
# Filtering the data and removing PS4 from the data for the next few steps.

# %%
lead_platforms_2013_data_score = lead_platforms_2013_data[['platform', 'critic_score', 'user_score', 'total_sales']]
lead_platforms_2013_data_score = lead_platforms_2013_data_score[lead_platforms_2013_data_score.notna().all(axis=1)]
lead_platforms_2013_data_score['user_score'] *= 10
lead_platforms_2013_data_score = lead_platforms_2013_data_score.query('platform != "PS4"')

# %% [markdown]
# Filtering PS4 out of the list of popular consoles.

# %%
lead_platforms_2013_other = lead_platforms_2013.iloc[0:4]

# %% [markdown]
# Create a function that, for a given console, does the following:<br>
# - Displays the correlation between user score and sales and critic score and sales.
# - Making scatter plots comparing critic and user ratings to total sales.
#
#
# This function is used in a loop for every other popular platform found in our data.

# %%
def score_effect(data,platform):
    # Creating a class for text styling
    class color:
        BOLD = '\033[1m'       # Bold text
        UNDERLINE = '\033[4m'  # Undelined text
        END = '\033[0m'        # End of text styling
    print(color.BOLD + color.UNDERLINE + 'Score / Sales Affect For', platform + color.END)
    print()
    
    # Filtering the data by platfrom
    data = data.query('platform == @platform')
    
    # Filtering data for critic reviews
    data_critic = data.drop('user_score',axis=1)
    print('There are', len(data_critic), 'reviews by critics for that platform')
    print('The correlation between critic score and sales is {:.2f}'
          .format(data_critic['total_sales'].corr(data_critic['critic_score'])))
    print()

    # Filtering data for user reviews
    data_user = data.drop('critic_score',axis=1)
    print('There are', len(data_user), 'reviews by users for that platform')
    print('The correlation between user score and sales is {:.2f}'
          .format(data_user['total_sales'].corr(data_user['user_score'])))
    print()
    
    # Plotting scatter for users and critics review for that platform
    fig, axes = plt.subplots(1, 2, figsize=(12,6), sharex=True)                               # Creating the figure and the axes for plotting.
    fig.suptitle('How User / Critic Score Affect Sales on '+platform, size=25)                # Creating the main title of the subplot.
    sns.set_style("whitegrid")                                                                # Setting the style of the plot to white grid.
    sns.scatterplot(ax=axes[0], x=data_user['user_score'], y=data_user['total_sales']);       # Plotting the first scatter for user score for that platform.
    axes[0].set_title('User Score' , size = 17 );                                             # Setting title of the first graph (left).
    axes[0].set_xlabel('Score', size=15);                                                     # Setting title and size of x axis.
    axes[0].set_ylabel('Total sales in mil.', size=15);                                       # Setting title and size of y axis.

    sns.scatterplot(ax=axes[1], x=data_critic['critic_score'], y=data_critic['total_sales']); # Plotting the second scatter for critic score for that platform.
    axes[1].set_title('Critic Score' , size = 17 );                                           # Setting title of the first graph (left).
    axes[1].set_xlabel('Score', size=15);                                                     # Setting title and size of x axis.
    axes[1].set_ylabel('Total sales in mil.', size=15);                                       # Setting title and size of y axis.
    sns.despine()                                                                             # Styling figure without top and right borders.
    plt.show()                                                                                # Showing plot and preventing plot to apear after the text for all iterations has been printed!
    print()
for x in lead_platforms_2013_other:                                                           # Create a loop to print all of the above for each of the popular platforms.
    score_effect(data=lead_platforms_2013_data_score, platform=x)
# Out:
# Score / Sales Affect For X360
#
# There are 81 reviews by critics for that platform
# The correlation between critic score and sales is 0.35
#
# There are 81 reviews by users for that platform
# The correlation between user score and sales is -0.01
# Score / Sales Affect For 3DS
#
# There are 67 reviews by critics for that platform
# The correlation between critic score and sales is 0.34
#
# There are 67 reviews by users for that platform
# The correlation between user score and sales is 0.27
# Score / Sales Affect For XOne
#
# There are 165 reviews by critics for that platform
# The correlation between critic score and sales is 0.41
#
# There are 165 reviews by users for that platform
# The correlation between user score and sales is -0.09
# Score / Sales Affect For PS3
#
# There are 120 reviews by critics for that platform
# The correlation between critic score and sales is 0.33
#
# There are 120 reviews by users for that platform
# ...

# %% [markdown]
# **Conclusion**<br>
#
# **X360:**<br>
#
# In the case of the X360, we see that there aren't many reviews for the time frame we choose to analyze, and this console has been replaced by the XOne, but we'll still interpret the data.<br>
#
# Based on the data we have, we see a weak positive correlation (0.35) between critics score and sales, similar to what we saw on the PS4 but weaker.<br>
#
# It appears, however, that there is virtually no correlation (-0.01) between user score and sales, which makes sense based on our limited data.<br>
#
# When we examine the scatter plots, we see two distinct trends: on one hand, the critics score distribution is more unified and skewed to the left, while the user score distribution is more scattered and without any apparent trend, which explains our correlation results.<br>
# <br>
#
#
# **3DS:**<br>
#
# In the case of the 3DS, we see even fewer reviews than we see for the X360 or PS4.<br>
# According to our data, this console does not appear to have a successor, and sales are declining steadily.<br>
#
# We see a weak positive correlation (0.34) between critics' scores and sales based on the data we have, similar to the X360.<br>
#
# Interestingly, we can see a weak positive correlation (0.27) between user score and sales, which is the opposite of most popular consoles. I wonder what makes the 3DS unique in that regard since Nintendo has a certain reputation among traditional gamer communities.<br>
#
# The scatter plots show that the critics' score distribution is less unified and skewed to the left, while the user's score distribution is more unified and also skewed to the left.<br>
# <br>
#
#
# **XOne:**<br>
#
# The XOne has twice as many reviews for the time period we chose compared to the X360, which makes sense since it is the successor to the X360 and we have much more data for the chosen period.<br>
#
# In the data we have, we see a medium-ish positive correlation (0.41) between critics score and sales, similar to what we saw on the PS4 but weaker.<br>
#
# However, it appears there is a very very weak negative correlation (-0.09) between user score and sales. I wonder if we had more data on the X360 we would see the same trend🤔.<br>
#
# The scatter plots reveal two distinct trends in score distributions: on the one hand, the critics score distribution is more unified and skewed to the left, while the user score distribution is more scattered and without any apparent trend, explaining our correlation results.<br>
# <br>
#
#
# **PS3:**<br>
#
# For the PS3, we find that there are 1.5 times as many reviews as we saw at the beginning for the Xbox 360.<br>
# This console has been replaced by the PS4 we looked at earlier, but we'll interpret its data nonetheless.<br>
#
# We see a weak positive correlation (0.33) between critics' scores and sales, similar to what we saw with the PS4 but weaker.<br>
#
# However, it appears that there is virtually no correlation (0.02) between user score and sales, but it is the opposite of what we have with PS4.<br>
#
# According to the scatter plots, both distributions are more unified towards the bottom of the graph, but critics' scores show a more skewed distribution to the left, whereas user scores show a more dispersed pattern, which is the reason behind our correlation findings.<br>
#
# **Critics score has little effect on sales, and user scores have no effect at all.**

# %% [markdown]
# <div style="border:solid green 2px; padding: 20px"> <b>Success:</b><br>
#     Perfect! Thus, the critics' score has little effect on sales; the users' score has no effect on sales.</div>

# %% [markdown]
# ### Distribution of games by genre
# <a class="anchor" id="chapter24"></a>
# [Go back to the Table of Contents](#table_of_contents)

# %%
lead_platforms_2013_data_genre = lead_platforms_2013_data.groupby(['genre'])['total_sales'].sum().sort_values().reset_index()
lead_platforms_2013_data_genre
# Out:
#            genre  total_sales
# 0         Puzzle         1.79
# 1       Strategy         3.20
# 2     Simulation        13.05
# 3      Adventure        18.59
# 4       Platform        22.88
# 5       Fighting        27.91
# 6         Racing        31.46
# 7           Misc        43.57
# 8   Role-Playing       127.83
# 9         Sports       142.48
# 10       Shooter       216.22
# 11        Action       285.96

# %% [markdown]
# The most profitable genre is action, followed by shooter by a small margin, and sports is almost 100 million behind.

# %% [markdown]
# Let's visualize it.

# %%
fig, ax = plt.subplots(figsize=(17,10))
sns.set_style("whitegrid")
sns.barplot(data=lead_platforms_2013_data_genre, 
             x="genre", 
             y="total_sales", )
ax.set_title( 'Total Sales (mil.) By Genre' , size = 25 )
plt.xlabel('Genre', size=18);
plt.ylabel('Number of sales in mil.', size=18);
plt.yticks(size=13)
plt.xticks(rotation=45, size=14);
sns.despine()

# %% [markdown]
# **Conclusion**<br>
#
# As can be seen from the graph, the most profitable genres of games in matching order of decent profit are Action, Shooter, Sports, and Role-Playing.

# %% [markdown]
# <div style="border:solid green 2px; padding: 20px"> <b>Success:</b><br>
#     Yes, your thoughts are logical 🙂  </div>

# %% [markdown]
# ----

# %% [markdown]
# ## 4. User Profile For Each Region
# <a class="anchor" id="chapter25"></a>
# [Go back to the Table of Contents](#table_of_contents)

# %% [markdown]
# ### Top 5 platforms per region
# <a class="anchor" id="chapter26"></a>
# [Go back to the Table of Contents](#table_of_contents)

# %% [markdown]
# In order to see how our lead platforms perform in different regions, we need to organize the data accordingly.

# %% [markdown]
# The data will be organized and sorted similarly for all regions so we can display them in a stacked bar graph.

# %%
top_platforms_na = lead_platforms_2013_data[['platform', 'na_sales']].groupby(['platform']).sum().sort_values(by='na_sales').reset_index()
top_platforms_na = top_platforms_na[top_platforms_na['na_sales'] > 0].reset_index(drop=True)

# %%
top_platforms_na_sort = top_platforms_na.sort_values(['platform']).reset_index(drop=True)

# %%
top_platforms_eu = lead_platforms_2013_data[['platform', 'eu_sales']].groupby(['platform']).sum().sort_values(by='eu_sales').reset_index()
top_platforms_eu = top_platforms_eu[top_platforms_eu['eu_sales'] > 0].reset_index(drop=True)

# %%
top_platforms_eu_sort = top_platforms_eu.sort_values(['platform']).reset_index(drop=True)

# %%
top_platforms_jp = lead_platforms_2013_data[['platform', 'jp_sales']].groupby(['platform']).sum().sort_values(by='jp_sales').reset_index()
top_platforms_jp = top_platforms_jp[top_platforms_jp['jp_sales'] > 0].reset_index(drop=True)

# %%
top_platforms_jp_sort = top_platforms_jp.sort_values(['platform']).reset_index(drop=True)

# %% [markdown]
# Plotting the stacked bar graph

# %%
fig, ax = plt.subplots(figsize=(14,10))
ax.bar(top_platforms_na_sort['platform'], 
       top_platforms_na_sort['na_sales'], label = 'North-America Sales')

ax.bar(top_platforms_eu_sort['platform'], 
      top_platforms_eu_sort['eu_sales'], label = 'Europe Sales', 
       bottom = top_platforms_na_sort['na_sales'])

ax.bar(top_platforms_jp_sort['platform'], 
       top_platforms_jp_sort['jp_sales'], label = 'Japan Sales', 
       bottom = top_platforms_na_sort['na_sales'])

ax.set_title('Top Platforms per Region',size=20)
ax.set_xlabel('Platform', size=16);
ax.set_ylabel('Total sales in mil.', size=16);
ax.tick_params(axis='both', which='major', labelsize=12)
ax.legend(fontsize = 14);

# %% [markdown]
# <div style="border:solid orange 2px; padding: 20px"> <b>Remarks:</b><br>
#
#    You can make such graphs interactive using the `plotly` library. I leave the link, it could be useful:
#
#   https://plotly.com/python/bar-charts/</div>

# %% [markdown]
# <div class="alert alert-info" style="border:solid blue 2px; padding: 20px"> <b>Student comment:</b> <br>
# I appreciate your input. I'll keep it in mind for future projects.
# </div>

# %% [markdown]
# #### Conclusion
# <a class="anchor" id="chapter36"></a>
# [Go back to the Table of Contents](#table_of_contents)

# %% [markdown]
# **PS4**<br>
# Comparing PS4 with other platforms, it is obvious that it is the leading platform. It appears to be most popular among European gamers, closely followed by US players and not so many Japanese players as this is the 3rd most popular platform in Japan.<br>
#
#
# **XOne**<br>
# the 2nd most popular platform, we can see that it is highly popular in the US a little shy of PS4 popularity, and less popular in Europe but still more popular than PS3 and X360.<br>
#
#
# **PS3**<br>
# The PS3 takes third place in terms of popularity worldwide, more so in the US than in Europe and Japan, while in Japan, it is the 2nd most popular.<br>
#
#
# **X360**<br>
# On our fourth popular console, we are seeing X360. It is nearing the end of its lifecycle and has been replaced by XOne. While it is more popular in the US than in Europe, we don't see any Japanese gamers using it.<br>
#
# **3DS**<br>
# In Japan, it is the most popular console of all platforms and all regions. In the United States, it is ranked 5th, while gamers still use it.

# %% [markdown]
# <div style="border:solid green 2px; padding: 20px"> <b>Success:</b><br>
#     Well done!</div>

# %% [markdown]
# ### Top five genres per region
# <a class="anchor" id="chapter27"></a>
# [Go back to the Table of Contents](#table_of_contents)

# %% [markdown]
# In order to see how popular are different genres in different regions, we need to organize the data accordingly.

# %% [markdown]
# The data will be organized and sorted similarly for all regions so we can display them in a stacked bar graph.

# %%
top_5_genres_na = lead_platforms_2013_data.groupby(['genre'])['na_sales'].sum().sort_values().reset_index()
top_5_genres_na_sort = top_5_genres_na.sort_values(['genre']).reset_index(drop=True)

# %%
top_5_genres_eu = lead_platforms_2013_data.groupby(['genre'])['eu_sales'].sum().sort_values().reset_index()
top_5_genres_eu_sort = top_5_genres_eu.sort_values(['genre']).reset_index(drop=True)

# %%
top_5_genres_jp = lead_platforms_2013_data.groupby(['genre'])['jp_sales'].sum().sort_values().reset_index()
top_5_genres_jp_sort = top_5_genres_jp.sort_values(['genre']).reset_index(drop=True)

# %% [markdown]
# Plotting the stacked bar graph

# %%
fig, ax = plt.subplots(figsize=(14,10))
ax.bar(top_5_genres_na_sort['genre'], 
       top_5_genres_na_sort['na_sales'], label = 'North-America Sales')

ax.bar(top_5_genres_eu_sort['genre'], 
      top_5_genres_eu_sort['eu_sales'], label = 'Europe Sales', 
       bottom = top_5_genres_na_sort['na_sales'])

ax.bar(top_5_genres_jp_sort['genre'], 
       top_5_genres_jp_sort['jp_sales'], label = 'Japan Sales', 
       bottom = top_5_genres_na_sort['na_sales'])

ax.set_title('Top Genres per Region',size=20)
ax.set_xlabel('Genre', size=16);
ax.set_ylabel('Total sales in mil.', size=16);
ax.tick_params(axis='both', which='major', labelsize=12)
ax.legend(fontsize = 14);

# %% [markdown]
# <s><div style="border:solid orange 2px; padding: 20px"> <b>Remarks:</b><br>
#   Please, pay attention to x-axes caption - it's not a platform, it's the name of a genre :)</div>
# <br>

# %% [markdown]
# <div class="alert alert-info" style="border:solid blue 2px; padding: 20px"> <b>Student comment:</b><br>
# Oops 😅
# </div>

# %% [markdown]
# <div style="border:solid green 2px; padding: 20px"> <b>Success V2:</b><br>
#     👍</div>

# %% [markdown]
# #### Conclusion
# <a class="anchor" id="chapter37"></a>
# [Go back to the Table of Contents](#table_of_contents)

# %% [markdown]
# **Action**<br>
# Globally, Action may be the most promising genre in terms of revenue compared to all the other genres. Most of its fans are American gamers, followed by European gamers and Japanese players.<br>
# It is the most popular genre in Europe and the second most popular in Japan.<br>
#
#
# **Shooter**<br>
# In addition to being the second most popular genre worldwide, it is the second most popular in the United States and in Europe.<br>
# There aren't a lot of Japanese gamers playing this genre as it ranks 4th or 5th in popularity.<br>
#
#
# **Sports**<br>
# Across the globe, sports is the 3rd most popular genre, with US players outpacing Europeans by a small margin.<br>
# There doesn't seem to be much demand in Japan for this genre.<br>
#
#
# **Role-Playing**<br>
# Although role-playing games rank fourth in popularity worldwide, they are the most popular in Japan, followed by US players by a narrow margin.<br>
# European players do not seem to be playing it, however.<br>
#
# **Misc**<br>
# It appears that misc (a collection of niche genres) is the 5th most popular genre worldwide, probably due to its multiple genres. There are more Americans who are fans than Europeans or Japanese, while Japan is last among the three countries.

# %% [markdown]
# ### ESRB rating affect on sales per region
# <a class="anchor" id="chapter28"></a>
# [Go back to the Table of Contents](#table_of_contents)

# %% [markdown]
# In order to see how ESRB ratings affect sales in different regions, we need to organize the data accordingly.

# %% [markdown]
# The data will be organized and sorted similarly for all regions so we can display them in a stacked bar graph.

# %%
na_esrb = lead_platforms_2013_data[lead_platforms_2013_data.notnull().all(axis=1)]
na_esrb = na_esrb.groupby(['rating'])['na_sales'].sum().sort_values().reset_index()
na_esrb_sort = na_esrb.sort_values(['rating']).reset_index(drop=True)

# %%
eu_esrb = lead_platforms_2013_data[lead_platforms_2013_data.notnull().all(axis=1)]
eu_esrb = eu_esrb.groupby(['rating'])['eu_sales'].sum().sort_values().reset_index()
eu_esrb_sort = eu_esrb.sort_values(['rating']).reset_index(drop=True)

# %%
jp_esrb = lead_platforms_2013_data[lead_platforms_2013_data.notnull().all(axis=1)]
jp_esrb = jp_esrb.groupby(['rating'])['jp_sales'].sum().sort_values().reset_index()
jp_esrb_sort = jp_esrb.sort_values(['rating']).reset_index(drop=True)

# %% [markdown]
# Plotting the stacked bar graph

# %%
fig, ax = plt.subplots(figsize=(14,10))
ax.bar(na_esrb_sort['rating'], 
       na_esrb_sort['na_sales'], 
       label = 'North-America Sales')

ax.bar(eu_esrb_sort['rating'], 
      eu_esrb_sort['eu_sales'], label = 'Europe Sales', 
       bottom = na_esrb_sort['na_sales'])

ax.bar(jp_esrb_sort['rating'], 
       jp_esrb_sort['jp_sales'], label = 'Japan Sales', 
       bottom = na_esrb_sort['na_sales'])

ax.set_title('ESRB Rating / Sales per Region',size=20)
ax.set_xlabel('ESRB Rating', size=16);
ax.set_ylabel('Total sales in mil.', size=16);
ax.tick_params(axis='both', which='major', labelsize=12)
ax.legend(fontsize = 14);

# %% [markdown]
# #### Conclusion
# <a class="anchor" id="chapter38"></a>
# [Go back to the Table of Contents](#table_of_contents)

# %% [markdown]
# **M**<br>
# Mature rating seems to be the most profitable genre worldwide.<br>
# It is highly popular in the US followed by Europe by a small margin.<br>
# It seems to be the 2nd most popular in Japan after Teen.<br>
#
#
# **E**<br>
# Everyone rating is the 2nd most profitable rating worldwide.<br>
# While it is as popular in the US and Europe, it is not so popular in Japan (3rd place).<br>
#
#
# **T**<br>
# Teen rating is the 3rd most popular world wide, while being the most popular rating is Japan.<br>
# It could also indicate what age group gamers play games in Japan, or how parents may care more about what their children play in Japan than in other countries.<br>
# It is more popular among US gamers than European gamers.<br>
#
# **E 10+**<br>
# The 10+ rating is the least profitable worldwide, probably due to the small jump to the T rating, which might be more interesting to play.<br>
# While it is more popular in the U.S. than in Europe, there is no indication of its popularity in Japan.

# %% [markdown]
# <div style="border:solid green 2px; padding: 20px"> <b>Success:</b><br>
#     Great!</div>

# %% [markdown]
# ### Profiling Conclusion
# <a class="anchor" id="chapter29"></a>
# [Go back to the Table of Contents](#table_of_contents)

# %% [markdown]
# Our analysis of the different regions reveals interesting details that we'll need to consider in our forecast.<br>
# - In terms of players' behavior, the markets in Europe and the US are quite similar.
# - The Japanese market is very different in terms of behavior and preferences.
# <br>
#
# From a platform perspective, we can see that **PS4 is the most profitable in the US and Europe**, while **3DS is the most profitable in Japan** (but it's nearing the end of its lifecycle).<br>
#
# **We have very strong evidence that action is the most profitable genre worldwide**, while it is the most popular genre in the US and EU, it is the 2nd most popular genre in Japan after role-playing games.<br>
#
# It seems that ESRB ratings affect sales, as mature games are much more profitable than the other ratings, perhaps because these games are the most enjoyable to play, or simply because there are more games of that rating available.<br>
# In terms of popularity and profitability, **mature is most popular worldwide**, it is most profitable in the United States and Europe, and it is the second most profitable in Japan.

# %% [markdown]
# <div style="border:solid green 2px; padding: 20px"> <b>Success:</b><br>
#     Great analysis by region! It's great that you worked out this point in such detail.
# What do you think the similarities and differences in the preferences of people from different regions might be related to?</div>

# %% [markdown]
# ----

# %% [markdown]
# ## 5. Hypotheses Testing
# <a class="anchor" id="chapter31"></a>
# [Go back to the Table of Contents](#table_of_contents)

# %% [markdown]
# ### XOne - PC user score
# <a class="anchor" id="chapter32"></a>
# [Go back to the Table of Contents](#table_of_contents)

# %% [markdown]
# **H0**: User ratings for Xbox One and PC belong to the same statistical population.<br>
# **H1**: The average user ratings for Xbox One and PC do not belong to the same population.<br>
# Our measure will be a null-test using a t-test for statistical insignificant difference, our level of sagnificance (alpha) be set to 0.05 as it is standard.

# %% [markdown]
# <div style="border:solid red 2px; padding: 20px"> <b>Needs fixing:</b><br>
#     Please pay attention, that "equal" conception is not appliable in case of distributions. Please, use "statistical insignificant difference" or "belonging to the same statistical population" in stead of it. </div>

# %% [markdown]
# <div class="alert alert-info" style="border:solid blue 2px; padding: 20px"> <b>Student comment:</b> DONE!<br>
# Thank you for the input, I would dive deeper into statistics as I feel I have some misunderstanding around it.
# </div>

# %% [markdown]
# <div style="border:solid red 2px; padding: 20px"> <b>Needs fixing V2:</b><br>
#     I mean to use this formulation for the null and alternative hypothesis to sound more professional, like this:
#
#    **H0:** Average user ratings by the platform Xbox One and PC  belong to the same statistical population.
#
#    **H1:** Average user ratings by the platform Xbox One and PC don't belong to the same statistical population.
# </div>

# %% [markdown]
# <div class="alert alert-info" style="border:solid blue 2px; padding: 20px"> <b>Student comment V2:</b> DONE!<br>
# </div>

# %%
pc = df_2013.query('platform == "PC"')
pc = pc[pc.notna().all(axis=1)]

# %% [markdown]
# <s><div style="border:solid red 2px; padding: 20px"> <b>Needs fixing:</b><br>
#     Please note that it is important here to use data from 2013 (the actual period we chose)</div>

# %% [markdown]
# <div class="alert alert-info" style="border:solid blue 2px; padding: 20px"> <b>Student comment:</b> DONE!<br>
# </div>

# %% [markdown]
# <div style="border:solid green 2px; padding: 20px"> <b>Success:</b><br>
#     Well done!</div>

# %%
xone = df_2013.query('platform == "XOne"')
xone = xone[xone.notna().all(axis=1)]

# %% [markdown]
# We'll run the t-test with equal variance.

# %%
alpha = 0.05  # critical statistical significance level.

xone_usc = xone['user_score'] # Data for XOne user scores.
pc_usc = pc['user_score'] # Data for PC user scores.

results = st.ttest_ind(xone_usc, 
                       pc_usc) # Performing t-test on both data sets.

print('p-value: ', results.pvalue)
print()
if results.pvalue < alpha: # if the p-value is less than alpha, we reject the hypothesis.
    print("We reject the null hypothesis")
else:
    print("We can't reject the null hypothesis")
# Out:
# p-value:  0.131558554879108
#
# We can't reject the null hypothesis

# %% [markdown]
# <div style="border:solid orange 2px; padding: 20px"> <b>Remarks:</b><br>
#
#    You checked the variance of the two samples and they were different, but in the T-test you don't use the parameter `equal_var=False` 🤔  </div>

# %% [markdown]
# <div class="alert alert-info" style="border:solid blue 2px; padding: 20px"> <b>Student comment:</b><br>
# Yes, because the variance test result was that they are equal, because it was less than 4, that's what I read online🧐.
# </div>

# %% [markdown]
# <div style="border:solid orange 2px; padding: 20px"> <b>Remarks V2:</b><br>
#
# Ok, the next time you can use a more scientific approach and apply Levene's test:
#
# https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.levene.html
#
# It is more accurate rather than use that heuristic estimate.
#
# </div>

# %% [markdown]
# <div class="alert alert-info" style="border:solid blue 2px; padding: 20px"> <b>Student comment V2:</b> 🙏🏼<br>
# </div>

# %% [markdown]
# #### **Conclusion** <br>
#
#
# Although our test does not prove our hypothesis(H0),<br>
# it suggests that the statistically speaking there might not be a sagnificant difference between our mean of user score for both platforms.<br>
# Thus, we cannot exclude it as a viable hypothesis.

# %% [markdown]
# ### Action - Sports genres user score
# <a class="anchor" id="chapter33"></a>
# [Go back to the Table of Contents](#table_of_contents)

# %% [markdown]
# **H0**: User ratings for Action and Sports belong to the same statistical population.<br>
# **H1**: The average user ratings for Action and Sports do not belong to the same population.<br>
# Our measure will be a null-test using a t-test for statistical insignificant difference, our level of sagnificance (alpha) be set to 0.05 as it is standard.

# %% [markdown]
# <div style="border:solid red 2px; padding: 20px"> <b>Needs fixing:</b><br>
#     The same problem in formulating hypotheses.</div>

# %% [markdown]
# <div class="alert alert-info" style="border:solid blue 2px; padding: 20px"> <b>Student comment:</b> DONE!<br>
# </div>

# %% [markdown]
# <div style="border:solid red 2px; padding: 20px"> <b>Needs fixing V2:</b><br>
#     Please pay attention to my comment above.</div>

# %% [markdown]
# <div class="alert alert-info" style="border:solid blue 2px; padding: 20px"> <b>Student comment V2:</b> DONE!<br>
# </div>

# %%
action = df_2013.query('genre == "Action"')
action = action[action.notna().all(axis=1)]

# %%
sports = df_2013.query('genre == "Sports"')
sports = sports[sports.notna().all(axis=1)]

# %% [markdown]
# <s><div style="border:solid red 2px; padding: 20px"> <b>Needs fixing:</b><br>
#     Please, use the actual period.</div>

# %% [markdown]
# <div class="alert alert-info" style="border:solid blue 2px; padding: 20px"> <b>Student comment:</b> DONE!<br>
# </div>

# %% [markdown]
# We'll run the t-test with equal variance.

# %%
alpha = 0.05  # critical statistical significance level.

action_usc = action['user_score'] # Data for Action user scores.
sports_usc = sports['user_score'] # Data for Sports user scores.

results = st.ttest_ind(action_usc, 
                       sports_usc) # Performing t-test on both data sets.

print('p-value: ', results.pvalue)
print()
if results.pvalue < alpha: # if the p-value is less than alpha, we reject the hypothesis.
    print("We reject the null hypothesis")
else:
    print("We can't reject the null hypothesis")
# Out:
# p-value:  1.7886065917750245e-15
#
# We reject the null hypothesis

# %% [markdown]
# #### **Conclusion** <br>
#
#
# Testing the statistical significance of the differences between the average user score for both popular geners among gamers, Action and Sports using t-test.
# The conclusion we draw is that we reject our null hypothesis (H0) because the statistical difference is not high enough, which means that we might suggest that there is difference in average user score between Action games and Sports games.

# %% [markdown]
# ----

# %% [markdown]
# ## 6. Overall Conclusion
# <a class="anchor" id="chapter34"></a>
# [Go back to the Table of Contents](#table_of_contents)

# %% [markdown]
# Ice is one of the most popular online gaming retailers in the industry, <br>
# serving countless customers every day by staying on top of the latest trends and providing exceptional service.<br>
#
# In order to serve Ice customers in the best way possible, we needed to develop a market forecast for the 2017 gaming market, considering developments and new trends in the industry.<br>
#
# With a variety of techniques and methods, we collected data from the gaming industry and extracted the valuable information we needed to make a prognosis for Ice campaigns in 2017.<br>
#
# Analyzing the data, **we found that to best meet our goal, we'll need to look at data from 2013 onwards, separated by different markets with different needs**.<br>
# Three sections of the global market were identified:
# 1. North-America.
# 2. Europe.
# 3. Japan.<br>
#
# We had other markets, but for the purpose of focusing Ice's advertising efforts, we chose these 3 because they are the biggest revenue generators.<br>
# <br>
#
#
# **- North-America**<br>
#
#
# **Among North-American gamers, the most popular platform is the PlayStation 4, followed by the Xbox One, only by a small margin.**<br>
# **Ice should focus its efforts on these two platforms** as they are the only ones in the data that are at the beginning of their life cycle**, compared to other consoles that are at the end of their life span and will be quickly obsolete. <br>
#
#
# As for game genres, we studied the different genres in every region and found that **the most profitable genre in North America is Action, followed by Shooter by a small margin, then Sports** and Role-Playing.<br>
# **Ice should concentrate its marketing efforts in North America on Action, Shooter, and Sports** as these are by far the most profitable genres.<br>
#
# **ESRB ratings show that Mature is the most profitable rating in North America by a very large margin**, followed by Everyone.<br>
# Ice should focus its marketing efforts on games that are rated Mature in North America to appeal to the biggest audience where the most profits are generated.<br>
# <br>
#
#
# **- Europe**<br>
#
#
# **Europe's most popular gaming platform is PS4 by a wide margin.**<br>
# Although the EU market and US are similar we can see those little but significant differences that can help Ice address its audience better and increase revenue.<br>
#
#
# We analyzed the different genres in every region and found that European gamers' preferences are very similar to those in the US.<br>
# **Ice should focus its marketing efforts in Europe on action, shooter and sports games, as these are by far the most profitable genres.**<br>
#
# From the ESRB ratings, we see that gamers in Europe have very similar preferences to those in the US.<br>
# **The most profitable rating is Mature by a wide margin**, followed by Everyone.<br>
# **We recommend that Ice uses its marketing resources in Europe to target the biggest audience and make the highest profits by focusing on games rated Mature.**<br>
# <br>
#
#
#
# **- Japan**<br>
#
#
# Our study indicated that **Japan is a very distinct and unique market** with different needs and audiences to target.<br>
# **In Japan, gamers prefer to play using the 3DS, which shows that the gaming audience in Japan is very different from that in the US or EU.**<br>
#
# As a marketing strategy, **we don't recommend focusing on 3DS** because **it's nearing the end of its life cycle** and **it would be better to carry out further research to find the new emerging consoles in Japan.**<br>
#
# Once again, we found Japan to be a unique market when it comes to genres of games. <br>
# **In Japan, the most profitable genre is Role-Playing, followed by Action. These two genres are more profitable by a significant margin.**<br>
#
# **Our recommendation would be to focus Ice's marketing efforts on role-playing and action in Japan** since these are the genres that are most profitable.<br>
#
# As we can see from the **ESRB Ratings**, the preferences of gamers in Japan are very different from those in the US and EU.<br>
# **Teen rating is the most profitable, followed by a Mature rating.**<br>
# This may indicate a difference in gaming audiences in Japan versus western countries, it could be that gamers in Japan are younger.<br>
# **We recommend Ice concentrate its marketing efforts in Japan on games rated Teen and Mature to appeal to the biggest audience where the most profits can be made.**

# %% [markdown]
# <div style="border:solid green 2px; padding: 20px"> <b>Success:</b><br>
#     Thank you for the detailed conclusion describing all the important insights of the study. You have a very awesome  project. Keep it up! 😊 </div>

# %% [markdown]
# ----

# %% [markdown]
# # Project completion checklist
# <a class="anchor" id="chapter35"></a>
# [Go back to the Table of Contents](#table_of_contents)

# %% [markdown]
# - [x] file opened.
# - [x] files explored (first rows printed, info() method).
# - [x] Replace the column names (make them lowercase).
# - [x] Convert the data to the required types.
# - [x] Describe the columns where the data types have been changed and why.
# - [x] Decide how to deal with missing values
# - [x] Explain why you filled in the missing values as you did or why you decided to leave them blank.
# - [x] Why do you think the values are missing? Give possible reasons.
# - [x] Pay attention to the abbreviation TBD (to be determined). Specify how you intend to handle such cases.
# - [x] Calculate the total sales (the sum of sales in all regions) for each game and put these values in a separate column.
# - [x] Look at how many games were released in different years. Is the data for every period significant?
# - [x] Look at how sales varied from platform to platform.
# - [x] Choose the platforms with the greatest total sales and build a distribution based on data for each year.
# - [x] Find platforms that used to be popular but now have zero sales.
# - [x] How long does it generally take for new platforms to appear and old ones to fade?
# - [x] Determine what period you should take data for. To do so, look at your answers to the previous questions.
# - [x] Work only with the data that you've decided is relevant. Disregard the data for previous years.
# - [x] Which platforms are leading in sales? Which ones are growing or shrinking? Select several potentially profitable platforms.
# - [x] Build a box plot for the global sales of all games, broken down by platform. Are the differences in sales significant? What about average sales on various platforms? Describe your findings.
# - [x] Take a look at how user and professional reviews affect sales for one popular platform (you choose). Build a scatter plot and calculate the correlation between reviews and sales. Draw conclusions.
# - [x] Keeping your conclusions in mind, compare the sales of the same games on other platforms.
# - [x] Take a look at the general distribution of games by genre. What can we say about the most profitable genres? Can you generalize about genres with high and low sales?
# - [x] The top five platforms. Describe variations in their market shares from region to region.
# - [x] The top five genres. Explain the difference.
# - [x] Do ESRB ratings affect sales in individual regions?
# - [x] Average user ratings of the Xbox One and PC platforms are the same.
# - [x] Average user ratings for the Action and Sports genres are different.
# - [x] Set the alpha threshold value yourself.
# - [x] Explain: How you formulated the null and alternative hypotheses
# - [x] Explain: What significance level you chose to test the hypotheses, and why
# - [x] Write an overall conclusion.
