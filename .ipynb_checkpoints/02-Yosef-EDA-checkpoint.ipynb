# %% [markdown]
# Hello, Yosef!
# My name is Olga. I'm happy to reviewing your project today.
#
# You can find my comments in green, yellow or red boxes like this:
#
#
# <div class="alert alert-block alert-success">
# <b>Reviewer's comment</b> <a class="tocSkip"></a>
#
# Success. Everything is done succesfully.
# </div>
#
#
# <div class="alert alert-block alert-warning">
# <b>Reviewer's comment</b> <a class="tocSkip"></a>
#
# Remarks. Some recommendations.
# </div>
#
#
# <div class="alert alert-block alert-danger">
#
# <b>Reviewer's comment</b> <a class="tocSkip"></a>
#
#
# Needs fixing. The block requires some corrections. Work can't be accepted with the red comments.
# </div>
#
# <b>Please don't remove my comments :)</b>
#
# You can answer me by using this:
#
# <div class="alert alert-block alert-info">
# <b>Student answer.</b> <a class="tocSkip"></a>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Overallv reviewer's comment</b> <a class="tocSkip"></a>
#
# Yosef, thank you for sending your project. You've done a really good job on it!
#
# While there's room for improvement, on the whole, your project is impressive good.I like your filling missing numbers in your project. You did a great job! I am really impressed!
#
# <span class="text-danger">There are few things that need to be corrected in your project. They're mostly minor issues that are easy to fix. I wrote comments, please, check them. Do not hesistate to ask an advice, if you have any problems!</span>
#
# Every issue with our code is a chance for us to learn something new.
#
# Good luck! :)
#
# </div>

# %% [markdown]
# <div class="alert alert-info" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Student's comment</h2>
# <strong>
# <p>thank you olga on the invesment of checking it, i'm sure it's not easy at all, and i took your remarks very seriously!</p>
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>For your future projects</b> <a class="tocSkip"></a>
#
# - try to give tables meaningful names. Cars, clients, orders etc. df = DataFrame. Imagine, that you have 50 tables: df1, df2, df3, etc. it is hard to understand which table we need.
#
# - It is very good that you use Markdown! Please, use it more clearly. You can right "conclusion" - and write you ideas. Check Navigate here. You will see all ideas by sentence.
#
# - I saw red automatic comments from Jupiter. We can remove them. We can add to libraries:
#
#         import warnings
#
#         warnings.filterwarnings("ignore")
#
#
# - Please, use Kernel-Restart&RunAll before sending a project. It helps to you to see problems in code and check them
# </div>

# %% [markdown]
# <div class="alert alert-info" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Student's comment</h2>
# <b>TO the reviewer: The platform haven't the updated versions of matplotlib and seaborn, that's why some of the graphs cause an error.       <br>
# I have added the code below, please, if you see that it runs and update matplolib and seaborn, restart the kernel so the updated libraries will took place :) <br>
# here i have added it before i import the libraries, so i think in this case you shouldnt restart the kernel.    <br>
#     thank you.      </b>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Overallv reviewer's comment</b> <a class="tocSkip"></a>
#
# Hello Yosef! Thank you for taking the time to correct your project! I really appreciate your hard work.
#
# Our project should start from cell №1. Also, sometimes reviewers should check some values and they need a work project. But firstly I checked your project and restart after that. :) It works now!
#
# Good idea to add libraries here. Perhaps, it is not good at work.Different companies have different security rules.
#
# I hope that I added comment anywhere. Your project is very big!
#
# <span class="text-danger">When you get a moment, shoot back for my comments, and I'll take a look to make sure everything is perfect.</span>
#
# Keep working on it, you are improving!
#
# One more time and you'll have it!
#
#
# </div>

# %%
# !pip install numpy

# %%
# !pip install pandas

# %%
# !pip install matplotlib

# %%
# !pip install seaborn

# %% [markdown]
# # Project 2: EDA

# %% [markdown]
# ## Project description
# I'm an analyst at Crankshaft List. Hundreds of free advertisements for vehicles are published on the company's site every day.I need to study data collected over the last few years and determine which factors influence the price of a vehicle.

# %% [markdown]
# ## Description of the data
# ## The dataset contains the following fields:
#
#    __price__
#    __model_year__
#    __model__
#    __condition__
#    __cylinders__
#    __fuel__ — gas, diesel, etc.
#    __odometer__ — the vehicle's mileage when the ad was published
#    __transmission__
#    __paint_color__
#    __is_4wd__ — whether the vehicle has 4-wheel drive (Boolean type)
#    __date_posted__ — the date the ad was published
#    __days_listed__ — from publication to removal

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Reviewer's comment</b> <a class="tocSkip"></a>
#
# Very good! Introduction is important part of our researh. We know what we have and our plans.
# </div>

# %% [markdown]
# ### Step 1. Open the data file and study the general information

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
try:
    df= pd.read_csv("vehicles_us.csv",na_values="null")
except Exception as e:
    df=pd.read_csv("/datasets/vehicles_us.csv",na_values="null")

# %%
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Reviewer's comment</b> <a class="tocSkip"></a>
#
# Import libraries in the first cell help us to set up programming environment.
#
# Try/Except is very good for working on a local and virtual machine.
#
# Well done!
#
# </div>

# %%
df.shape
# Out:
# (51525, 13)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51525 entries, 0 to 51524
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   price         51525 non-null  int64
#  1   model_year    47906 non-null  float64
#  2   model         51525 non-null  object
#  3   condition     51525 non-null  object
#  4   cylinders     46265 non-null  float64
#  5   fuel          51525 non-null  object
#  6   odometer      43633 non-null  float64
#  7   transmission  51525 non-null  object
#  8   type          51525 non-null  object
#  9   paint_color   42258 non-null  object
#  10  is_4wd        25572 non-null  float64
#  11  date_posted   51525 non-null  object
#  12  days_listed   51525 non-null  int64
# dtypes: float64(4), int64(2), object(7)
# memory usage: 5.1+ MB

# %% [markdown]
# #### we already see here some things which need our attention:
#     1. missing values: at columns "model_year","cylinders","odometer","paint_color","is_4wd".
#     2. dtypes: model_year,cylinders and odometer should be int, is_4wd should be boolean, days_posted should be a datetime object.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Reviewer's comment</b> <a class="tocSkip"></a>
#
# Great ideas!
#
# </div>

# %% [markdown]
# #### lets see how much missing values we have in each column:

# %%
df.isnull().sum()
# Out:
# price               0
# model_year       3619
# model               0
# condition           0
# cylinders        5260
# fuel                0
# odometer         7892
# transmission        0
# type                0
# paint_color      9267
# is_4wd          25953
# date_posted         0
# days_listed         0
# dtype: int64

# %% [markdown]
# #### or in precentage:

# %%
df.isnull().sum()*100/len(df)
# Out:
# price            0.000000
# model_year       7.023775
# model            0.000000
# condition        0.000000
# cylinders       10.208637
# fuel             0.000000
# odometer        15.316836
# transmission     0.000000
# type             0.000000
# paint_color     17.985444
# is_4wd          50.369723
# date_posted      0.000000
# days_listed      0.000000
# dtype: float64

# %%
df.head()
# Out:
#    price  model_year           model  condition  cylinders fuel  odometer  \
# 0   9400      2011.0          bmw x5       good        6.0  gas  145000.0
# 1  25500         NaN      ford f-150       good        6.0  gas   88705.0
# 2   5500      2013.0  hyundai sonata   like new        4.0  gas  110000.0
# 3   1500      2003.0      ford f-150       fair        8.0  gas       NaN
# 4  14900      2017.0    chrysler 200  excellent        4.0  gas   80903.0
#
#   transmission    type paint_color  is_4wd date_posted  days_listed
# 0    automatic     SUV         NaN     1.0  2018-06-23           19
# 1    automatic  pickup       white     1.0  2018-10-19           50
# 2    automatic   sedan         red     NaN  2019-02-07           79
# 3    automatic  pickup         NaN     NaN  2019-03-22            9
# 4    automatic   sedan       black     NaN  2019-04-02           28

# %%
df.tail()
# Out:
#        price  model_year           model  condition  cylinders fuel  odometer  \
# 51520   9249      2013.0   nissan maxima   like new        6.0  gas   88136.0
# 51521   2700      2002.0     honda civic    salvage        4.0  gas  181500.0
# 51522   3950      2009.0  hyundai sonata  excellent        4.0  gas  128000.0
# 51523   7455      2013.0  toyota corolla       good        4.0  gas  139573.0
# 51524   6300      2014.0   nissan altima       good        4.0  gas       NaN
#
#       transmission   type paint_color  is_4wd date_posted  days_listed
# 51520    automatic  sedan       black     NaN  2018-10-03           37
# 51521    automatic  sedan       white     NaN  2018-11-14           22
# 51522    automatic  sedan        blue     NaN  2018-11-15           32
# 51523    automatic  sedan       black     NaN  2018-07-02           71
# 51524    automatic  sedan         NaN     NaN  2018-06-05           10

# %%
df.sample(5)
# Out:
#        price  model_year                     model  condition  cylinders fuel  \
# 48351  36990      2019.0        chevrolet traverse   like new        6.0  gas
# 201    15900         NaN               ford escape  excellent        4.0  gas
# 25349  31988      2018.0       jeep grand cherokee   like new        6.0  gas
# 25846  15500      2011.0  chevrolet silverado 1500  excellent        8.0  gas
# 14502   6499      2010.0             honda odyssey       good        6.0  gas
#
#        odometer transmission   type paint_color  is_4wd date_posted  \
# 48351   12886.0    automatic    SUV       black     NaN  2019-02-12
# 201     19764.0    automatic    SUV       black     1.0  2018-07-03
# 25349   10000.0    automatic    SUV       black     NaN  2018-08-09
# 25846  213000.0    automatic  truck        blue     NaN  2018-05-28
# 14502       NaN    automatic    van        blue     NaN  2018-10-20
#
#        days_listed
# 48351           21
# 201             32
# 25349           10
# ...

# %% [markdown]
# ## we will create now a copy of the dataframe, so we could forward to compare data with and without outliers

# %%
df_outliers = df.copy()

# %%
df.describe().loc[['min','max']]
# Out:
#         price  model_year  cylinders  odometer  is_4wd  days_listed
# min       1.0      1908.0        3.0       0.0     1.0          0.0
# max  375000.0      2019.0       12.0  990000.0     1.0        271.0

# %% [markdown]
# ### There are some values which seems strange:
#     price - 1
#     odometer - 0
#     we see that the min and max in is_4wd is 1, which means thats the only value there.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Reviewer's comment</b> <a class="tocSkip"></a>
#
# Very good! You are absolutely right about strange values here!
#
# </div>
#
# <div class="alert alert-block alert-warning">
# <b>Reviewer's comment</b> <a class="tocSkip"></a>
#
# It would be It would be understandble and logically to use head()/tail()/sample() firstly. And info()/describe()/isnull()/etc secondly. :)
# </div>

# %% [markdown]
# <div class="alert alert-info" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Student's comment</h2>
# <b>TO the reviewer: you right!    </b>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Reviewer's comment. V.2.</b> <a class="tocSkip"></a>
#
# :)
# </div>

# %% [markdown]
# ### lets check these values:

# %% [markdown]
# ### __checking the odometer values__

# %% [markdown]
# #### if the odometer is 0, it should be a new car.

# %%
df_odometer = df.query("odometer==0")

# %%
df_odometer.sample(10)
# Out:
#        price  model_year                     model  condition  cylinders fuel  \
# 33893   6250      1968.0              chrysler 300       good        8.0  gas
# 1461    1000      1992.0           gmc sierra 1500       good        8.0  gas
# 49170   3300      2002.0          hyundai santa fe       good        6.0  gas
# 27923   5888      2004.0            toyota 4runner       good        6.0  gas
# 36121   8450      2010.0       jeep grand cherokee       good        6.0  gas
# 33887  11888      2010.0  chevrolet silverado 1500       good        8.0  gas
# 48169   7988      2011.0              ford mustang       good        6.0  gas
# 8266    1478      2011.0                ford f-150  excellent        8.0  gas
# 35632   5950      2008.0             nissan maxima       good        6.0  gas
# 31444   9900      2016.0             nissan altima  excellent        4.0  gas
#
#        odometer transmission   type paint_color  is_4wd date_posted  \
# ...

# %% [markdown]
# * from what we see, it isn't a new cars at all ! not in the model year, not in the condition.
# * seems like odometer 0 is replacement to null values lets check how many rows have it:

# %%
df_odometer.shape[0]
# Out:
# 185

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Reviewer's comment</b> <a class="tocSkip"></a>
#
# Not so much!
# </div>

# %% [markdown]
# #### maybe visualization help us to see more strange values:

# %%
fig,axes = plt.subplots(nrows=1, ncols=2,figsize=(12,5));
axes[0].hist(df['odometer'],bins=200);
axes[0].set_xlim(0,500000)
axes[0].set_xlabel('odometer');
axes[0].set_ylabel('count');
axes[0].set_title('odometer histogram');
df.boxplot("odometer")
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### we see here that there are many small values here, not just 0!
# #### (we could see in the histogram an unnatural "pick" on 0)
# #### lets check how many values we have under 1000:

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Reviewer's comment</b> <a class="tocSkip"></a>
#
# Let's check!
# </div>

# %%
df.query("odometer<1000").sample(8)
# Out:
#        price  model_year                       model condition  cylinders  \
# 20130   2500      2014.0               toyota tundra      good        8.0
# 30251   2750      1984.0  chevrolet silverado 2500hd      fair        8.0
# 929     4995      2003.0                  ford f-150  like new        8.0
# 30053   5995      2003.0                    ram 2500      good        6.0
# 20776   2800      2004.0                 honda civic      good        4.0
# 4837    1100      1997.0              toyota 4runner      fair        4.0
# 15610   8500         NaN                honda accord      good        4.0
# 38676  37784      2018.0    chevrolet silverado 1500       new        NaN
#
#          fuel  odometer transmission    type paint_color  is_4wd date_posted  \
# 20130     gas       1.0    automatic  pickup       white     1.0  2019-02-16
# 30251     gas       0.0    automatic   truck        blue     NaN  2018-11-20
# ...

# %% [markdown]
# #### it's not logical at all.
# #### there are many old cars with less than 1000 mile!
# #### i suspect that all this values are in thousands.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Reviewer's comment</b> <a class="tocSkip"></a>
#
# Yes, it is very strange value. I agree with you about values!
# </div>

# %% [markdown]
# #### lets see what happens above 1000 but under 10000:

# %%
df.query("1000<odometer<10000").sample(8)
# Out:
#        price  model_year                model  condition  cylinders    fuel  \
# 29934  34988      2018.0  chevrolet silverado   like new        4.0     gas
# 37843  38900      2019.0        toyota sienna        new        6.0     gas
# 5240   51995      2019.0             ram 2500  excellent        NaN  diesel
# 1891   60774      2018.0      chevrolet tahoe  excellent        8.0     gas
# 41995  37500      2018.0     chevrolet camaro   like new        8.0     gas
# 42492  38500      2005.0           gmc sierra   like new        8.0  diesel
# 40111  33950      2017.0             ram 1500   like new        8.0     gas
# 11625      1      2018.0             ram 3500  excellent        6.0     gas
#
#        odometer transmission      type paint_color  is_4wd date_posted  \
# 29934    3000.0    automatic     truck         NaN     NaN  2018-10-11
# 37843    5000.0    automatic  mini-van         red     1.0  2019-01-12
# ...

# %% [markdown]
# #### between 1000 and 10000, it's a little more logical (the last dates in the data are 2019).
# #### we will do two things:
#     * we would try to multiply by 1000 all the values which are smaller than 1000
#     * we will replace 0 values with null.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Reviewer's comment</b> <a class="tocSkip"></a>
#
# Wow! You did a great job here! You have studied the odometer in great detail. Excellent!
#
# </div>
#
# <div class="alert alert-block alert-danger">
# <b>Reviewer's comment</b> <a class="tocSkip"></a>
#
# ~Replace 0 values with null give to us unreal numbers. It would be better to fill missing values in odometer based on car model and year. Because often odometers value is the same for 2 cars with the same model and release year.~
#
# ~Please, change cell 18 and continue your great work. It is very interesting!~
#
# ~P.S. You can use this construction instead lambda:~
#
# ~df['odometer'] = df['odometer'].fillna(round(df.groupby(['model','model_year'])['odometer'].transform('median'),0))~
#
# </div>

# %% [markdown]
# <div class="alert alert-info" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Student's comment</h2>
#     <h4> I didn't explained clearly the proccess i did, so it's my fault that the proccess isn't clear enouth, because i already did what you had suggested but in a little different way.</h4>
#     <h4>i did it in 3 stages:</h4>
#
# <br>
# <b>1. first stage, i replaced all non logical values with null.</b> <br/>
# <br>
# <b>2. second stage, i replaced all the "nulls" (the old ones which were in the column, and the new ones i created) based on featuers like the car model and year - exactly like you suggested!.<br/></b>
# <br>
# <b>3. because i have a lot of nulls on the "model year" column (and i need this feature for the price and odometer columns) i have waited with the second stage until i filled all the null values in the model year column.</b>
#     <h3> so meantime, i am doing the first stage: i replace all non logical values with nulls</h3>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Reviewer's comment. V.2.</b> <a class="tocSkip"></a>
#
# Thank you for explanation. You can use comments in code:
#
#     #replaced all non logical values with null
#     your code
#
#     #replaced all the "nulls" (the old ones which were in the column, and the new ones i created) based on featuers like the car model and year
#     your code
#
#     etc
#
# It help to understand more clearly. :)
#
# </div>

# %% [markdown]
# ### __How i treat the outliers ?__
#
# ### __1. first stage, i replaced all non logical values with null.__
#
# ### __2. second stage, i replaced all the "nulls" (the "old" nulls, and the new ones I have created) based on featuers like the car model and year.__
#
# ### __3. because i have a lot of nulls on the "model year" column, and i need this feature to fill the price's and odometer's missing values, i have waited with the second stage until i filled all the null values in the model year column.__

# %% [markdown]
#     so now i am on the first stage and replacing all non logical values with nulls:

# %%
df["odometer"] = df["odometer"].apply(lambda x: x if x>1000 else x*1000)

# %%
df["odometer"] = df["odometer"].apply(lambda x: np.nan if x==0 else x)

# %%
fig,axes = plt.subplots(nrows=1, ncols=1,figsize=(8,5));
axes.hist(df['odometer'],bins=200);
axes.set_xlim(0,500000)
axes.set_xlabel('odometer');
axes.set_ylabel('count');
axes.set_title('odometer histogram');

# %% [markdown]
# #### it seems much better, the pick on 0 dissapired
# #### but still i think there is a problem  some values in the next table are not logical too:

# %%
df.query("odometer<10000 and model_year<2015").head()
# Out:
#       price  model_year                     model  condition  cylinders fuel  \
# 2834  49000      1965.0              ford mustang  excellent        8.0  gas
# 3695   2995      1992.0              ford mustang       fair        4.0  gas
# 3856  67500      1964.0        chevrolet corvette  excellent        8.0  gas
# 4708  10500      1974.0        chevrolet corvette       good        8.0  gas
# 6357  25600      2014.0  ford mustang gt coupe 2d       good        8.0  gas
#
#       odometer transmission         type paint_color  is_4wd date_posted  \
# 2834    5160.0       manual        other         red     NaN  2019-02-27
# 3695    1000.0    automatic  convertible         red     NaN  2018-08-06
# 3856    2800.0       manual        coupe      silver     NaN  2019-01-28
# 4708    4133.0    automatic        coupe         red     NaN  2018-09-16
# 6357    2589.0        other        coupe         NaN     NaN  2018-07-30
#
#       days_listed
# 2834           57
# 3695           10
# ...

# %%
len(df.query("odometer<10000 and model_year<2015"))
# Out:
# 87

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Reviewer's comment</b> <a class="tocSkip"></a>
#
# Intresting!
# </div>

# %% [markdown]
# #### we will replace all this strange values with null:

# %%
df["odometer"] = df.apply(lambda r: np.nan if r["odometer"]<10000 and r["model_year"]<2015 else r["odometer"],axis=1)

# %%
len(df.query("odometer<10000 and model_year<2015"))
# Out:
# 0

# %%
fig,axes = plt.subplots(nrows=1, ncols=1,figsize=(8,5));
axes.hist(df['odometer'],bins=200);
axes.set_xlim(0,500000)
axes.set_xlabel('odometer');
axes.set_ylabel('count');
axes.set_title('odometer histogram');

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Reviewer's comment</b> <a class="tocSkip"></a>
#
# Here 0 is ok!
# </div>

# %% [markdown]
# ### lets check the upper outliers:

# %% [markdown]
# #### we removed the x limit, so the plot seems smaller:

# %%
fig,axes = plt.subplots(nrows=1, ncols=1,figsize=(8,5));
axes.hist(df['odometer'],bins=200);
axes.set_xlabel('odometer');
axes.set_ylabel('count');
axes.set_title('odometer histogram');

# %%
df.query("odometer>400000")
# Out:
#        price  model_year                     model  condition  cylinders  \
# 1023    5000      1996.0            toyota 4runner       good        6.0
# 2264    2500      2001.0             toyota tundra    salvage        8.0
# 2440    5300      2010.0            toyota corolla  excellent        4.0
# 2840   18500      2014.0             ford explorer  excellent        6.0
# 3107    3500      2002.0                  ram 3500       good        6.0
# ...      ...         ...                       ...        ...        ...
# 45547  23988      2018.0             nissan altima   like new        4.0
# 48373   4995      2007.0  chevrolet silverado 1500       good        6.0
# 48962  40000      2014.0                  ram 3500  excellent        NaN
# 49206  11900      2004.0                  ram 2500       good        6.0
# 50742  12900      2018.0               honda civic   like new        4.0
#
#          fuel  odometer transmission    type paint_color  is_4wd date_posted  \
# ...

# %% [markdown]
# #### the average mile per year in usa is like 16500 for men and 11000 per women.
# the data is from here <a href="https://www.caranddriver.com/research/a32880477/average-mileage-per-year/">car and driver</a>
# #### we will took 40000 miles as a security factor. if
# ```
# (2019-model_year)*40000 < odometer
# ```
# we will see it as outlier. and replace it with null.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Reviewer's comment</b> <a class="tocSkip"></a>
#
# Excellt! It is very very good that you used other sites for information.
#
# Thank you for you give a give a link!
# </div>

# %% [markdown]
# #### first lets check how many values like this we have

# %%
df["high_odometer"] = df.apply(lambda r: 1 if (2019-r["model_year"])*40000<r["odometer"] else 0,axis=1)

# %%
df["high_odometer"].sum()
# Out:
# 1333

# %% [markdown]
# #### There are 1333 outliers with this condition.
# #### now we get rid from this column:

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Reviewer's comment</b> <a class="tocSkip"></a>
#
# Great! What's next?
# </div>

# %%
df.drop("high_odometer",inplace=True,axis=1)

# %%
def high_odometer(r):
    if (2019-r["model_year"])*40000<r["odometer"]:
        return np.nan
    else:
        return r["odometer"]

df["odometer"] = df.apply(high_odometer,axis=1)

# %%
fig,axes = plt.subplots(nrows=1, ncols=2,figsize=(12,5));
axes[0].hist(df['odometer'],bins=200);
axes[0].set_xlim(0,500000)
axes[0].set_xlabel('odometer');
axes[0].set_ylabel('count');
axes[0].set_title('odometer histogram');
df.boxplot("odometer")
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### we see that there are still some high values, lets check if these are old vehicles.

# %%
df.query("odometer>600000").head(10)
# Out:
#        price  model_year                model  condition  cylinders fuel  \
# 14245   6000      1996.0             ram 2500       good       10.0  gas
# 15588  16500         NaN        nissan maxima  excellent        6.0  gas
# 17869  59900      1964.0   chevrolet corvette   like new        NaN  gas
# 23839  15000      1998.0   chevrolet corvette  excellent        8.0  gas
# 39064  14998         NaN        nissan sentra  excellent        4.0  gas
# 40089  20000      1960.0     chevrolet impala  excellent        8.0  gas
# 42749  69900      1969.0     chevrolet camaro        new        8.0  gas
# 42985   4500      1988.0  chevrolet silverado       good        8.0  gas
# 43966   5000      1986.0   chevrolet corvette  excellent        8.0  gas
#
#         odometer transmission         type paint_color  is_4wd date_posted  \
# 14245   920000.0    automatic        truck        blue     NaN  2019-02-02
# 15588   950000.0    automatic        sedan       black     NaN  2018-07-25
# ...

# %% [markdown]
# #### seems o.k. !
# #### all these cars with high odometer are old ones!

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Reviewer's comment</b> <a class="tocSkip"></a>
#
# Yes, all clear!
# </div>

# %% [markdown]
# #### __we want now to fill all the null values in the "odometer" column based on our data. but we have a problem - there are many missing values in the "model_year" column.__
# #### __so we will fill all these missing values later, after we fill the missing values in the model year column__

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Reviewer's comment</b> <a class="tocSkip"></a>
#
# ~I wrote about missing values above, please check. :)~
# </div>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51525 entries, 0 to 51524
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   price         51525 non-null  int64
#  1   model_year    47906 non-null  float64
#  2   model         51525 non-null  object
#  3   condition     51525 non-null  object
#  4   cylinders     46265 non-null  float64
#  5   fuel          51525 non-null  object
#  6   odometer      42028 non-null  float64
#  7   transmission  51525 non-null  object
#  8   type          51525 non-null  object
#  9   paint_color   42258 non-null  object
#  10  is_4wd        25572 non-null  float64
#  11  date_posted   51525 non-null  object
#  12  days_listed   51525 non-null  int64
# dtypes: float64(4), int64(2), object(7)
# memory usage: 5.1+ MB

# %% [markdown]
# ## __checking the price column__

# %% [markdown]
# <div class="alert alert-info" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Student's comment</h2>
#
# <strong>here too i will use the same method like before:
#     <ol>
#         <li>i will replace all non logical values with nulls.</li>
#         <li>i will replace all nulls (old and new) based on features like model year, model etc.</li>
#     <li>because we need the "model year" values to do this, and there are a lot of nulls in this column, we will wait with the second stage. until we fill all the missing values in "model year".</li>
#     </ol>
#     </strong>
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Reviewer's comment. V.2.</b> <a class="tocSkip"></a>
#
# Thank you for this comment!
#
# </div>

# %%
fig,axes = plt.subplots(nrows=1, ncols=2,figsize=(11,5));
axes[0].hist(df['price'],bins=200);
axes[0].set_xlim(0,80000)
axes[0].set_xlabel('price');
axes[0].set_ylabel('count');
axes[0].set_title('price histogram');
axes[1].set_title("price boxplot")
df.boxplot("price");

# %%
fig,axes = plt.subplots(nrows=1, ncols=1,figsize=(8,5));
axes.hist(df['price'],bins=200);
axes.set_xlim(0,80000)
axes.set_xlabel('price');
axes.set_ylabel('count');
axes.set_title('price histogram');

# %%
df.query("price<100")["price"].value_counts()
# Out:
# 1     798
# 69     34
# 85      4
# 12      3
# 15      3
# 39      3
# 35      2
# 80      2
# 25      2
# 6       1
# 5       1
# 65      1
# 36      1
# 28      1
# 32      1
# 9       1
# 3       1
# 20      1
# 11      1
# 10      1
# 24      1
# Name: price, dtype: int64

# %%
len(df.query("price<100"))
# Out:
# 863

# %% [markdown]
# #### we see that there are like 863 car beyond 100 where 798 from them are only 1 !
# #### i will replace all of them with null, and fill them after this based on properties.

# %%
df["price"] = df["price"].apply(lambda p: p if p>100 else np.nan)

# %%
len(df.query("price<100"))
# Out:
# 0

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Reviewer's comment</b> <a class="tocSkip"></a>
#
# Yes, it is possible!
#
# </div>

# %% [markdown]
# #### lets look on the highests prices:

# %%
df.query("price>50000")
# Out:
#           price  model_year                       model  condition  cylinders  \
# 188     52000.0      2008.0        ford f350 super duty       good        8.0
# 1309   189000.0      2014.0                  ford f-150       good        6.0
# 1326    79900.0         NaN                   ford f350   like new        8.0
# 1347    59995.0         NaN                    ram 2500   like new        6.0
# 1523    50948.0      2017.0  chevrolet silverado 2500hd  excellent        8.0
# ...         ...         ...                         ...        ...        ...
# 50108   68000.0      2017.0                  ford f-150  excellent        8.0
# 50113   66000.0      2018.0                  ford f-250        new        8.0
# 50664   76995.0      2018.0           cadillac escalade  excellent        8.0
# 50671   58995.0      2017.0          chevrolet corvette  excellent        8.0
# 50994   57000.0      2012.0         dodge grand caravan       good        6.0
#
# ...

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Reviewer's comment</b> <a class="tocSkip"></a>
#
# I agree with you! Very good condition=high price!
# </div>

# %% [markdown]
# #### i think that these values are logical, so i wouldn't touch them.
# #### but lets check the extrimly high values:

# %%
df.query("price>150000")
# Out:
#           price  model_year              model  condition  cylinders    fuel  \
# 1309   189000.0      2014.0         ford f-150       good        6.0     gas
# 1668   189000.0      2014.0         ford f-150       good        6.0     gas
# 11359  300000.0      2015.0           ram 2500  excellent        NaN  diesel
# 12504  375000.0      1999.0    nissan frontier       good        6.0     gas
# 27375  189000.0      2014.0         ford f-150       good        6.0     gas
# 30634  189000.0      2014.0         ford f-150       good        6.0     gas
# 33434  189000.0      2014.0         ford f-150       good        6.0     gas
# 34206  175000.0      2004.0  gmc sierra 2500hd       good        8.0  diesel
# 34389  189000.0      2014.0         ford f-150       good        6.0     gas
#
#        odometer transmission    type paint_color  is_4wd date_posted  \
# 1309   151248.0    automatic   truck       black     NaN  2019-03-02
# ...

# %% [markdown]
# ### lets check if such prices to these models are normal:

# %%
models = df.query("price>150000")["model"].unique()
df[df["model"].isin(models)].boxplot(column="price",by="model",figsize=(10,5));

# %% [markdown]
# #### i think that there is a big difference, and these are truely outliers!
# #### we will replace them with null:

# %%
df["price"] = df["price"].apply(lambda p: p if p<150000 else np.nan)

# %% [markdown]
# check that we replaced all the prices above 150,000 with null:

# %%
len(df.query("price>150000"))
# Out:
# 0

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Reviewer's comment</b> <a class="tocSkip"></a>
#
# ~It is not good idea to replace to 0. Yes, it is outliries. But in this project we need them. :)~
#
# ~Please, return outliries. :)~
# </div>

# %% [markdown]
# <div class="alert alert-info" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Student's comment</h2><h4>i didn't replaced them with 0, i replaced them with nulls! you could see.<h4><h4>later after i will fill the "model year" column, i will replace all the nulls based on features. i'm sory about that i didn't clarified myself before</h4><h4> the 0 above is checking that after replacing there are no more prices above 150000</h4>
#        </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Reviewer's comment. V.2.</b> <a class="tocSkip"></a>
#
# Yep! It is very great idea to do such thing!
#
# </div>

# %% [markdown]
# ### __we want now to fill all the null values in the "price" column based on our data. but we have a problem - there are many missing values in the "model_year" column.
# ### so we will fill all these missing values later, only after we fill the missing values in the "model year" column

# %% [markdown]
# ## __lowercase data__

# %% [markdown]
# #### I dont see here case sensitive data, so i will lowercase the data:

# %%
df = df.applymap(lambda s:s.lower() if type(s) == str else s)

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Reviewer's comment</b> <a class="tocSkip"></a>
#
# You can use:
#
#     df.columns = df.columns.str.lower()
# </div>

# %% [markdown]
# ### after i lowercase the table, let's check duplicated rows:

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Reviewer's comment</b> <a class="tocSkip"></a>
#
# Great!</div>

# %% [markdown]
# ### lets explore some columns:

# %% [markdown]
# ## __model_year__

# %% [markdown]
# <div class="alert alert-info" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Student's comment</h2><strong>
#     <ol>
#         <li>first i will treat this column - i will check missing values, outliers, etc.</li>
#          <li>than after i have data, i will pay my debts from before - based on this "model year" column and other feartues i will replace all the null values on the "price" and "odometer" columns.</li>
#     </ol>
#     </strong>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Reviewer's comment. V.2.</b> <a class="tocSkip"></a>
#
# Well done! Comments are excellent!
#
# </div>

# %%
df["model_year"].value_counts()
# Out:
# 2013.0    3549
# 2012.0    3468
# 2014.0    3448
# 2011.0    3375
# 2015.0    3323
#           ...
# 1948.0       1
# 1961.0       1
# 1936.0       1
# 1949.0       1
# 1955.0       1
# Name: model_year, Length: 68, dtype: int64

# %%
df["model_year"].nunique()
# Out:
# 68

# %%
fig,axes = plt.subplots(nrows=1, ncols=2,figsize=(11,5));
axes[0].hist(df['model_year'],bins=200);
axes[0].set_xlim(1900,2020)
axes[0].set_xlabel('model_year');
axes[0].set_ylabel('count');
axes[0].set_title('model_year histogram');
axes[1].set_title("model_year boxplot")
df.boxplot("model_year");

# %% [markdown]
# #### lets see the extreme outliers:

# %%
df.query("model_year<1960")
# Out:
#          price  model_year               model  condition  cylinders fuel  \
# 10018  23900.0      1955.0           ford f250  excellent        6.0  gas
# 14752  15000.0      1954.0          ford f-150  excellent        NaN  gas
# 22595  21000.0      1948.0    chevrolet impala   like new        8.0  gas
# 33906  12995.0      1908.0           gmc yukon       good        8.0  gas
# 33907  12995.0      1908.0   cadillac escalade  excellent        8.0  gas
# 34713   5000.0      1936.0          ford f-150  excellent        6.0  gas
# 36582  44900.0      1949.0  chevrolet suburban       good        NaN  gas
# 39580  35000.0      1958.0    chevrolet impala  excellent        8.0  gas
# 45694  18000.0      1929.0          ford f-150       good        8.0  gas
# 48414  37900.0      1958.0    chevrolet impala       good        8.0  gas
#
#        odometer transmission    type paint_color  is_4wd date_posted  \
# 10018   47180.0       manual   truck        blue     NaN  2018-12-22
# ...

# %% [markdown]
# #### lets check if these values are logical, we will see if these models have more old cars:

# %%
models = df.query("model_year<1960")["model"].unique()
df[df["model"].isin(models)].boxplot(column="model_year",by="model",figsize=(10,5));

# %% [markdown]
# #### we see here only two extreme outliers - gmc yukon, cadilac escalade. we will remove only them.

# %%
df["model_year"] = df["model_year"].apply(lambda x: x if x>=1920 else np.nan)

# %% [markdown]
# #### lets check the missing values in this column:

# %%
df[df["model_year"].isnull()].head()
# Out:
#       price  model_year            model  condition  cylinders fuel  odometer  \
# 1   25500.0         NaN       ford f-150       good        6.0  gas   88705.0
# 20   6990.0         NaN  chevrolet tahoe  excellent        8.0  gas  147485.0
# 65  12800.0         NaN       ford f-150  excellent        6.0  gas  108500.0
# 69   7800.0         NaN       ford f-150   like new        8.0  gas   97510.0
# 72   3650.0         NaN   subaru impreza  excellent        NaN  gas   74000.0
#
#    transmission    type paint_color  is_4wd date_posted  days_listed
# 1     automatic  pickup       white     1.0  2018-10-19           50
# 20    automatic     suv      silver     1.0  2018-08-05           28
# 65    automatic  pickup       white     NaN  2018-09-23           15
# 69    automatic   truck       white     1.0  2019-02-20           39
# 72    automatic   sedan        blue     1.0  2018-08-07           60

# %% [markdown]
# * we will fill the missing values based on the model names, transmission and type (we haven't missing values in all these columns!)
# * for example - if we have some ford f-150, automatic in the dataset, we could find the average year and put it in the model year column where we haven't data.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Reviewer's comment</b> <a class="tocSkip"></a>
#
# Veru good ideas!
# </div>

# %%
df['model_year'] = df['model_year'].fillna(df.groupby(['model','transmission','type'])['model_year'].transform('mean'))

# %% [markdown]
# let's check how many null values we have now ?

# %%
df['model_year'].isnull().sum()
# Out:
# 19

# %% [markdown]
# we have big enough dataset (over 54,000 rows), so we will drop these rows:

# %%
df.dropna(subset=['model_year'], how='all', inplace=True)

# %%
df['model_year'].isnull().sum()
# Out:
# 0

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Reviewer's comment</b> <a class="tocSkip"></a>
#
# Yes, herewe can delete 19 values.</div>

# %% [markdown]
# #### we will change the type to int:

# %%
df["model_year"] = df["model_year"].astype('int')

# %%
df["model_year"].dtype
# Out:
# dtype('int64')

# %%
fig,axes = plt.subplots(nrows=1, ncols=2,figsize=(11,5));
axes[0].hist(df['model_year'],bins=200);
axes[0].set_xlim(1960,2020)
axes[0].set_xlabel('model_year');
axes[0].set_ylabel('count');
axes[0].set_title('model_year histogram');
axes[1].set_title("model_year boxplot")
df.boxplot("model_year");

# %% [markdown]
# #### we dont see the extreme outliers anymore, seems better!

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Reviewer's comment</b> <a class="tocSkip"></a>
#
# Well done!</div>

# %% [markdown]
# #### __now, lets fill all the null values in the odometer and price columns, like we said before. we will do it based of features we have:__

# %%
df["odometer"].isnull().sum()
# Out:
# 9496

# %%
df['odometer'] = df['odometer'].fillna(round(df.groupby(['model_year','fuel','model'])['odometer'].transform('median'),0))

# %% [markdown]
# <div class="alert alert-info" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Student's comment</h2>
# <h3>I have added "round"</h3>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Reviewer's comment. V.2.</b> <a class="tocSkip"></a>
#
# It is strange, that round will not help with 0. I will check this moment and answer to you in your next(last. I knew you are the best!) iteration.
#
# I returned drop.
#
# </div>

# %% [markdown]
# <div class="alert alert-info" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Student's comment</h2>
# :)
# </div>

# %%
fig,axes = plt.subplots(nrows=1, ncols=2,figsize=(12,5));
axes[0].hist(df['odometer'],bins=200);
#axes[0].set_xlim(0,500000)
axes[0].set_xlabel('odometer');
axes[0].set_ylabel('count');
axes[0].set_title('odometer histogram');
df.boxplot("odometer")
# Out:
# <AxesSubplot:>

# %%
df["odometer"].isnull().sum()
# Out:
# 600

# %% [markdown]
# #### we will drop these rows:

# %%
#df.dropna(subset=['odometer'], how='all', inplace=True)

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Reviewer's comment</b> <a class="tocSkip"></a>
#
# ~I write about odometr in previous cells. So, we do not need to drop values here because we filling missing numbers previously.~
#
# ~Also, please, remeber about round:~
#
#     df['odometer'] = df['odometer'].fillna(round(df.groupby(['model_year','fuel','model'])['odometer'].transform('median'),0))~
#
# ~It help us to escape nulls.~
# </div>

# %% [markdown]
# <div class="alert alert-info" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Student's comment</h2>
# <strong>hi olga, please see 5 cells above, i did exacly what you said now ! <br>
#     after i did it, i checked again for missing values, and i see that there are still some.<br>
#     there were 9497 missing values and after this filling remain 1154.<br>
#     i have dropped just this rows, which i couldn't fill based on features.<br>
#     there are above 50,000 rows in our db, it's like only 2% from the db, so it should be o.k.<br>
#     but because you asked i didn't droped, and now i need "error="ignore" in the convertion to int.
#     </strong>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Reviewer's comment. V.2.</b> <a class="tocSkip"></a>
#
# Yep! It is very great idea to do such thing!
#
# </div>

# %% [markdown]
# #### __lets convert odometer to int:__

# %%
df["odometer"] = df["odometer"].astype('int',errors="ignore")

# %% [markdown]
# #### __now we will do the same with the price column:__

# %%
df['price'] = df['price'].fillna(round(df.groupby(['model','model_year','transmission',"condition"])['price'].transform('median'),0))

# %%
fig,axes = plt.subplots(nrows=1, ncols=2,figsize=(11,5));
axes[0].hist(df['price'],bins=200);
axes[0].set_xlim(0,80000)
axes[0].set_xlabel('price');
axes[0].set_ylabel('count');
axes[0].set_title('price histogram');
axes[1].set_title("price boxplot")
df.boxplot("price");

# %%
df["price"].isnull().sum()
# Out:
# 275

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Reviewer's comment</b> <a class="tocSkip"></a>
#
# ~Please, use round here. And we do not to delete rows after that.~
# </div>

# %% [markdown]
# <div class="alert alert-info" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Student's comment</h2>
# <strong>
#     if i not drop them, i couldnt convert the column to int - i would get an error.<br>
#     and we have above 50,000 rows on our db, the null values are only 0.4% <br>
#     but because you asked i didnt droped and added errors="ignore" in the conversion.
#     </strong>
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Reviewer's comment. V.2.</b> <a class="tocSkip"></a>
#
# It is strange, that round will not help with 0. I will check this moment and answer to you in your next(last. I knew you are the best!) iteration.
#
#
# </div>

# %%
#df.dropna(subset=['price'], how='all', inplace=True)

# %%
df["price"] = df["price"].astype('int', errors="ignore")

# %% [markdown]
# ## __model__

# %%
df["model"].value_counts()
# Out:
# ford f-150                           2796
# chevrolet silverado 1500             2171
# ram 1500                             1748
# chevrolet silverado                  1270
# jeep wrangler                        1119
#                                      ...
# ford f-250 super duty                 241
# kia sorento                           236
# acura tl                              236
# nissan murano                         235
# mercedes-benz benze sprinter 2500      41
# Name: model, Length: 100, dtype: int64

# %%
df["model"].nunique()
# Out:
# 100

# %% [markdown]
# * we see a 100 different models
# * I think it would be good to add a "manufactor" column, we will substract the manufactor name from this column

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Reviewer's comment</b> <a class="tocSkip"></a>
#
# Great idea!
# </div>

# %%
df["manufactor"] = df["model"].apply(lambda x: x.split()[0])

# %%
df.head()
# Out:
#      price  model_year           model  condition  cylinders fuel  odometer  \
# 0   9400.0        2011          bmw x5       good        6.0  gas  145000.0
# 1  25500.0        2009      ford f-150       good        6.0  gas   88705.0
# 2   5500.0        2013  hyundai sonata   like new        4.0  gas  110000.0
# 3   1500.0        2003      ford f-150       fair        8.0  gas  181000.0
# 4  14900.0        2017    chrysler 200  excellent        4.0  gas       NaN
#
#   transmission    type paint_color  is_4wd date_posted  days_listed manufactor
# 0    automatic     suv         NaN     1.0  2018-06-23           19        bmw
# 1    automatic  pickup       white     1.0  2018-10-19           50       ford
# 2    automatic   sedan         red     NaN  2019-02-07           79    hyundai
# 3    automatic  pickup         NaN     NaN  2019-03-22            9       ford
# 4    automatic   sedan       black     NaN  2019-04-02           28   chrysler

# %%
manufactors = df["manufactor"].value_counts()
manufactors
# Out:
# ford             12668
# chevrolet        10606
# toyota            5443
# honda             3484
# ram               3314
# jeep              3278
# nissan            3208
# gmc               2378
# subaru            1272
# dodge             1255
# hyundai           1172
# volkswagen         868
# chrysler           838
# kia                585
# cadillac           322
# buick              271
# bmw                267
# acura              236
# mercedes-benz       41
# Name: manufactor, dtype: int64

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Reviewer's comment</b> <a class="tocSkip"></a>
#
# Excellent! Now we havemore information about our cars!
# </div>
#
# <div class="alert alert-block alert-warning">
# <b>Reviewer's comment</b> <a class="tocSkip"></a>
#
# It would be informative to add a conclusion for this table. :)
# </div>

# %% [markdown]
# <div class="alert alert-info" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Student's comment</h2>
# <strong>
#    you right! i have added a bar plot.
#     </strong>
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Reviewer's comment. V.2.</b> <a class="tocSkip"></a>
#
# Barplot is great! It is very helpful to visually our data.
#
# </div>

# %% [markdown]
# ### 10 big manufactors in the data set:

# %%
manufactors[:10].plot(kind="bar",figsize=(10,7));
plt.xlabel("manufactors");
plt.ylabel("count");

# %% [markdown]
# ## __condition:__

# %%
df["condition"].value_counts()
# Out:
# excellent    24766
# good         20136
# like new      4741
# fair          1605
# new            143
# salvage        115
# Name: condition, dtype: int64

# %% [markdown]
# * in this column we have been asked:
# "In the condition column, replace string values with a numeric scale:
#     * new = 5
#     * like new = 4
#     * excellent = 3
#     * good = 2
#     * fair = 1
#     * salvage = 0
# * we will do it now.

# %%
def replace_condition(x):
    return ["salvage","fair","good","excellent","like new","new"].index(x)
        
df.loc[:,"condition"]= df["condition"].apply(replace_condition)

# %%
df["condition"].value_counts()
# Out:
# 3    24766
# 2    20136
# 4     4741
# 1     1605
# 5      143
# 0      115
# Name: condition, dtype: int64

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Reviewer's comment</b> <a class="tocSkip"></a>
#
# Great! </div>

# %% [markdown]
# * the values are equal, so we didn't do a mistake.

# %%
# it's truely a histogram , even i did it with bar plot:
df["condition"].value_counts().plot(kind="bar",figsize=(10,5));
plt.xlabel("condition (5 new, 0 salvage)");
plt.ylabel("count");

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Reviewer's comment</b> <a class="tocSkip"></a>
#
# ~Something wrong, please, check you graph.~
# </div>

# %% [markdown]
# <div class="alert alert-info" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Student's comment</h2>
# <strong>
#    corrected
#     </strong>
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Reviewer's comment. V.2.</b> <a class="tocSkip"></a>
#
# Great! 3 Condition is a big value! And 5 and 0 arevery close.
#
# </div>

# %% [markdown]
# #### we could see that the most of the vehicles are in the middle (2,3).

# %% [markdown]
# #### __cylinders:__

# %%
df["cylinders"].value_counts().sort_values(ascending=False)
# Out:
# 8.0     15836
# 6.0     15695
# 4.0     13859
# 10.0      549
# 5.0       272
# 3.0        34
# 12.0        2
# Name: cylinders, dtype: int64

# %% [markdown]
# here too, let's fill the missing values based on other properties like we did in the "model year" column:

# %%
df['cylinders'] = df['cylinders'].fillna(round(df.groupby(['model','model_year'])['cylinders'].transform('median'),0))

# %%
df["cylinders"].isnull().sum()
# Out:
# 26

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Reviewer's comment</b> <a class="tocSkip"></a>
#
# ~The same for round. :)~
# </div>

# %% [markdown]
# <div class="alert alert-info" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Student's comment</h2>
# <strong>
#    corrected
#     </strong>
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Reviewer's comment. V.2.</b> <a class="tocSkip"></a>
#
# It is strange, that round will not help with 0. I will check this moment and answer to you in your next(last. I knew you are the best!) iteration.
#
#
# </div>

# %% [markdown]
# #### we will drop the rows with these missing values:

# %%
df.dropna(subset=['cylinders'], how='all', inplace=True)

# %%
df["cylinders"].isnull().sum()
# Out:
# 0

# %% [markdown]
# #### we will change the type to int:

# %%
df["cylinders"] = df["cylinders"].astype('int')

# %%
df["cylinders"].dtype
# Out:
# dtype('int64')

# %%
# it's truely a histogram , even i did it with bar plot:
df["cylinders"].value_counts().plot(kind="bar",figsize=(10,5));
plt.xlabel("cylinders");
plt.ylabel("count");

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Reviewer's comment</b> <a class="tocSkip"></a>
#
# ~omething wrong too, please, check. :)~
# </div>

# %% [markdown]
# <div class="alert alert-info" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Student's comment</h2>
# <strong>
#    corrected
#     </strong>
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Reviewer's comment. V.2.</b> <a class="tocSkip"></a>
#
# I see cylindres! Very good! :)
#
# </div>

# %% [markdown]
# #### we could see that the absolute majority of the vehicles are 4,6,8 cylinders.

# %% [markdown]
# #### __fuel__:

# %%
df["fuel"].value_counts()
# Out:
# gas         47249
# diesel       3709
# hybrid        409
# other         107
# electric        6
# Name: fuel, dtype: int64

# %% [markdown]
# #### __transmission__

# %%
df["transmission"].value_counts()
# Out:
# automatic    46874
# manual        2817
# other         1789
# Name: transmission, dtype: int64

# %% [markdown]
# #### __type__

# %%
df["type"].value_counts()
# Out:
# suv            12398
# truck          12345
# sedan          12146
# pickup          6980
# coupe           2297
# wagon           1538
# mini-van        1161
# hatchback       1047
# van              631
# convertible      445
# other            254
# offroad          214
# bus               24
# Name: type, dtype: int64

# %% [markdown]
# #### __paint_color:__

# %%
df["paint_color"].value_counts()
# Out:
# white     10023
# black      7685
# silver     6244
# grey       5033
# blue       4470
# red        4413
# green      1393
# brown      1221
# custom     1151
# yellow      255
# orange      229
# purple      102
# Name: paint_color, dtype: int64

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Reviewer's comment</b> <a class="tocSkip"></a>
#
# ~We have missing values in this column. Let's filling them by "no info". :)~
# </div>

# %% [markdown]
# <div class="alert alert-info" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Student's comment</h2>
# <strong>
#    corrected
#     </strong>
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Reviewer's comment. V.2.</b> <a class="tocSkip"></a>
#
# Excellent!
#
# </div>

# %%
df['paint_color'] = df['paint_color'].fillna("no info")

# %%
df['paint_color'].value_counts()
# Out:
# white      10023
# no info     9261
# black       7685
# silver      6244
# grey        5033
# blue        4470
# red         4413
# green       1393
# brown       1221
# custom      1151
# yellow       255
# orange       229
# purple       102
# Name: paint_color, dtype: int64

# %% [markdown]
# #### __is_4wd__

# %%
df["is_4wd"].value_counts()
# Out:
# 1.0    25555
# Name: is_4wd, dtype: int64

# %% [markdown]
# * it's very clear that 1 is True here, and the null values are false.
# * so we will replace the values now:

# %%
df["is_4wd"] = df["is_4wd"].apply(lambda x: True if x==1 else False)

# %%
df["is_4wd"].value_counts()
# Out:
# False    25925
# True     25555
# Name: is_4wd, dtype: int64

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Reviewer's comment</b> <a class="tocSkip"></a>
#
# Great idea!</div>

# %% [markdown]
# #### __date_posted__

# %%
df["date_posted"].value_counts()
# Out:
# 2019-03-17    186
# 2019-01-05    183
# 2018-09-20    178
# 2019-03-11    175
# 2018-10-09    174
#              ...
# 2018-06-18    119
# 2018-07-04    118
# 2019-01-11    117
# 2018-06-08    117
# 2019-01-04    116
# Name: date_posted, Length: 354, dtype: int64

# %%
df["date_posted"] = pd.to_datetime(df["date_posted"].astype(str),format='%Y-%m-%d')

# %% [markdown]
# ### we would convert our "oulier dataframe" too:

# %%
df_outliers["date_posted"] = pd.to_datetime(df_outliers["date_posted"].astype(str),format='%Y-%m-%d')

# %%
df["date_posted"].head()
# Out:
# 0   2018-06-23
# 1   2018-10-19
# 2   2019-02-07
# 3   2019-03-22
# 4   2019-04-02
# Name: date_posted, dtype: datetime64[ns]

# %% [markdown]
# * in this column we have been asked too:
#     * Calculate and add to the table the following:
#         Day of the week, month, and year the ad was placed
#         The vehicle's age (in years) when the ad was placed
#         The vehicle's average mileage per year
# we will do it now:

# %%
df["date_posted"]
# Out:
# 0       2018-06-23
# 1       2018-10-19
# 2       2019-02-07
# 3       2019-03-22
# 4       2019-04-02
#            ...
# 51520   2018-10-03
# 51521   2018-11-14
# 51522   2018-11-15
# 51523   2018-07-02
# 51524   2018-06-05
# Name: date_posted, Length: 51480, dtype: datetime64[ns]

# %%
df['dayofweek_ad_placed'] = df['date_posted'].dt.weekday

# %% [markdown]
# * reminder : this method returns a number which represents the day of the week (Monday=0, Sunday=6).

# %%
df['month_ad_placed'] = df['date_posted'].dt.month

# %%
df['year_ad_placed'] = df['date_posted'].dt.year

# %%
df["vehicle_age"] = df["year_ad_placed"] - df["model_year"]+1

# %% [markdown]
# ### we would add two columns to our "outliers dataframe" too:

# %%
df_outliers['year_ad_placed'] = df_outliers['date_posted'].dt.year

# %%
df_outliers["vehicle_age"] = df_outliers["year_ad_placed"] - df_outliers["model_year"]+1

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Reviewer's comment</b> <a class="tocSkip"></a>
#
# We can use this construction here:
#
#     df['dayofweek_ad_placed'] = df['date_posted'].dt.weekday
#     df['month_ad_placed'] = df['date_posted'].dt.month
#     df['year_ad_placed'] = df['date_posted'].dt.year
#
# </div>
#
#
# <div class="alert alert-block alert-danger">
# <b>Reviewer's comment</b> <a class="tocSkip"></a>
#
# ~Unforchantly for vehicle_age we need +1 in tail. Otherwise, we will have cars with 0 mileage.Please, add it.~
# </div>

# %% [markdown]
# <div class="alert alert-info" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Student's comment</h2>
# <strong>
#    corrected both!
#     </strong>
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Reviewer's comment. V.2.</b> <a class="tocSkip"></a>
#
# Now we have right values in a year! Great!
#
# </div>

# %%
df["mileage_per_year"]= np.round(df["odometer"]/df["vehicle_age"],0)

# %%
df.head()
# Out:
#      price  model_year           model  condition  cylinders fuel  odometer  \
# 0   9400.0        2011          bmw x5          2          6  gas  145000.0
# 1  25500.0        2009      ford f-150          2          6  gas   88705.0
# 2   5500.0        2013  hyundai sonata          4          4  gas  110000.0
# 3   1500.0        2003      ford f-150          1          8  gas  181000.0
# 4  14900.0        2017    chrysler 200          3          4  gas       NaN
#
#   transmission    type paint_color  is_4wd date_posted  days_listed  \
# 0    automatic     suv     no info    True  2018-06-23           19
# 1    automatic  pickup       white    True  2018-10-19           50
# 2    automatic   sedan         red   False  2019-02-07           79
# 3    automatic  pickup     no info   False  2019-03-22            9
# 4    automatic   sedan       black   False  2019-04-02           28
#
#   manufactor  dayofweek_ad_placed  month_ad_placed  year_ad_placed  \
# ...

# %% [markdown]
# ### __vehicle_age__

# %%
fig,axes = plt.subplots(nrows=1, ncols=2,figsize=(11,5));
axes[0].hist(df['vehicle_age'],bins=200);
axes[0].set_xlim(0,60)
axes[0].set_xlabel('vehicle age');
axes[0].set_ylabel('count');
axes[0].set_title('vehicle age histogram');
axes[1].set_title("vehicle age boxplot")
df.boxplot("vehicle_age");

# %% [markdown]
# #### we already did the hard work on "model year" column, so i think these values are o.k.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Reviewer's comment</b> <a class="tocSkip"></a>
#
# Veru good histograms! And we have 2 for more detailed information!</div>

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Reviewer's comment</b> <a class="tocSkip"></a>
#
#
# ~Before days_listed we need to do:~
#
# ~- Study the following parameters: price, vehicle's age when the ad was placed, mileage, number of cylinders, and condition.~     ~- Plot histograms for each of these parameters.~
# ~- Study how outliers affect the form and readability of the histograms.~
# ~- Determine the upper limits of outliers, remove the outliers and store them in a separate DataFrame, and continue your work with the filtered data.~
# ~- Use the filtered data to plot new histograms. Compare them with the earlier histograms (the ones that included outliers).~
# ~- Draw conclusions for each histogram.~
#
# ~Please, add this steps. :)~
#
# </div>

# %% [markdown]
# <div class="alert alert-info" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Student's comment</h2>
# <strong>
# <p>I'm not sure i understood what you call here "outliers".</p>
#     <p>I see outliers as falsy data, falsy values. </p>
#     <p>so even extreme values which could be real truth values, are not outliers as i understand "outliers".</p>
#     <p>I removed before just the values which i saw as unlogical ones, and i am doing now the same</p>
#     <p>the same thing with "condition" and "cylinders" columns, there are there some extremly low values, but they could be true values! there are cars with 10 or 3 cylinders, even there are few</p>
#     <p>If you want that i would remove any extreme value, i will do it</p>
#     </strong>
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Reviewer's comment. V.2.</b> <a class="tocSkip"></a>
#
# This project implied another structure.
#
# - lite version with filling missing values
# - graphs for price, vehicle's age when the ad was placed, mileage, number of cylinders, and condition.
# - remove the outliers
# - plot new histograms for price, vehicle's age when the ad was placed, mileage, number of cylinders, and condition.
# - study days listed
# - Select the two types with the greatest number of ads.
# - plot box-and-whisker charts for ransmission type and color(note that it must have at least 50 ads)
# - create scatterplots for age, mileage, condition.
#
#
# Your structure was different. It would be better to follow the plan. At work, the manager may not see that your work done.
#
# So, you choose the perfect hard way to filling missing numbers. You compare 4 steps in one. Ok. :)
#
# And I see additional graphs in next cells. Thank you for adding them!
#
# <span class="text-danger">Could you add here a graph for mileage_per_year? And little conclusion for it. If you found outliries, please, figure it out. :)</span>
#
#
# </div>

# %% [markdown]
# <div class="alert alert-info" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Student's comment</h2>
# <strong>
# thank you, I took to my attention next time to be more accurate with the project structure...
# </strong>
# </div>

# %% [markdown]
# ## mileage per year

# %%
fig,axes = plt.subplots(nrows=1, ncols=2,figsize=(14,5));
axes[0].hist(df['mileage_per_year'],bins=200);
# axes[0].set_xlim(0,60)
axes[0].set_xlabel('mileage_per_year');
axes[0].set_ylabel('count');
axes[0].set_title('mileage_per_year histogram');
axes[1].set_title("mileage_per_year boxplot")
df.boxplot("mileage_per_year");

# %% [markdown]
# ### i created a boxplot too, because we could see outliers better in box plot.
# ### we see that the main outliers are above 40,000
# ### before we remove outliers, we will take a copy of the column:

# %%
milage_per_year_copy = df["mileage_per_year"].copy()

# %%
df.query("mileage_per_year>40000").loc[:,["mileage_per_year","type","condition","model"]]
# Out:
#        mileage_per_year      type  condition                        model
# 7757            93283.0       suv          3                 nissan rogue
# 10471           51921.0     truck          3                ford f-250 sd
# 15588           95000.0     sedan          3                nissan maxima
# 15919           59258.0       suv          2            cadillac escalade
# 30111           51494.0     truck          2  nissan frontier crew cab sv
# 32946           43333.0  mini-van          1      chrysler town & country
# 39064           98429.0     sedan          3                nissan sentra

# %% [markdown]
# ### i think that the values could be logical for trucks, but of course not to sedan.
# ### i will remove all the values above 60,000:

# %%
df = df[df["mileage_per_year"]<60000]

# %%
df.query("mileage_per_year>40000").loc[:,["mileage_per_year","type","condition","model"]]
# Out:
#        mileage_per_year      type  condition                        model
# 10471           51921.0     truck          3                ford f-250 sd
# 15919           59258.0       suv          2            cadillac escalade
# 30111           51494.0     truck          2  nissan frontier crew cab sv
# 32946           43333.0  mini-van          1      chrysler town & country

# %% [markdown]
# ### i think it's extreme but reasonable values for this types.

# %% [markdown]
# ### lets check the low limit:

# %%
df[df["mileage_per_year"]<1000].sample(10)
# Out:
#          price  model_year                model  condition  cylinders fuel  \
# 4563   18000.0        1980   chevrolet corvette          3          8  gas
# 12429   5600.0        1989           ford f-250          2          6  gas
# 12108   9947.0        2008      chevrolet tahoe          3          8  gas
# 4708   10500.0        1974   chevrolet corvette          2          8  gas
# 41164  14000.0        1973         ford mustang          3          8  gas
# 40840   3000.0        1994  chevrolet silverado          2          8  gas
# 32212  24500.0        2011             ram 3500          3          6  gas
# 39142  35000.0        2009           ford f-150          4          6  gas
# 2941    8200.0        2011       subaru impreza          3          4  gas
# 31458  19900.0        2007     chevrolet camaro          3          4  gas
#
#        odometer transmission         type paint_color  is_4wd date_posted  \
# ...

# %% [markdown]
# ### first hand from a doctor :) , and more seriously, i think that some of this values are not reasonable. we will do the same method like before - we would place null in this values (and in the odometer values too) in this rows, and fill them by other features.
#
# ### just first lets check how much vehicles are with this low values:

# %%
(df["mileage_per_year"]<1000).sum()
# Out:
# 138

# %%
df["odometer"] = df.apply(lambda r: r["odometer"] if r["mileage_per_year"]>1000 else np.nan,axis=1)

# %%
df["mileage_per_year"] = df.apply(lambda r: r["mileage_per_year"] if r["mileage_per_year"]>1000 else np.nan,axis=1)

# %% [markdown]
# ### checking:

# %%
(df["mileage_per_year"]<1000).sum()
# Out:
# 0

# %% [markdown]
# ### fill the nulls in odometer column again:

# %%
df['odometer'] = df['odometer'].fillna(df.groupby(['model_year','model','type'])['odometer'].transform('median'))

# %%
df["mileage_per_year"] = np.round(df["odometer"]/df["vehicle_age"],0)

# %% [markdown]
# #### how much values we didn't fill ?

# %%
df["odometer"].isnull().sum()
# Out:
# 34

# %% [markdown]
# ### it's a small amount, we will drop this rows:

# %%
df.dropna(subset=['odometer'], how='all', inplace=True)

# %%
df["odometer"].isnull().sum()
# Out:
# 0

# %% [markdown]
# ### now we could compare the two histograms - with and without outliers:

# %% [markdown]
# #### (we will use the copy of this column we did before)

# %%
fig,axes = plt.subplots(nrows=1, ncols=2,figsize=(14,5));
axes[0].hist(df['mileage_per_year'],bins=200);
axes[0].set_xlim(0,50000)
axes[0].set_xlabel('mileage_per_year');
axes[0].set_ylabel('count');
axes[0].set_title('mileage_per_year histogram without outliers');
axes[1].hist(milage_per_year_copy,bins=200);
axes[1].set_xlim(0,50000)
axes[1].set_xlabel('mileage_per_year');
axes[1].set_ylabel('count');
axes[1].set_title('mileage_per_year histogram with outliers');

# %% [markdown]
# ### both are right skewed / close to normal. where we remove the outliers, the histogram begins from 1000 miles.

# %%
fig,axes = plt.subplots(nrows=1, ncols=2,figsize=(14,5));
axes[0].set_title('mileage_per_year boxplot without outliers');
sns.boxplot(df["mileage_per_year"],ax=axes[0],orient="v");
axes[0].set_ylim(0,100000)
axes[1].set_title('mileage_per_year boxplot with outliers');
sns.boxplot(milage_per_year_copy,ax=axes[1],orient="v");

# %% [markdown]
# ### here in boxplots we could see the differences more clearly.

# %% [markdown]
# ## Price

# %% [markdown]
# ### we already removed outliers from price:

# %%
fig,axes = plt.subplots(nrows=1, ncols=2,figsize=(11,5));
axes[0].hist(df['price'],bins=200);
axes[0].set_xlabel('price');
axes[0].set_ylabel('count');
axes[0].set_xlim(0,80000)
axes[0].set_title('price without outliers histogram');
axes[1].hist(df_outliers['price'],bins=200);
axes[1].set_xlabel('price');
axes[1].set_ylabel('count');
axes[1].set_xlim(0,80000)
axes[1].set_title('price with outliers histogram');

# %% [markdown]
# ### we could see that there are more little "pics" on the left, i think it because we filled the nulls values based on features.
# ### we could see there are less cars on the very small prices on the left histogram, because we changed it above.
# ### we could see that there is a pick around 9000 in the histograms. around it are the prices of the most cars.
# ### in general, we see here right skwed histograms, which is very logical to a variable like "price", the meaning is that after the pick there are less and less "high prices" cars.

# %% [markdown]
# ### lets check the numbers:

# %%
df["price"].describe()
# Out:
# count     50606.000000
# mean      12264.618010
# std        9462.449258
# min         105.000000
# 25%        5300.000000
# 50%        9499.000000
# 75%       16900.000000
# max      145000.000000
# Name: price, dtype: float64

# %%
df_outliers["price"].describe()
# Out:
# count     51525.000000
# mean      12132.464920
# std       10040.803015
# min           1.000000
# 25%        5000.000000
# 50%        9000.000000
# 75%       16839.000000
# max      375000.000000
# Name: price, dtype: float64

# %% [markdown]
# ### we could see that the max value is very different too, because we removed unlogical outliers above. it was unlogical price for these car model.

# %% [markdown]
# ## vehicle's age

# %% [markdown]
# #### here too we already removed outliers before , from the "model year" column.

# %%
fig,axes = plt.subplots(nrows=1, ncols=2,figsize=(11,5));
axes[0].hist(df['vehicle_age'],bins=200);
axes[0].set_xlabel('vehicle_age');
axes[0].set_ylabel('count');
axes[0].set_xlim(0,80)
axes[0].set_title('vehicle_age without outliers histogram');
axes[1].hist(df_outliers['vehicle_age'],bins=200);
axes[1].set_xlim(0,80)
axes[1].set_xlabel('vehicle_age');
axes[1].set_ylabel('count');
axes[1].set_title('vehicle_age with outliers histogram');

# %% [markdown]
# ### the right is a little wider, higher varience.
# ### here too they are right skewed, which is logical too for "age" variable (i think even a human age!).
# ### the meaning: as the age of the car rising, we see less and less cars.
# ### the pick is around 9 years.
# ### we see here a lot of "lines", not like the price, because it's descrete ordinary variable.

# %%
df["vehicle_age"].describe()
# Out:
# count    50853.000000
# mean         9.605471
# std          5.909241
# min          1.000000
# 25%          5.000000
# 50%          9.000000
# 75%         13.000000
# max         61.000000
# Name: vehicle_age, dtype: float64

# %%
df_outliers["vehicle_age"].describe()
# Out:
# count    47906.000000
# mean         9.556966
# std          6.295266
# min          1.000000
# 25%          5.000000
# 50%          8.000000
# 75%         13.000000
# max        111.000000
# Name: vehicle_age, dtype: float64

# %% [markdown]
# #### we could see difference in the "max" and 50% values.

# %% [markdown]
# ## odometer:

# %% [markdown]
# ### here too we already removed outliers and filled all nulls

# %%
fig,axes = plt.subplots(nrows=1, ncols=2,figsize=(11,5));
axes[0].hist(df['odometer'],bins=200);
axes[0].set_xlim(0,600000)
axes[0].set_xlabel('odometer');
axes[0].set_ylabel('count');
axes[0].set_title('odometer without outliers histogram');
axes[1].hist(df_outliers['odometer'],bins=200);
axes[1].set_xlim(0,600000)
axes[1].set_xlabel('odometer');
axes[1].set_ylabel('count');
axes[1].set_title('odometer with outliers histogram');

# %% [markdown]
# ### we see that in the left histogram there isn't a line in 0 value, because we removed all this values and replaced them based on features.
# ### the histograms are right skwed too, but more close to the normal distribution than the first two (age,price) . it's because there are
#     * few cars with very low odometer (new ones)
#     * few with very high (old ones)
#     * the majority are in the middle.

# %%
df["odometer"].describe()
# Out:
# count      50853.000000
# mean      117385.931302
# std        60916.991070
# min         1003.000000
# 25%        74000.000000
# 50%       115971.000000
# 75%       154029.000000
# max      1000000.000000
# Name: odometer, dtype: float64

# %%
df_outliers["odometer"].describe()
# Out:
# count     43633.000000
# mean     115553.461738
# std       65094.611341
# min           0.000000
# 25%       70000.000000
# 50%      113000.000000
# 75%      155000.000000
# max      990000.000000
# Name: odometer, dtype: float64

# %% [markdown]
# ### we could see differences in the std (the varience is bigger in the "outliers" dataframe).
# ### we could see differece in all the numeric parameters too.
# ### but we see here a very strange thing - the max in the "without outliers" is bigger than the max of the table with outliers !
# ### lets check why it happend:

# %%
# without outliers:
df[df["odometer"]==df["odometer"].max()]
# Out:
#          price  model_year             model  condition  cylinders fuel  \
# 28128  44900.0        1969  chevrolet camaro          2          8  gas
# 33007  17500.0        1960  chevrolet impala          3          8  gas
# 40089  20000.0        1960  chevrolet impala          3          8  gas
# 42749  69900.0        1969  chevrolet camaro          5          8  gas
#
#         odometer transmission         type paint_color  is_4wd date_posted  \
# 28128  1000000.0    automatic  convertible     no info   False  2018-10-26
# 33007  1000000.0    automatic        sedan       white   False  2019-02-01
# 40089  1000000.0    automatic        sedan      custom   False  2018-06-30
# 42749  1000000.0    automatic  convertible     no info   False  2019-04-10
#
#        days_listed manufactor  dayofweek_ad_placed  month_ad_placed  \
# 28128          102  chevrolet                    4               10
# 33007           11  chevrolet                    4                2
# ...

# %%
# with outliers:
df_outliers.loc[[40089,42749],]
# Out:
#        price  model_year             model  condition  cylinders fuel  \
# 40089  20000      1960.0  chevrolet impala  excellent        8.0  gas
# 42749  69900      1969.0  chevrolet camaro        new        8.0  gas
#
#        odometer transmission         type paint_color  is_4wd date_posted  \
# 40089    1000.0    automatic        sedan      custom     NaN  2018-06-30
# 42749    1000.0    automatic  convertible         NaN     NaN  2019-04-10
#
#        days_listed  year_ad_placed  vehicle_age
# 40089           75            2018         59.0
# 42749           60            2019         51.0

# %% [markdown]
# ### we solved the mystery:
# ### both are old cars with 1000 miles! not logical ! so we multipy (before) all this values, because it's probably was 1000K.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Reviewer's comment. V.2.</b> <a class="tocSkip"></a>
#
# Multipy is a good and real variant!
#
#
# </div>

# %% [markdown]
# ## __cylinders__

# %%
fig,axes = plt.subplots(nrows=1, ncols=1,figsize=(11,5));
axes.hist(df['cylinders'],bins=200);
axes.set_xlabel('cylinders');
axes.set_ylabel('count');
axes.set_title('cylinders histogram');

# %% [markdown]
# ### i don't think that i should remove the values in 3, 5, 7, 10 columns even they are small values.
# ### there are some cars with these number of cylinders. so i don't call it "outliers" and i don't remove them.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Reviewer's comment. V.2.</b> <a class="tocSkip"></a>
#
# OK
#
#
# </div>

# %% [markdown]
# ## __condition__

# %%
fig,axes = plt.subplots(nrows=1, ncols=1,figsize=(11,5));
axes.hist(df['condition'],bins=200);
axes.set_xlabel('condition');
axes.set_ylabel('count');
axes.set_title('condition histogram');

# %% [markdown]
# ### the same here ! i don't see these small values as outliers. they could be true !
# ### we even could see here that the histogram is similar to the normal distribution, because this extreme values!

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Reviewer's comment. V.2.</b> <a class="tocSkip"></a>
#
# Great!
#
# </div>

# %% [markdown]
# ## __days_listed__

# %%
fig,axes = plt.subplots(nrows=1, ncols=2,figsize=(11,5));
axes[0].hist(df['days_listed'],bins=90);
axes[0].set_xlabel('days listed ad');
axes[0].set_ylabel('count');
axes[0].set_title('days listed histogram');
axes[1].set_title("days listed boxplot")
df.boxplot("days_listed");

# %% [markdown]
# #### we see here a right skwed histogram, range from 0 to 270, the median is around 30, and most of the values are between 0 to 100 (bix with the whiskers).

# %%
df["days_listed"].agg(["mean","median"])
# Out:
# mean      39.565473
# median    33.000000
# Name: days_listed, dtype: float64

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Reviewer's comment</b> <a class="tocSkip"></a>
#
# Also we can use describe method. :)
# </div>

# %% [markdown]
# #### we see that as a right skewed column, the mean is more than the median (more affected by extreme values).

# %% [markdown]
# #### lets check when AD removed quickly, and when not:

# %% [markdown]
# #### first, lets try to compare the numerical columns:

# %%
long = df.query("days_listed>190").describe().loc[["mean","50%"],].transpose()
long
# Out:
#                               mean       50%
# price                 13603.680851    9885.0
# model_year             2011.404255    2011.0
# condition                 2.723404       3.0
# cylinders                 5.787234       6.0
# odometer             103884.255319  103000.0
# days_listed             215.255319     207.0
# dayofweek_ad_placed       2.914894       3.0
# month_ad_placed           6.042553       5.0
# year_ad_placed         2018.404255    2018.0
# vehicle_age               8.000000       8.0
# mileage_per_year      13747.468085   12970.0

# %%
short = df.query("days_listed<10").describe().loc[["mean","50%"],].transpose()
short
# Out:
#                               mean       50%
# price                 12323.149711    9495.0
# model_year             2009.800795    2011.0
# condition                 2.644214       3.0
# cylinders                 6.113516       6.0
# odometer             116920.706714  116000.0
# days_listed               5.924912       6.0
# dayofweek_ad_placed       2.961131       3.0
# month_ad_placed           6.719744       7.0
# year_ad_placed         2018.293286    2018.0
# vehicle_age               9.492491       9.0
# mileage_per_year      14164.644214   13333.0

# %%
means = pd.concat([long.loc[:,'mean'],short.loc[:,'mean']], axis=1).transform("round")
means.columns=["long","short"]
means
# Out:
#                          long     short
# price                 13604.0   12323.0
# model_year             2011.0    2010.0
# condition                 3.0       3.0
# cylinders                 6.0       6.0
# odometer             103884.0  116921.0
# days_listed             215.0       6.0
# dayofweek_ad_placed       3.0       3.0
# month_ad_placed           6.0       7.0
# year_ad_placed         2018.0    2018.0
# vehicle_age               8.0       9.0
# mileage_per_year      13747.0   14165.0

# %%
medians = pd.concat([long.loc[:,'50%'],short.loc[:,'50%']], axis=1)
medians.columns=["long","short"]
medians
# Out:
#                          long     short
# price                  9885.0    9495.0
# model_year             2011.0    2011.0
# condition                 3.0       3.0
# cylinders                 6.0       6.0
# odometer             103000.0  116000.0
# days_listed             207.0       6.0
# dayofweek_ad_placed       3.0       3.0
# month_ad_placed           5.0       7.0
# year_ad_placed         2018.0    2018.0
# vehicle_age               8.0       9.0
# mileage_per_year      12970.0   13333.0

# %% [markdown]
# ### the main difference we see is in the price:
# ### __higher price = long time.__
# ### we see differences too in other parameters like odometer and mileage per year.
# ### surprisingly, they are better in the "long time" dataframe!
# ### the explanation is that because they are better, they cause a higher price which cause long time.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Reviewer's comment</b> <a class="tocSkip"></a>
#
# Very good differences!</div>

# %% [markdown]
# #### lets check non numerical features:

# %%
short = df.query("days_listed<10")
long = df.query("days_listed>190")

# %%
# the length are not equal!
# so we will use ratios
print(len(short),len(long))
# Out:
# 4528 47

# %%
for col in ["model","type","fuel","paint_color"]:
    print(f"******************{col}**********************************")
    print(f"----------short-------------------------------------------")
    print(short[col].value_counts()[:4]/short[col].value_counts().sum())
    print(f"----------long-------------------------------------------")
    print(long[col].value_counts()[:4]/long[col].value_counts().sum())
    print()
    print()
# Out:
# ******************model**********************************
# ----------short-------------------------------------------
# ford f-150                  0.057641
# chevrolet silverado 1500    0.042845
# ram 1500                    0.035777
# chevrolet silverado         0.023852
# Name: model, dtype: float64
# ----------long-------------------------------------------
# chevrolet silverado        0.063830
# toyota rav4                0.063830
# jeep wrangler unlimited    0.042553
# toyota tundra              0.042553
# Name: model, dtype: float64
#
#
# ******************type**********************************
# ----------short-------------------------------------------
# sedan     0.240283
# suv       0.237853
# truck     0.237412
# pickup    0.134496
# Name: type, dtype: float64
# ----------long-------------------------------------------
# sedan     0.255319
# suv       0.212766
# truck     0.170213
# pickup    0.127660
# Name: type, dtype: float64
#
#
# ...

# %% [markdown]
# ### the main things we could see from this comparison:
# #### there are models which sells much faster!
# #### amazing ! there are colors which sells much faster!

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Reviewer's comment</b> <a class="tocSkip"></a>
#
# Intresting!</div>

# %% [markdown]
# ## Analyzing the number of ads and the average price for each type of vehicle

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Reviewer's comment</b> <a class="tocSkip"></a>
#
# ~Result will be different after your new preparation. :)~ </div>
#
# <div class="alert alert-block alert-warning">
# <b>Reviewer's comment. V.2.</b> <a class="tocSkip"></a>
#
# You big job with missing values give to us other types of vehicle. But ok. :)
#
# </div>

# %%
x = df.groupby("type").agg({'price':['count','mean']})
x.columns = x.columns.droplevel(0)
x.columns= ["number_of_ADs",'mean_price']
x["mean_price"]=np.round(x["mean_price"])
x["type_percentage"] = np.round(x["number_of_ADs"]/x["number_of_ADs"].sum(),2)*100
x.sort_values(by="number_of_ADs",inplace=True,ascending=False)
x
# Out:
#              number_of_ADs  mean_price  type_percentage
# type
# suv                  12239     11434.0             24.0
# truck                12050     17032.0             24.0
# sedan                11994      7078.0             24.0
# pickup                6869     15870.0             14.0
# coupe                 2237     14842.0              4.0
# wagon                 1532      9063.0              3.0
# mini-van              1150      8074.0              2.0
# hatchback             1032      6904.0              2.0
# van                    585      9358.0              1.0
# convertible            433     14866.0              1.0
# other                  248     11055.0              0.0
# offroad                213     14196.0              0.0
# bus                     24     17136.0              0.0

# %%
x["number_of_ADs"][:10].plot(kind="bar",figsize=(10,5));
plt.xlabel("Type");
plt.ylabel("count of ADs");

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Reviewer's comment</b> <a class="tocSkip"></a>
#
# ~Please, check your code. :)~</div>
#
# <div class="alert alert-block alert-success">
# <b>Reviewer's comment. V.2.</b> <a class="tocSkip"></a>
#
# Great! It works!
#
# </div>

# %% [markdown]
# #### the two best sellers types are SUV and truck.

# %% [markdown]
# #### we will take these types and see what factors impact the price most:

# %%
df_types = df[df["type"].isin(["suv","truck"])]

# %%
df_type_suv= df.query("type=='suv'")

# %%
df_type_truck= df.query("type=='truck'")

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Reviewer's comment</b> <a class="tocSkip"></a>
#
# ~It can be other types~</div>
#
# <div class="alert alert-block alert-success">
# <b>Reviewer's comment. V.2.</b> <a class="tocSkip"></a>
#
# OK
#
# </div>

# %%
for feature in ["transmission","type","paint_color"]:
    #     check that the ads category is over 50 :
    if len(df_types[feature])>50:
        fig, ax = plt.subplots(figsize=(14,8))
        x = sns.boxplot(data = df_types,y="price",x=feature,ax=ax,hue="type")
        x.set_title(f'suv and truck comparing {feature}',fontsize=20)
        x.set_xlabel(f"{feature}",fontsize=20)
        x.set_ylabel(f"price",fontsize=20)
        plt.show()

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Reviewer's comment</b> <a class="tocSkip"></a>
#
# ~What graph is for one type? What is for another? Could you show the difference?~</div>
#
#
# <div class="alert alert-block alert-success">
# <b>Reviewer's comment. V.2.</b> <a class="tocSkip"></a>
#
# Wow! Excellent graphs! Now we have all information on them! :)
#
# </div>

# %% [markdown]
# ### we could see that all these categorical factors affecting the price and there are many differents between the two types.

# %% [markdown]
# ### lets check more numerical columns:

# %%
for feature in ['condition', 'odometer','vehicle_age', 'mileage_per_year']:
#     check that the ads category is over 50 :
    if len(df_types[feature])>50:
        fig, ax = plt.subplots(figsize=(14,8))
        x = sns.scatterplot(data = df_types,y="price",x=feature,ax=ax,hue="type")
        x.set_title(f'suv and truck comparing {feature}',fontsize=20)
        x.set_xlabel(f"{feature}",fontsize=20)
        x.set_ylabel(f"price",fontsize=20)
        plt.show()

# %%
fig, ax = plt.subplots(figsize=(14,8))
sns.heatmap(df.corr(),annot=True,ax=ax,cmap="YlGnBu");

# %% [markdown]
# #### we could see that "model year" affects on the price, but there are old models with high price too.
# #### condition- as long as the condition isn't 0 or 1 (low price) the others are much same.
# #### cylinders - 6,8 are the expensive ones.
# #### odometer - as long as the odometer high, the price is lower, but there are high odometers with high price too.

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Reviewer's comment</b> <a class="tocSkip"></a>
#
# ~I guess, you forgot that we need different graphs for different columns.~
# ~I remember:~
#
# ~- transmission type and color needs box-and-whisker charts. Note that the categories must have at least 50 ads.~
# ~- age, mileage, condition need scatterplots.~
#
# ~Please, change your code a little. :)~
#
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Reviewer's comment. V.2.</b> <a class="tocSkip"></a>
#
# Very good graph!
#
# </div>

# %% [markdown]
# # Conclusion:
# ## we were need to study data collected over the last few years and determine which factors influence the price of a vehicle.
# ### the dataset:
#     * the dataset was big, 54,000 of vehicles AD's  - with different models, different years and differnt types and conditions.
#     * in our research we tried to remove outliers and fill missing values (based on features we had) so we could conclude reliable conclusions.
#     * there were many mistaken values in the dataset (for example GMC YUCON from 1930,zero  prices, and zero "odometer" calls, we did our best to clean it and make our research only on reliable data.
# ### the conclusions:
#     * some factors have influence on the number of days the AD listed. high price ? more time to sell. old car ? more time to sell too.
#     * there are many factors which have influence on the price, the odometer (negative realationship), model year, cylinders, is_4wd, condition, all have influence on the price, but there are many changes between models and types. in some models we saw that even the paint has some influence.
#     * the data has a lot of details and every vehicle is very different one from another (model, age, miles per age ...), so i think that we couldn't generilize too much the conclusions.
#     * on the other hand, we could predict very well what should be a price of a vehicle, if we would have the data on this speciphic vehicle - model, year, odometer, condition etc.
#     * so the continue should be to build a Machine Learning model, which would predict the price, based on this data.
#     * we had found that there were 3 types with the greatest number of ads in our dataset - suv, truck and sedan.
#     * we did different comparisions between truck and suv,in general trucks are more expensive, but again - there are many factors which have influence on the price.

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Reviewer's comment</b> <a class="tocSkip"></a>
#
# You did a big job. You did many researches in it. Detailed conclusion make your project completed. It is like a conclusion in a book: we want to know what's happened in a nutshell.
#
#
# </div>

# %% [markdown]
# <div class="alert alert-info" style="border-radius: 15px; box-shadow: 4px 4px 4px; border: 1px solid ">
# <h2> Student's comment</h2>
# <strong>
# <p>thank you on all the work you invested in this check!</p>
# <p>i think that the explanations of the project were not clear enough and i did a lot of things twice because of it</p>
# <p>there is here so much i could write so i dont know what conclution to write.
#     <p> if you could please give me a questions you want i answer on the conclusion, i would try to do it.
# </strong>
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Reviewer's comment. V.2.</b> <a class="tocSkip"></a>
#
# It would be good to open our project description and look on steps.
#
# - What data do we have? About what our df?
# - What we found? Any strange values, common values.
# - What changed after work with outliries?
# - What is typical for ads?
# - What is the two types with the greatest number of ads?
# - What we found in graphs for them?
#
# Of course, it could be short comments. :)
#
# </div>
