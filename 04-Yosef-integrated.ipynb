# %% [markdown]
# <div style="border:solid Chocolate 2px; padding: 40px">
#
# <b>Hello, Yosef!👋 How are you today?</b>
#
# My name is Arina U. and I am glad to be your reviewer in this project! Nice to meet you!<br />
#
#
# You can find my comments in <font color='green'>green</font>, <font color='gold'>yellow</font> and <font color='red'>red</font> boxes. Examples you can see below:
#
# <div class="alert alert-block alert-success">
#     <h2>Reviewer's commentary <a class="tocSkip"> </h2>
#     <br/>
# <b>Well done!👍:</b> In case if task is completely correct and everything is alright!
# </div>
#
#
# <div class="alert alert-block alert-warning">
#    <h2>Reviewer's commentary <a class="tocSkip"> </h2>
#     <br/>
# <b>Remarks and recommendations📌:</b>  In case when I can give some advice that can help you to improve your work or recommend you some useful links and resources that can help you widen your knowledge and help in future tasks.
# </div>
#
# <div class="alert alert-block alert-danger">
#     <h2>Reviewer's commentary <a class="tocSkip"> </h2>
#     <br/>
# <b>Needs fixing!🤔:</b> In case when step requires some extra work and some corrections. Project can't be accepted with comments in the red boxes
# </div>
#
# Please pay attention to not move or change my comments. It would be good to highlight your answers in some way.
#
# #### <font color='Purple'>Student's commentary:</font> for example like this <a class="tocSkip"> </div>
#
# OK, now let's go!😏
# </font>

# %% [markdown]
# <div class="alert alert-info"> <b>Student comments:</b><br>
#     Thank you very much arina on your checking, i see you invested a lot of time on it.<br>
#     i learned from it a lot!<br>
#     i tried to fix all, i hope it done.
#     </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
#     <h2>Reviewer's commentary: second iteration of the review <a class="tocSkip"> </h2>
#     <br/>
# <b>Well done!👍:</b>
#
# Ok, Yosef, hi again! Thank you for feedback, let's look at your improvements👀

# %% [markdown]
# # Project description
# You work for the online store Ice, which sells video games all over the world. User and expert reviews, genres, platforms (e.g. Xbox or PlayStation), and historical data on game sales are available from open sources. You need to identify patterns that determine whether a game succeeds or not. This will allow you to spot potential big winners and plan advertising campaigns.
# In front of you is data going back to 2016. Let’s imagine that it’s December 2016 and you’re planning a campaign for 2017.
# (The important thing is to get experience working with data. It doesn't really matter whether you're forecasting 2017 sales based on data from 2016 or 2027 sales based on data from 2026.)
# The dataset contains the abbreviation ESRB. The Entertainment Software Rating Board evaluates a game's content and assigns an age rating such as Teen or Mature.

# %% [markdown]
# ## Data description
# __Name__
# **Platform
# Year_of_Release
# Genre
# NA_sales (North American sales in USD million)
# EU_sales (sales in Europe in USD million)
# JP_sales (sales in Japan in USD million)
# Other_sales (sales in other countries in USD million)
# Critic_Score (maximum of 100)
# User_Score (maximum of 10)
# Rating (ESRB)
# Data for 2016 may be incomplete.**

# %% [markdown]
# ## To the reviewer:
# **from my past experience: some of the libraries, are not updated on the platform.
# specialy metplotlib and seaborn.
# so please, when you check my work, remove the # sign, and run the next commands so all would run properly.
# thanks!**

# %%
# !pip install -U numpy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      |████████████████████████████████| 15.7 MB 52 kB/s eta 0:00:014    |██████████████▋                 | 7.2 MB 1.6 MB/s eta 0:00:06     |████████████████▎               | 8.0 MB 1.6 MB/s eta 0:00:05
# ...
#   WARNING: The scripts f2py, f2py3 and f2py3.7 are installed in '/home/jovyan/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# ...

# %%
# !pip install -U pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      |████████████████████████████████| 10.8 MB 50 kB/s eta 0:00:01
# ...

# %%
# !pip install -U matplotlib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      |████████████████████████████████| 10.3 MB 14.9 MB/s eta 0:00:01
# ...

# %%
# !pip install -U seaborn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      |████████████████████████████████| 285 kB 1.5 MB/s eta 0:00:01
# ...

# %%
#!pip install --upgrade seaborn

# %%
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# <div class="alert alert-block alert-warning">
#    <h2>Reviewer's commentary <a class="tocSkip"> </h2>
#     <br/>
# <b>Remarks and recommendations📌:</b>
#
# Ok, Yosef, but apart from installing libraries it is important to upgrade them too. I add this code (see above), because your code provides the errors (your version of seaborn newer than version of seaborn at Yandex.Praktikum server), reviwer shouldn't upgrade libraries in student's project, so next time be more attentive to this moment.

# %% [markdown]
# <div class="alert alert-info"> <b>Student comments:</b> on the first project seaborn didn't worked to me, this was the solution the instructor told me to do.
#     i saw the code you added, thanks!<br> i have added `-U` it will work like `--upgrade`.
# i hope there would be a better solution to this!</div>

# %% [markdown]
# <div class="alert alert-block alert-success">
#     <h2>Reviewer's commentary: second iteration of the review <a class="tocSkip"> </h2>
#     <br/>
# <b>Well done!👍:</b>
#
# Ok!😎

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
try:
    df_games = pd.read_csv("games.csv",na_values="null")
except Exception as e:
    df_games=pd.read_csv("/datasets/games.csv",na_values="null")

# %%
df_games
# Out:
#                                 Name Platform  Year_of_Release         Genre  \
# 0                         Wii Sports      Wii           2006.0        Sports
# 1                  Super Mario Bros.      NES           1985.0      Platform
# 2                     Mario Kart Wii      Wii           2008.0        Racing
# 3                  Wii Sports Resort      Wii           2009.0        Sports
# 4           Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing
# ...                              ...      ...              ...           ...
# 16710  Samurai Warriors: Sanada Maru      PS3           2016.0        Action
# 16711               LMA Manager 2007     X360           2006.0        Sports
# 16712        Haitaka no Psychedelica      PSV           2016.0     Adventure
# 16713               Spirits & Spells      GBA           2003.0      Platform
# 16714            Winning Post 8 2016      PSV           2016.0    Simulation
#
# ...

# %% [markdown]
# ### we already see some things:
#     * null values in some columns
#     * 0 sales for some rows
#     * seems that in the "tail" of the DB there are more nulls and 0 sales

# %%
df_games.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16715 entries, 0 to 16714
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Name             16713 non-null  object
#  1   Platform         16715 non-null  object
#  2   Year_of_Release  16446 non-null  float64
#  3   Genre            16713 non-null  object
#  4   NA_sales         16715 non-null  float64
#  5   EU_sales         16715 non-null  float64
#  6   JP_sales         16715 non-null  float64
#  7   Other_sales      16715 non-null  float64
#  8   Critic_Score     8137 non-null   float64
#  9   User_Score       10014 non-null  object
#  10  Rating           9949 non-null   object
# dtypes: float64(6), object(5)
# memory usage: 1.4+ MB

# %% [markdown]
# * user_score should be a float - because it's a numerical value, not object.

# %%
df_games["User_Score"] = pd.to_numeric(df_games["User_Score"],errors='coerce',downcast="float")

# %%
df_games.dtypes
# Out:
# Name                object
# Platform            object
# Year_of_Release    float64
# Genre               object
# NA_sales           float64
# EU_sales           float64
# JP_sales           float64
# Other_sales        float64
# Critic_Score       float64
# User_Score         float32
# Rating              object
# dtype: object

# %% [markdown]
# ### i don't see here a case sensitive data, so i convert all the dataset to lower case:

# %%
df_games.columns= df_games.columns.str.lower()

# %%
df_games = df_games.applymap(lambda s:s.lower() if type(s) == str else s)

# %%
df_games.head()
# Out:
#                        name platform  year_of_release         genre  na_sales  \
# 0                wii sports      wii           2006.0        sports     41.36
# 1         super mario bros.      nes           1985.0      platform     29.08
# 2            mario kart wii      wii           2008.0        racing     15.68
# 3         wii sports resort      wii           2009.0        sports     15.61
# 4  pokemon red/pokemon blue       gb           1996.0  role-playing     11.27
#
#    eu_sales  jp_sales  other_sales  critic_score  user_score rating
# 0     28.96      3.77         8.45          76.0         8.0      e
# 1      3.58      6.81         0.77           NaN         NaN    NaN
# 2     12.76      3.79         3.29          82.0         8.3      e
# 3     10.93      3.28         2.95          80.0         8.0      e
# 4      8.89     10.22         1.00           NaN         NaN    NaN

# %% [markdown]
# ### check duplicated rows:

# %%
df_games.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ### lets see how much nulls we have in percentage.

# %%
def find_nulls():
    nulls = df_games.isnull().sum()*100/len(df_games)
    nulls = nulls.where(nulls>0).dropna().sort_values(ascending=False)
    print("the nulls values (as percentege):")
    return round(nulls,2)
find_nulls()
# Out:
# the nulls values (as percentege):
# user_score         54.59
# critic_score       51.32
# rating             40.48
# year_of_release     1.61
# name                0.01
# genre               0.01
# dtype: float64

# %% [markdown]
# ### why so many missing values ?
# i found that this data set is from https://www.kaggle.com/rush4ratio/video-game-sales-with-ratings
# and the answer is in the description:
# **"Video game sales from Vgchartz and corresponding ratings from Metacritic.
# Motivated by Gregory Smith's web scrape of VGChartz Video Games Sales, this data set simply extends the number of variables with another web scrape from Metacritic. Unfortunately, there are missing observations as Metacritic only covers a subset of the platforms. Also, a game may not have all the observations of the additional variables discussed below. Complete cases are ~ 6,900"**

# %% [markdown]
# name and genre missing values we could drop because there are very few:

# %%
df_games.dropna(subset=['name'], how='all', inplace=True)
df_games.dropna(subset=['genre'], how='all', inplace=True)

# %% [markdown]
# we will begin from "year of release" column, because it will help us to fill the other columns.

# %% [markdown]
# <div class="alert alert-block alert-success">
#     <h2>Reviewer's commentary <a class="tocSkip"> </h2>
#     <br/>
# <b>Well done!👍:</b>
#
# Ok, Yosef, by this time all your actions are correct, let's move on and check your decisions at the next steps of the analysis.

# %% [markdown]
# ### year_of_release column:

# %% [markdown]
# first, lets see the distribution:

# %%
fig,axes = plt.subplots(nrows=1, ncols=2,figsize=(11,4));
sns.histplot(data=df_games,x="year_of_release",ax=axes[0]);
sns.boxplot(data=df_games,x="year_of_release",ax=axes[1]);
axes[0].set_title(f'year of release hist',fontsize=12)
axes[0].set_xlabel(f"year of release",fontsize=12)
axes[0].set_ylabel(f"count",fontsize=12)
axes[1].set_title(f'year of release boxplot',fontsize=12)
axes[1].set_xlabel(f"year of release",fontsize=12);

# %% [markdown]
# <div class="alert alert-block alert-warning">
#    <h2>Reviewer's commentary<a class="tocSkip"> </h2>
#     <br/>
# <b>Remarks and recommendations📌:</b>
#
# Well, Yosef, it is better to add the common titles and y and x-axis labels to your plot. So, please, try to improve all the plots in your project

# %% [markdown]
# <div class="alert alert-block alert-success">
#     <h2>Reviewer's commentary: second iteration of the review <a class="tocSkip"> </h2>
#     <br/>
# <b>Well done!👍:</b>
#
# Ok, this time visualization is formetted more correctly!

# %%
df_games[df_games["year_of_release"].isnull()]
# Out:
#                                     name platform  year_of_release  \
# 183                      madden nfl 2004      ps2              NaN
# 377                     fifa soccer 2004      ps2              NaN
# 456           lego batman: the videogame      wii              NaN
# 475           wwe smackdown vs. raw 2006      ps2              NaN
# 609                       space invaders     2600              NaN
# ...                                  ...      ...              ...
# 16373  pdc world championship darts 2008      psp              NaN
# 16405                      freaky flyers       gc              NaN
# 16448                          inversion       pc              NaN
# 16458        hakuouki: shinsengumi kitan      ps3              NaN
# 16522                       virtua quest       gc              NaN
#
#               genre  na_sales  eu_sales  jp_sales  other_sales  critic_score  \
# 183          sports      4.26      0.26      0.01         0.71          94.0
# ...

# %% [markdown]
# we see that in some of the names, there is a year at the end. we will try to extract it:

# %%
import re
def getYear(row):
    if type(row["year_of_release"]) in ('int','float') :
        return row["year_of_release"]
    else:
        arr = re.findall(r'[0-9]+', row["name"])
        if [x for x in arr if 1980<int(x)<2020]:
            return [int(x) for x in arr if 1900<int(x)<2030][0]
        else:
            return row["year_of_release"]

df_games["year_of_release"] = df_games.apply(getYear,axis=1)
df_games[df_games["year_of_release"].isnull()]
# Out:
#                                               name platform  year_of_release  \
# 456                     lego batman: the videogame      wii              NaN
# 609                                 space invaders     2600              NaN
# 627                                      rock band     x360              NaN
# 657       frogger's adventures: temple of the frog      gba              NaN
# 678    lego indiana jones: the original adventures      wii              NaN
# ...                                            ...      ...              ...
# 16348                 agarest senki: re-appearance      ps3              NaN
# 16405                                freaky flyers       gc              NaN
# 16448                                    inversion       pc              NaN
# 16458                  hakuouki: shinsengumi kitan      ps3              NaN
# 16522                                 virtua quest       gc              NaN
#
# ...

# %% [markdown]
# it helped a little, but we still have a lot of missing values.
# we will try to fill the missing years based on the platform:

# %%
df_games['year_of_release'] = df_games['year_of_release'].fillna(df_games.groupby('platform')['year_of_release'].transform('median'))

# %%
df_games["year_of_release"].isnull().sum()
# Out:
# 0

# %%
fig,axes = plt.subplots(nrows=1, ncols=2,figsize=(11,4));
sns.histplot(data=df_games,x="year_of_release",ax=axes[0]);
sns.boxplot(data=df_games,x="year_of_release",ax=axes[1]);
axes[0].set_title(f'year of release hist',fontsize=12)
axes[0].set_xlabel(f"year of release",fontsize=12)
axes[0].set_ylabel(f"count",fontsize=12)
axes[1].set_title(f'year of release boxplot',fontsize=12)
axes[1].set_xlabel(f"year of release",fontsize=12);

# %%
df_games["year_of_release"]=df_games["year_of_release"].astype('int')
df_games.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16713 entries, 0 to 16714
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   name             16713 non-null  object
#  1   platform         16713 non-null  object
#  2   year_of_release  16713 non-null  int64
#  3   genre            16713 non-null  object
#  4   na_sales         16713 non-null  float64
#  5   eu_sales         16713 non-null  float64
#  6   jp_sales         16713 non-null  float64
#  7   other_sales      16713 non-null  float64
#  8   critic_score     8137 non-null   float64
#  9   user_score       7590 non-null   float64
#  10  rating           9949 non-null   object
# dtypes: float64(6), int64(1), object(4)
# memory usage: 1.5+ MB

# %% [markdown]
# ### user_score column:

# %% [markdown]
# we have here above 50% missing values! i could fill them based on median or mean, or stay it null. lets see the distribution first:

# %%
fig,axes = plt.subplots(nrows=1, ncols=2,figsize=(11,4));
sns.histplot(data=df_games,x="user_score",ax=axes[0]);
sns.boxplot(data=df_games,x="user_score",ax=axes[1]);
axes[0].set_title(f'user score hist',fontsize=12)
axes[0].set_xlabel(f"user score",fontsize=12)
axes[0].set_ylabel(f"count",fontsize=12)
axes[1].set_title(f'user score boxplot',fontsize=12)
axes[1].set_xlabel(f"user score",fontsize=12);

# %% [markdown]
# we see a left skewed distribution with outliers.

# %% [markdown]
# i will fill them based on features, that's my best choice in such situation:

# %%
df_games['user_score'] = df_games['user_score'].fillna(round(df_games.groupby(['genre','year_of_release','platform'])['user_score'].transform('mean'),1))

# %%
fig,axes = plt.subplots(nrows=1, ncols=2,figsize=(11,4));
sns.histplot(data=df_games,x="user_score",ax=axes[0]);
sns.boxplot(data=df_games,x="user_score",ax=axes[1]);
axes[0].set_title(f'user score hist',fontsize=12)
axes[0].set_xlabel(f"user score",fontsize=12)
axes[0].set_ylabel(f"count",fontsize=12)
axes[1].set_title(f'user score boxplot',fontsize=12)
axes[1].set_xlabel(f"user score",fontsize=12);

# %% [markdown]
# it's very far from ideal, but we haven't better way (we could try scrap the web to get the missing data, but it's not what we have been asked to do)

# %%
find_nulls()
# Out:
# the nulls values (as percentege):
# critic_score    51.31
# rating          40.47
# user_score      12.12
# dtype: float64

# %% [markdown]
# anyway, we reduced missing values in this column from 54% to 12%

# %% [markdown]
# the 12% remains, we will try to fill based on genres only:

# %%
df_games['user_score'] = df_games['user_score'].fillna(round(df_games.groupby(['genre'])['user_score'].transform('mean'),1))

# %%
find_nulls()
# Out:
# the nulls values (as percentege):
# critic_score    51.31
# rating          40.47
# dtype: float64

# %%
fig,axes = plt.subplots(nrows=1, ncols=2,figsize=(11,4));
sns.histplot(data=df_games,x="user_score",ax=axes[0]);
sns.boxplot(data=df_games,x="user_score",ax=axes[1]);
axes[0].set_title(f'user score hist',fontsize=12)
axes[0].set_xlabel(f"user score",fontsize=12)
axes[0].set_ylabel(f"count",fontsize=12)
axes[1].set_title(f'user score boxplot',fontsize=12)
axes[1].set_xlabel(f"user score",fontsize=12);

# %% [markdown]
# ### critic score column

# %% [markdown]
# i will do here the same process as "user_score", so i'm not explaining it:

# %%
fig,axes = plt.subplots(nrows=1, ncols=2,figsize=(11,4));
sns.histplot(data=df_games,x="critic_score",ax=axes[0]);
sns.boxplot(data=df_games,x="critic_score",ax=axes[1]);
axes[0].set_title(f'critic score hist',fontsize=12)
axes[0].set_xlabel(f"critic score",fontsize=12)
axes[0].set_ylabel(f"count",fontsize=12)
axes[1].set_title(f'critic score boxplot',fontsize=12)
axes[1].set_xlabel(f"critic score",fontsize=12);

# %%
df_games['critic_score'] = df_games['critic_score'].fillna(round(df_games.groupby(['genre','year_of_release','platform'])['critic_score'].transform('mean'),1))

# %%
fig,axes = plt.subplots(nrows=1, ncols=2,figsize=(11,4));
sns.histplot(data=df_games,x="critic_score",ax=axes[0]);
sns.boxplot(data=df_games,x="critic_score",ax=axes[1]);
axes[0].set_title(f'critic score hist',fontsize=12)
axes[0].set_xlabel(f"critic score",fontsize=12)
axes[0].set_ylabel(f"count",fontsize=12)
axes[1].set_title(f'critic score boxplot',fontsize=12)
axes[1].set_xlabel(f"critic score",fontsize=12);

# %%
df_games['critic_score'] = df_games['critic_score'].fillna(round(df_games.groupby(['genre'])['critic_score'].transform('mean'),1))

# %%
find_nulls()
# Out:
# the nulls values (as percentege):
# rating    40.47
# dtype: float64

# %% [markdown]
# ### rating

# %% [markdown]
# the rating is an ordinal variable. we will use it to fill the missing values based on the median value.
# we first will give rating column a numerical value, then replace the missing values with the median.

# %%
df_games["rating"].value_counts()
# Out:
# e       3990
# t       2961
# m       1563
# e10+    1420
# ec         8
# k-a        3
# rp         3
# ao         1
# Name: rating, dtype: int64

# %% [markdown]
# from search on the internet "k-a" is "kids to adoults" and become "e", "ec" is "early childhood" and removed too and became "e".
# rp is return pending, so we replace it with null.
# https://www.esrb.org/history/
# https://rating-system.fandom.com/wiki/ESRB_Early_Childhood

# %%
def map_values(x):
    if x=="k-a" or x=='ec':
        return "e"
    elif x=="rp":
        return np.nan
    else: 
        return x
df_games["rating"] = df_games["rating"].apply(map_values)

# %%
df_games["rating"].value_counts()
# Out:
# e       4001
# t       2961
# m       1563
# e10+    1420
# ao         1
# Name: rating, dtype: int64

# %% [markdown]
# we have now 5 ordinal values, we will replace them with numbers, and fill the null values with the median:

# %%
# create new numerical rating column (0 for every body, 5 adoults only)
cat_list = ["e","e10+","t","m","ao"]
cat_dict = dict(zip(cat_list, np.arange(len(cat_list))))
df_games['rating_numerical'] = df_games['rating'].map(cat_dict)
# fill the null values with the median:
df_games['rating_numerical'] = df_games['rating_numerical'].fillna(df_games['rating_numerical'].median())

# %%
df_games.head()
# Out:
#                        name platform  year_of_release         genre  na_sales  \
# 0                wii sports      wii             2006        sports     41.36
# 1         super mario bros.      nes             1985      platform     29.08
# 2            mario kart wii      wii             2008        racing     15.68
# 3         wii sports resort      wii             2009        sports     15.61
# 4  pokemon red/pokemon blue       gb             1996  role-playing     11.27
#
#    eu_sales  jp_sales  other_sales  critic_score  user_score rating  \
# 0     28.96      3.77         8.45          76.0         8.0      e
# 1      3.58      6.81         0.77          69.0         7.4    NaN
# 2     12.76      3.79         3.29          82.0         8.3      e
# 3     10.93      3.28         2.95          80.0         8.0      e
# 4      8.89     10.22         1.00          72.7         7.7    NaN
#
#    rating_numerical
# 0               0.0
# 1               1.0
# 2               0.0
# ...

# %% [markdown]
# we see that the median is 1 ("e10+") and we replaced the nulls to it.

# %%
df_games['rating_numerical'].value_counts()
# Out:
# 1.0    8187
# 0.0    4001
# 2.0    2961
# 3.0    1563
# 4.0       1
# Name: rating_numerical, dtype: int64

# %%
### we will remove the rating column:
df_games.drop('rating', axis='columns', inplace=True)

# %%
find_nulls()
# Out:
# the nulls values (as percentege):
# Series([], dtype: float64)

# %% [markdown]
# ### there aren't null values anymore !

# %% [markdown]
# <div class="alert alert-block alert-warning">
#    <h2>Reviewer's commentary<a class="tocSkip"> </h2>
#     <br/>
# <b>Remarks and recommendations📌:</b>
#
# Yosef, you offered a rather interesting approach to dealing with missing values.
#
# But I would like to note that it is a rather risky strategy to fill in missing values in columns `user_score`, `critic_score`.
#
# In fact, we do not know why the data in this column is missing (we can only hypothesize as you did), and we do not have access to a source that would allow us to replenish the data, restore it, so it is better leave missing values in the data and simply replace them with indicators. Missing values are also some kind of signal worth paying attention to and analyzing, it is valuable in its own way! The analyst's goal when working with missing values is not about filling the 100% of missing values! When filling missing values, it is important to proceed from the specifics of the data, take into account the risks of data distortion and the introduction of artificial trends and characteristics.
#
# The same logic is about the filling in the missing values in the column `year_of_release`: despite the fact that there are not many missing values in this column.
#
# My aim is to give some recommendations and food for thought! Of course the last word is always with the analyst, it is important to argue your position and give explanations of the strategy for working with data, you do it. In the real work of an analyst, there is always a risk of distorting data and getting an inaccurate, biased estimate or analysis results, so it is important to weigh the pros and cons when working with the missing values and data transformations at all!
#
# P.S. As for rating it is better to replace NaN values in the column `rating` with `unknown` because, again, if we try to fill in missing values in this column in other ways we face the risk of distortion of the original data. What is more important is that at the next steps of the analysis we need to analyse the rating by the region, and at this step it is better to analyse the games without rating!

# %% [markdown]
# <div class="alert alert-info"> <b>Student comments:</b> what you write was my attitude before this course, but other reveiwers asked me to fill missing values based on features.<br>
# if i was could in case like this of above 50% are missing, i was doing scraping or something to get more values from the web.<br> anyway i was thought that's what the reveiewer except from me, to fill the missing values based on features :)</div>

# %% [markdown]
# <div class="alert alert-block alert-success">
#     <h2>Reviewer's commentary: second iteration of the review <a class="tocSkip"> </h2>
#     <br/>
# <b>Well done!👍:</b>
#
# Ok, there are dozens of approaches to filling in missing values. There is no mistake in filling missing values using features, it can be a strategy, but from my point of view, this strategy can be used when we have not very big percentage of missing values (up to 10%)
#
# And agree with your idea about scraping, it also can be a good way to restore the data with minimal distortion. Anyway: you are an analyst, and you can have your position.

# %% [markdown]
# ### search TBD value:

# %%
df_games[df_games.eq('tbd').any(1)]
# Out:
# Empty DataFrame
# Columns: [name, platform, year_of_release, genre, na_sales, eu_sales, jp_sales, other_sales, critic_score, user_score, rating_numerical]
# Index: []

# %% [markdown]
# there isn't such value in our dataframe.

# %% [markdown]
# <div class="alert alert-block alert-warning">
#    <h2>Reviewer's commentary<a class="tocSkip"> </h2>
#     <br/>
# <b>Remarks and recommendations📌:</b>
#
# As for `tbd` value you can replace it with NaN.

# %% [markdown]
# ### create "total sales" column

# %%
df_games["total_sales"]=sum([df_games["na_sales"],df_games["eu_sales"],df_games["jp_sales"],df_games["other_sales"]])

# %%
fig,axes = plt.subplots(nrows=1, ncols=2,figsize=(14,4));
sns.histplot(data=df_games,x="total_sales",ax=axes[0]);
sns.boxplot(data=df_games,x="total_sales",ax=axes[1]);
axes[0].set_title(f'total sales hist',fontsize=12)
axes[0].set_xlabel(f"total sales",fontsize=12)
axes[0].set_ylabel(f"count",fontsize=12)
axes[1].set_title(f'total sales boxplot',fontsize=12)
axes[1].set_xlabel(f"total sales",fontsize=12);

# %% [markdown]
# we see right sqewed distribution, but a lot of outliers!
# lets see the values above 80:

# %%
df_games.query('total_sales>80')
# Out:
#          name platform  year_of_release   genre  na_sales  eu_sales  jp_sales  \
# 0  wii sports      wii             2006  sports     41.36     28.96      3.77
#
#    other_sales  critic_score  user_score  rating_numerical  total_sales
# 0         8.45          76.0         8.0               0.0        82.54

# %% [markdown]
# ## Step 3. Analyze the data

# %% [markdown]
# ### Look at how many games were released in different years. Is the data for every period significant?

# %%
df_games["year_of_release"].value_counts().sort_index(ascending=False)
# Out:
# 2017      16
# 2016     501
# 2015     606
# 2014     585
# 2013     548
# 2012     663
# 2011    1164
# 2010    1303
# 2009    1470
# 2008    1460
# 2007    1185
# 2006    1003
# 2005    1004
# 2004     781
# 2003     793
# 2002     832
# 2001     473
# 2000     367
# 1999     312
# 1998     376
# 1997     290
# 1996     262
# 1995     218
# 1994     120
# 1993      60
# 1992      42
# 1991      41
# 1990      16
# 1989      17
# 1988      15
# 1987      16
# 1986      21
# 1985      14
# 1984      14
# 1983      17
# 1982      53
# 1981      46
# 1980       9
# Name: year_of_release, dtype: int64

# %% [markdown]
# from the project description:
# ```
# You need to identify patterns that determine whether a game succeeds or not. This will allow you to spot potential big winners and plan advertising campaigns.
# In front of you is data going back to 2016. Let’s imagine that it’s December 2016 and you’re planning a campaign for 2017.
# ```
# i think that the data from 2017 isnt relevant - it's too new and we haven't yet enough data .
# as same as the data before 2004 is too old (the games and tech had changed from then a lot).

# %% [markdown]
# <div class="alert alert-block alert-warning">
#    <h2>Reviewer's commentary<a class="tocSkip"> </h2>
#     <br/>
# <b>Remarks and recommendations📌:</b>
#
# Yosef, at this step of the analysis it is better to draw histogram for the number of released games in different years, it can look like this:
#
# ![image.png](attachment:image.png)

# %%
games_by_year = df_games.groupby("year_of_release").count()["name"].reset_index()
fig,axes = plt.subplots(nrows=1, ncols=1,figsize=(14,6));
sns.barplot(data=games_by_year,x="year_of_release",y="name",color='blue');
axes.tick_params(axis='x',labelrotation=90)
axes.set_title(f'movies number by year',fontsize=14)
axes.set_xlabel(f"year of release",fontsize=12)
axes.set_ylabel(f"games count",fontsize=12);

# %% [markdown]
# <div class="alert alert-block alert-success">
#     <h2>Reviewer's commentary: second iteration of the review <a class="tocSkip"> </h2>
#     <br/>
# <b>Well done!👍:</b>
#
# Ok, you created rather informative plot!

# %% [markdown]
# ### Look at how sales varied from platform to platform.

# %%
x = df_games.groupby("platform").agg({"total_sales":["std","var"]})
x.columns = x.columns.droplevel(0)
x.sort_values("std",ascending=False).reset_index()
# Out:
#    platform       std        var
# 0        gb  5.365478  28.788352
# 1       nes  5.108012  26.091786
# 2       wii  3.126609   9.775681
# 3      snes  1.869469   3.494913
# 4      x360  1.615674   2.610403
# 5       ps4  1.609456   2.590350
# 6       gen  1.490041   2.220223
# 7       3ds  1.430876   2.047406
# 8        ds  1.426451   2.034764
# 9       ps3  1.391749   1.936966
# 10      n64  1.316733   1.733785
# 11      ps2  1.137927   1.294878
# 12     wiiu  1.058836   1.121133
# 13       ps  1.054502   1.111973
# 14     xone  1.036139   1.073584
# 15     2600  0.917799   0.842355
# 16      gba  0.896897   0.804423
# 17       gc  0.686346   0.471071
# 18       pc  0.675577   0.456404
# 19      scd  0.584055   0.341120
# 20       xb  0.534791   0.286002
# 21      psp  0.520210   0.270618
# 22       dc  0.468660   0.219642
# 23      sat  0.218092   0.047564
# 24      psv  0.212193   0.045026
# 25       ws  0.159457   0.025427
# 26     tg16  0.084853   0.007200
# ...

# %% [markdown]
# ### Choose the platforms with the greatest total sales and build a distribution based on data for each year.

# %%
# platform sales by year
platform_sales = df_games.groupby(['platform','year_of_release']).sum()["total_sales"]
platform_sales = platform_sales.to_frame().reset_index()
# 10 platforms with most sales
platforms = platform_sales.groupby("platform")["total_sales"].sum().sort_values(ascending=False).index[:10]
platform_sales = platform_sales.query("platform in @platforms")
# distribution of 10 platforms, years, sales (as size and color):
fig,axes = plt.subplots(nrows=1, ncols=1,figsize=(14,6));
sns.scatterplot(data = platform_sales, x='platform',y='year_of_release',size="total_sales",hue="total_sales",sizes=(40, 400));
axes.set_title(f'10 platforms sales by year',fontsize=14)
axes.set_xlabel(f"year of release",fontsize=12)
axes.set_ylabel(f"platform",fontsize=12);

# %% [markdown]
# ### Find platforms that used to be popular but now have zero sales.
# How long does it generally take for new platforms to appear and old ones to fade?

# %%
platforms_years = df_games.groupby(['platform']).agg({"year_of_release":["min","max"]})
platforms_years.columns = platforms_years.columns.droplevel(0)
platforms_years = platforms_years.reset_index()
platforms_years["duration"] = platforms_years['max']- platforms_years['min']
platforms_years["0 sales now"] = platforms_years.apply(lambda row: 2017>row['max'],axis=1)
platforms_years
# Out:
#    platform   min   max  duration  0 sales now
# 0      2600  1980  1989         9         True
# 1       3do  1994  1995         1         True
# 2       3ds  2011  2016         5         True
# 3        dc  1998  2008        10         True
# 4        ds  1985  2013        28         True
# 5        gb  1988  2001        13         True
# 6       gba  2000  2007         7         True
# 7        gc  2001  2007         6         True
# 8       gen  1990  1994         4         True
# 9        gg  1992  1992         0         True
# 10      n64  1996  2002         6         True
# 11      nes  1983  1994        11         True
# 12       ng  1993  1996         3         True
# 13       pc  1985  2017        32        False
# 14     pcfx  1996  1996         0         True
# 15       ps  1994  2012        18         True
# 16      ps2  1999  2012        13         True
# 17      ps3  2006  2017        11        False
# 18      ps4  2013  2017         4        False
# ...

# %% [markdown]
# if we want to see how much is the average duration for platform:

# %%
round(platforms_years["duration"].mean(),0)
# Out:
# 8.0

# %% [markdown]
# average duration for platform is 8 years.

# %% [markdown]
# how much time takes for new platforms to appear ? lets check the "ps" family:

# %%
platforms_years.loc[[15,16,17,18],"min"]
# Out:
# 15    1994
# 16    1999
# 17    2006
# 18    2013
# Name: min, dtype: int64

# %% [markdown]
# answer - every 5 to 7 years.

# %% [markdown]
# lets visualize all this:

# %%
platforms_years = df_games.groupby(["platform","year_of_release"]).count().reset_index(level=[0,1])[["platform","year_of_release"]]
platforms_years.columns=["platform","years"]
platforms_years
# Out:
#     platform  years
# 0       2600   1980
# 1       2600   1981
# 2       2600   1982
# 3       2600   1983
# 4       2600   1984
# ..       ...    ...
# 245     xone   2013
# 246     xone   2014
# 247     xone   2015
# 248     xone   2016
# 249     xone   2017
#
# [250 rows x 2 columns]

# %%
fig,axes = plt.subplots(nrows=1, ncols=1,figsize=(18,6));
sns.boxplot(data= platforms_years, x = "platform",y="years");
axes.tick_params(axis='x',labelrotation=90)
axes.set_title(f'platforms by year',fontsize=14)
axes.set_xlabel(f"platforms",fontsize=12)
axes.set_ylabel(f"years",fontsize=12);

# %% [markdown]
# we see that pc is different from the other platforms, because it's a popular computer, and not video game platform.

# %% [markdown]
# <div class="alert alert-block alert-success">
#     <h2>Reviewer's commentary <a class="tocSkip"> </h2>
#     <br/>
# <b>Well done!👍:</b>
#
# Ok, at this step of the analysis you built different plots and managed to get interesting insights from the data, good job!

# %% [markdown]
# <div class="alert alert-block alert-warning">
#    <h2>Reviewer's commentary<a class="tocSkip"> </h2>
#     <br/>
# <b>Remarks and recommendations📌:</b>
#
# But reminds you about plot formatting, it is better to improve the visualization at this step of the analysis.

# %% [markdown]
# <div class="alert alert-block alert-success">
#     <h2>Reviewer's commentary: second iteration of the review <a class="tocSkip"> </h2>
#     <br/>
# <b>Well done!👍</b>

# %% [markdown]
# ### Determine what period you should take data for.
# To do so, look at your answers to the previous questions. The data should allow you to build a prognosis for 2017.

# %% [markdown]
# because of our findings, i will took data for 4 years - from 2013 to 2016.

# %% [markdown]
# i will remove "ds" and "psp","ps2" platforms too, because we see that they are dupricated (even they still were in 2009!)

# %%
relevant = df_games.query("year_of_release>=2013 & year_of_release<2017").query("~(platform in ['ds','psp','ps2','ps'])")
relevant
# Out:
#                                 name platform  year_of_release         genre  \
# 16                grand theft auto v      ps3             2013        action
# 23                grand theft auto v     x360             2013        action
# 31         call of duty: black ops 3      ps4             2015       shooter
# 33               pokemon x/pokemon y      3ds             2013  role-playing
# 42                grand theft auto v      ps4             2014        action
# ...                              ...      ...              ...           ...
# 16703               strawberry nauts      psv             2016     adventure
# 16707               aiyoku no eustia      psv             2014          misc
# 16710  samurai warriors: sanada maru      ps3             2016        action
# 16712        haitaka no psychedelica      psv             2016     adventure
# 16714            winning post 8 2016      psv             2016    simulation
#
# ...

# %% [markdown]
# <div class="alert alert-block alert-danger">
#     <h2>Reviewer's commentary <a class="tocSkip"> </h2>
#     <br/>
# <b>Needs fixing!🤔:</b>
#
# Yosef,
#
# as I have understand your actions here correctly, the lower border of actual (current) period is 2009. But it is not a very correct lower border for the actual period!
#
# The relevance of the game falls according to the plots (if you build barplots for each platform sales per year you will see it) on average for 3-4 years (if you build barplots for each platform sales per year you will see it) since games quickly become obsolete, although they can continue to be sold in stores. Accordingly, if we choose a longer period, for example, as in your case, we risk capturing a lagging trend, i.e. we include in the data irrelevant pre-period platforms that should not remain in the data for the predicted period.
#
# <br/>
# For example, the case of PS2. We see that the leader in sales in the entire history of the PS2. But sales by 2011 are already equal to zero. Or X360: it was at its peak in 2010, but by 2016 it had dropped to almost 0. You can see this if you build the barplots of total_sales for each platform. That is why the choice of 2010 year as a start year can catch the outdated tendency and bias the results of your analysis at the next steps.
#
# <br/>
# It is worth adjusting the time period here to obtain more accurate results. So , please, try to correct the actual period! <br><br>
#
# It is better to use 2013 or 2014 year as the lower border of the currect period. The year that can be considered as boundary of the current period, can be determined by building histograms for each platform. The histograms will show that games lose relevance within 3-4, maximum 5 years, at the same time the lifespan of the platform is on average about 10 years. The final year of the dataset is 2016, so we subtract 3-4 years from 2017 (as the year for which we buid the prediction) and get a year, which can be considered the boundary of the current period.
#
# Please, remember, that the global aim of this project is the PREDICTION of the sales, popularity, profitability of the platforms, so we need to analyze not past but now and future. See instruction:
#
# `In front of you is data going back to 2016. Let’s imagine that it’s December 2016 and you’re planning a campaign for 2017.
# (The important thing is to get experience working with data. It doesn't really matter whether you're forecasting 2017 sales based on data from 2016 or 2027 sales based on data from 2026.)`
#
# And when you determine the actual perios, it is better not to include in the analysis the outdated platforms, such as "PS3", "X360", "Wii", "PSP".
#
# Some examples for you (in support of my argument about the time of game relevance)
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# <div class="alert alert-info"> you right! i have changed it.</div>

# %% [markdown]
# <div class="alert alert-block alert-success">
#     <h2>Reviewer's commentary: second iteration of the review <a class="tocSkip"> </h2>
#     <br/>
# <b>Well done!👍:</b>
#
# Ok, this time the lower border of the current period is more correct, good job!

# %% [markdown]
# ### Which platforms are leading in sales?
# Which ones are growing or shrinking? Select several potentially profitable platforms.

# %%
# platforms leading in sales:
relevant.groupby('platform')["total_sales"].sum().sort_values(ascending=False)[:5]
# Out:
# platform
# ps4     313.65
# ps3     182.79
# xone    159.25
# 3ds     144.62
# x360    137.04
# Name: total_sales, dtype: float64

# %%
# check what platforms are shrinking or growing:
fig,axes = plt.subplots(nrows=1, ncols=1,figsize=(16,6));
sns.scatterplot(data = relevant, x='platform',y='year_of_release',size="total_sales",hue="total_sales",sizes=(40, 1000));
axes.set_title(f'platforms sales by year',fontsize=14)
axes.set_xlabel(f"platforms",fontsize=12)
axes.set_ylabel(f"years",fontsize=12);

# %% [markdown]
# we see that wii,x360,ps3,wiiu are shrinking.
# ps4,3ds are growing,
# pc,xone,psv stay stable.

# %% [markdown]
# <div class="alert alert-block alert-success">
#     <h2>Reviewer's commentary <a class="tocSkip"> </h2>
#     <br/>
# <b>Well done!👍:</b>
#
# Ok, you are right about the PS4 and 3DS, these platforms can be considered as potentially profitable for 2017.

# %% [markdown]
# ### Build a box plot for the global sales of all games, broken down by platform.
# Are the differences in sales significant? What about average sales on various platforms? Describe your findings.

# %%
fig,axes = plt.subplots(nrows=1, ncols=1,figsize=(18,6));
sns.boxplot(data= relevant, x = "platform",y="total_sales");
axes.set_title(f'platforms global sales',fontsize=14)
axes.set_xlabel(f"platforms",fontsize=12)
axes.set_ylabel(f"sales",fontsize=12);

# %% [markdown]
# ### and without outliers:

# %%
fig,axes = plt.subplots(nrows=1, ncols=1,figsize=(18,6));
sns.boxplot(data= relevant, x = "platform",y="total_sales",showfliers = False);
axes.set_title(f'platforms global sales',fontsize=14)
axes.set_xlabel(f"platforms",fontsize=12)
axes.set_ylabel(f"sales",fontsize=12);

# %% [markdown]
# <div class="alert alert-block alert-warning">
#    <h2>Reviewer's commentary<a class="tocSkip"> </h2>
#     <br/>
# <b>Remarks and recommendations📌:</b>
#
# To get rid of outliers on the plots you can use `showfliers = False`

# %% [markdown]
# ### Are there differences in sales significant?
# you should define "significant".
# of course we see differences , in the median , IQR, etc.
# some differences are smaller than others, but it depends on your scale!
# we see differences in the outliers (and range) too.
# ### What about average sales on various platforms?
# where there are many outliers, it influence the average sales, in addition to the differences we said.

# %% [markdown]
# ### Take a look at how user and professional reviews affect sales for one popular platform (you choose).
# Build a scatter plot and calculate the correlation between reviews and sales.
# Draw conclusions.

# %%
# i will take PS4 and i will remove total sales outliers which are bigger than 5:
ps4 = relevant.query('platform=="ps4"').query("total_sales<5")
fig,axes = plt.subplots(nrows=1, ncols=2,figsize=(14,6));
sns.scatterplot(data = ps4, x='total_sales',y='user_score',hue="total_sales",ax=axes[0]);
sns.scatterplot(data = ps4, x='total_sales',y='critic_score',hue="total_sales",ax=axes[1]);

# %% [markdown]
# we see that in general as we grow up in user score or critic score, there are more sales.
# but we see too that there are many games with high user score without high sales !
# **so good reviews dont ensure good sales, but if there are bad reviews it's pretty sure there wouldn't be good sales.**

# %% [markdown]
# ### Keeping your conclusions in mind, compare the sales of the same games on other platforms.

# %%
other = relevant[relevant["name"].isin(ps4["name"])].query("platform!='ps4'")
other
# Out:
#                                                 name platform  \
# 60                              call of duty: ghosts     x360
# 69                              call of duty: ghosts      ps3
# 72                                         minecraft     x360
# 126                                          fifa 14      ps3
# 149                                   the last of us      ps3
# ...                                              ...      ...
# 16672  metal gear solid v: the definitive experience     xone
# 16691                   dynasty warriors: eiketsuden      ps3
# 16692              metal gear solid v: ground zeroes       pc
# 16710                  samurai warriors: sanada maru      ps3
# 16714                            winning post 8 2016      psv
#
#        year_of_release       genre  na_sales  eu_sales  jp_sales  other_sales  \
# 60                2013     shooter      6.73      2.56      0.04         0.91
# ...

# %%
for p in ["pc","xone","x360","ps3"]:
    x = relevant.query('platform==@p').query("total_sales<5")
    fig,axes = plt.subplots(nrows=1, ncols=2,figsize=(14,6));
    fig.suptitle(f"{p} platform, reviews vs sales:")
    sns.scatterplot(data = x, x='total_sales',y='user_score',hue="total_sales",ax=axes[0]);
    axes[0].set_xlabel(f"user score",fontsize=12)
    axes[0].set_ylabel(f"sales",fontsize=12);
    sns.scatterplot(data = x, x='total_sales',y='critic_score',hue="total_sales",ax=axes[1]);
    axes[1].set_xlabel(f"critic score",fontsize=12)
    axes[1].set_ylabel(f"sales",fontsize=12);

# %% [markdown]
# i think that the conclusion is very simillar:
# **good reviews dont ensure good sales, but if there are bad reviews it's pretty sure there wouldn't be good sales.**

# %%
fig, ax = plt.subplots(figsize=(14,8))
sns.heatmap(relevant.corr()[["total_sales"]],annot=True,ax=ax,cmap="YlGnBu");
ax.set_title(f'total sales correlation',fontsize=14);

# %% [markdown]
#     we see here a weak correlation between critic score and sales (0.24) , and even negative correlation
#     (-0.03) between user score and sales. like we said before, there isn't good correlaion,
#     there could be games with high score without sales, but like we saw in the scatter plots, usually
#     bad score games haven't sales too.

# %% [markdown]
# <div class="alert alert-block alert-success">
#     <h2>Reviewer's commentary <a class="tocSkip"> </h2>
#     <br/>
# <b>Well done!👍:</b>
#
# Ok, as a whole the logic of the analysis is correct.

# %% [markdown]
# <div class="alert alert-block alert-danger">
#     <h2>Reviewer's commentary <a class="tocSkip"> </h2>
#     <br/>
# <b>Needs fixing!🤔:</b>
#
# But some corrections need to be done:
#
# * first of all at this step of the analysis it is better to choose one of the potentially profitable and growing platforms (PS3 is outdated platform)
#
# * it is absolutely important to calculate correlation (using scatter plot is correct, but not enough)
#
# * it is better to format your plots more correctly

# %% [markdown]
# <div class="alert alert-block alert-success">
#     <h2>Reviewer's commentary: second iteration of the review <a class="tocSkip"> </h2>
#     <br/>
# <b>Well done!👍:</b>
#
# Ok, agree with your improvements here, keep it up!

# %% [markdown]
# ### Take a look at the general distribution of games by genre.
# What can we say about the most profitable genres? Can you generalize about genres with high and low sales?

# %%
x = relevant.groupby("genre").agg({"total_sales":["mean","sum","count"]})
x.columns = x.columns.droplevel(0)
x.columns =["total sales mean","total sales sum","games count"]
x= x.reset_index()
x
# Out:
#            genre  total sales mean  total sales sum  games count
# 0         action          0.425695           321.40          755
# 1      adventure          0.108443            22.99          212
# 2       fighting          0.446709            35.29           79
# 3           misc          0.443857            62.14          140
# 4       platform          0.582500            41.94           72
# 5         puzzle          0.186471             3.17           17
# 6         racing          0.464884            39.98           86
# 7   role-playing          0.504340           145.25          288
# 8        shooter          1.239628           233.05          188
# 9     simulation          0.369194            22.89           62
# 10        sports          0.726857           152.64          210
# 11      strategy          0.182909            10.06           55

# %%
genre_sales = x.loc[:,["genre","total sales sum"]]
genre_sales = genre_sales.sort_values("total sales sum",ascending=False)
genre_sales
# Out:
#            genre  total sales sum
# 0         action           321.40
# 8        shooter           233.05
# 10        sports           152.64
# 7   role-playing           145.25
# 3           misc            62.14
# 4       platform            41.94
# 6         racing            39.98
# 2       fighting            35.29
# 1      adventure            22.99
# 9     simulation            22.89
# 11      strategy            10.06
# 5         puzzle             3.17

# %%
fig,axes = plt.subplots(nrows=1, ncols=1,figsize=(14,6));
sns.barplot(data=genre_sales,x="genre",y="total sales sum",color='blue');
axes.tick_params(axis='x',labelrotation=90)
axes.set_title(f'sales by genre',fontsize=14)
axes.set_xlabel(f"genre",fontsize=12)
axes.set_ylabel(f"total sales (m)",fontsize=12);

# %% [markdown]
# sorry, but i don't see any generalize feature of the most/low profitable genre.

# %% [markdown]
# <div class="alert alert-block alert-danger">
#     <h2>Reviewer's commentary <a class="tocSkip"> </h2>
#     <br/>
# <b>Needs fixing!🤔:</b>
#
# Here you need to calculate not only mean but total sales per genre (calculating sales per platform is more important, mean or median can be treated as additional statistics). Also here it is important to provide visualization, like this for example:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# <div class="alert alert-block alert-success">
#     <h2>Reviewer's commentary: second iteration of the review <a class="tocSkip"> </h2>
#     <br/>
# <b>Well done!👍:</b>
#
# Ok, now everything is alright!

# %% [markdown]
# ## Step 4. Create a user profile for each region

# %% [markdown]
# For each region (NA, EU, JP), determine:
#
#     The top five platforms. Describe variations in their market shares from region to region.
#     The top five genres. Explain the difference.
#     Do ESRB ratings affect sales in individual regions?

# %%
from IPython.display import Markdown, display

for s in ["na_sales","eu_sales","jp_sales"]:
    display(Markdown(f"**top 5 platforms in {s}, values in percentage:**"))
    x = relevant.groupby("platform")[s].sum()
    print(round(x.sort_values(ascending=False)[:5]/sum(x.values)*100),1)
# Out:
# **top 5 platforms in na_sales, values in percentage:**
# platform
# ps4     25.0
# xone    21.0
# x360    19.0
# ps3     15.0
# 3ds      9.0
# Name: na_sales, dtype: float64 1
# **top 5 platforms in eu_sales, values in percentage:**
# platform
# ps4     36.0
# ps3     17.0
# xone    13.0
# x360    11.0
# 3ds      8.0
# Name: eu_sales, dtype: float64 1
# **top 5 platforms in jp_sales, values in percentage:**
# platform
# 3ds     49.0
# ps3     17.0
# psv     14.0
# ps4     11.0
# wiiu     8.0
# Name: jp_sales, dtype: float64 1

# %% [markdown]
#
#     i think that in japan the 3ds is rolling because it developed by nintendo - japanese compny.
#     on other reagons ps4 lead the market!

# %% [markdown]
# <div class="alert alert-block alert-danger">
#     <h2>Reviewer's commentary <a class="tocSkip"> </h2>
#     <br/>
# <b>Needs fixing!🤔:</b>
#
# Despite your common logic is correct it is better to adjust the lower border of the current period and recheck your results, now the leaders in platforms in all regions are the platforms that are outdated, it is not very correct.

# %% [markdown]
# <div class="alert alert-block alert-success">
#     <h2>Reviewer's commentary: second iteration of the review <a class="tocSkip"> </h2>
#     <br/>
# <b>Well done!👍:</b>
#
# Ok, this time your results are absolutely correct.

# %%
# The top five genres. Explain the difference.

for s in ["na_sales","eu_sales","jp_sales"]:
    display(Markdown(f"**top 5 genres in {s}, values in percentage:**"))
    x = relevant.groupby("genre")[s].sum()
    print(round(x.sort_values(ascending=False)[:5]/sum(x.values)*100),1)
# Out:
# **top 5 genres in na_sales, values in percentage:**
# genre
# action          29.0
# shooter         25.0
# sports          15.0
# role-playing    11.0
# misc             6.0
# Name: na_sales, dtype: float64 1
# **top 5 genres in eu_sales, values in percentage:**
# genre
# action          30.0
# shooter         22.0
# sports          16.0
# role-playing     9.0
# racing           5.0
# Name: eu_sales, dtype: float64 1
# **top 5 genres in jp_sales, values in percentage:**
# genre
# role-playing    36.0
# action          29.0
# misc             7.0
# fighting         6.0
# shooter          5.0
# Name: jp_sales, dtype: float64 1

# %% [markdown]
# **i suppose that there are differences in mentality of people in different regions in the world, and creates these differences in the favorite genres in every region.**

# %% [markdown]
# <div class="alert alert-block alert-success">
#     <h2>Reviewer's commentary <a class="tocSkip"> </h2>
#     <br/>
# <b>Well done!👍:</b>
#
# Ok, I can agree with your conclusion.

# %%
# Do ESRB ratings affect sales in individual regions?
# we will use the column "rating numerical" we created before. 
# the values [0,1,2,3,4] corresponds to ["e","e10+","t","m","ao"]

for s in ["na_sales","eu_sales","jp_sales"]:
    display(Markdown(f"**ESRB vs region in {s} in percentage:**"))
    x = relevant.groupby("rating_numerical")[s].sum()
    print(round(x.sort_values(ascending=False)/sum(x.values)*100),1)
# Out:
# **ESRB vs region in na_sales in percentage:**
# rating_numerical
# 3.0    38.0
# 1.0    33.0
# 0.0    18.0
# 2.0    11.0
# Name: na_sales, dtype: float64 1
# **ESRB vs region in eu_sales in percentage:**
# rating_numerical
# 3.0    37.0
# 1.0    31.0
# 0.0    21.0
# 2.0    11.0
# Name: eu_sales, dtype: float64 1
# **ESRB vs region in jp_sales in percentage:**
# rating_numerical
# 1.0    64.0
# 2.0    15.0
# 0.0    11.0
# 3.0    10.0
# Name: jp_sales, dtype: float64 1

# %% [markdown]
# ### we see that ESRB ratings affect sales in individual regions.
#     in japan (maybe more conservative society) the most games are rating 1 (e10+),
#     in europe and na the most games are rating 3 ("m") with more violence etc.
#     and maybe na more conservative than eu, because the next value in na is 0 ("e"), and in eu is 1 ("e10+").

# %% [markdown]
# <div class="alert alert-block alert-warning">
#    <h2>Reviewer's commentary<a class="tocSkip"> </h2>
#     <br/>
# <b>Remarks and recommendations📌:</b>
#
# It is important to analyse games without rating and there is no need to replace rating categories with numbers, categories' names look much more informative.

# %% [markdown]
# ## Step 5. Test the following hypotheses:

# %% [markdown]
# ### test: Average user ratings of the Xbox One and PC platforms are the same.

# %% [markdown]
# <div class="alert alert-block alert-danger">
#     <h2>Reviewer's commentary <a class="tocSkip"> </h2>
#     <br/>
# <b>Needs fixing!🤔:</b>
#
# Why is it so? It is important to use the slice with relevant data at the step of the statistical hypotheses testing, any other strategy is not very correct. If you did everything correctly, the XOne shoud be in the slice with current period.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# <div class="alert alert-info" >
# <h2> Student's comment</h2>
# <div>i was confused with xo and xone, i thought that xo is xone, beside i corrected the period of time.</div>
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
#     <h2>Reviewer's commentary: second iteration of the review <a class="tocSkip"> </h2>
#     <br/>
# <b>Well done!👍:</b>
#
# Ok, understand, I how now it is more clear for your😉

# %% [markdown]
# ### Null :
# $\Large\mu$$_{xbox-user-rating}$ - $\Large\mu$$_{pc-user-rating}$ =0
#
#
# ### Alternative:
# **$\Large\mu$$_{xbox-user-rating}$** - **$\Large\mu$$_{pc-user-rating}$** != 0
#
# $\Large\alpha$ = $\Large5\%$

# %% [markdown]
# ### the null hypothesis suggests that there isn't a difference between the platforms average user rating, the alternative suggests there is a difference.
# ### we choose alpha 5% because it's a standard.

# %%
from scipy import stats as st
import numpy as np

alpha = 0.05  # critical statistical significance level
# if the p-value is less than alpha, we reject the hypothesis
arr1= relevant.query("platform=='xone'")["user_score"]
arr2= relevant.query("platform=='pc'")["user_score"]

results = st.ttest_ind(arr1, arr2,equal_var=False)

print('p-value: ', results.pvalue)

if results.pvalue < alpha:
    print("We reject the null hypothesis")
else:
    print("We can't reject the null hypothesis")
# Out:
# p-value:  0.11196715883171036
# We can't reject the null hypothesis

# %% [markdown]
#     we see that p value is bigger than alpha, so we can't reject the null hypothesis, we couldn't prove
#     that there is a difference between the platforms.

# %%
# Which higher ?
df_games.groupby("platform")["user_score"].mean()[["pc","xone"]]
# Out:
# platform
# pc      7.067967
# xone    6.587045
# Name: user_score, dtype: float64

# %% [markdown]
#     pc has higher user rating.

# %% [markdown]
# ### test: —Average user ratings for the Action and Sports genres are different.

# %% [markdown]
# ### Null :
# $\Large\mu$$_{action-user-rating}$ - $\Large\mu$$_{sports-user-rating}$ =0
#
#
# ### Alternative:
# **$\Large\mu$$_{action-user-rating}$** - **$\Large\mu$$_{sports-user-rating}$** != 0
#
# $\Large\alpha$ = $\Large5\%$

# %% [markdown]
# ### the null hypothesis suggests that there isn't a difference between the genres average rating, the alternative suggests there is a difference.
# ### we choose alpha 5% because it's a standard.

# %%
from scipy import stats as st
import numpy as np

alpha = 0.05  # critical statistical significance level
# if the p-value is less than alpha, we reject the hypothesis
arr1= relevant.query("genre=='action'")["user_score"]
arr2= relevant.query("genre=='sports'")["user_score"]

results = st.ttest_ind(arr1, arr2,equal_var=False)

print('p-value: ', results.pvalue)

if results.pvalue < alpha:
    print("We reject the null hypothesis")
else:
    print("We can't reject the null hypothesis")
# Out:
# p-value:  1.8811923548951913e-30
# We reject the null hypothesis

# %% [markdown]
#       we see that p value is small more than alpha, so we reject the null hypothesis, and we believe that there is a differnce between the user ratings of the games in the two genres.

# %%
# Which higher ?
df_games.groupby("genre")["user_score"].mean()[["action","sports"]]
# Out:
# genre
# action    7.016622
# sports    7.101704
# Name: user_score, dtype: float64

# %% [markdown]
#     sports has higher user rating.

# %% [markdown]
# <div class="alert alert-block alert-success">
#     <h2>Reviewer's commentary <a class="tocSkip"> </h2>
#     <br/>
# <b>Well done!👍:</b>
#
# Ok, Yosef, as a whole the logic of your decision is correct (apart from the using of the current period slice): you correctly chose the method for statistican hypotheses testing, you also correctly formulated the H0 and H1.

# %% [markdown]
# <div class="alert alert-block alert-warning">
#    <h2>Reviewer's commentary <a class="tocSkip"> </h2>
#     <br/>
# <b>Remarks and recommendations📌:</b>
#
# Yosef, if you will decide not to filling in missing values in column `user_score` it is important to drop NaN from the samples before testing the hypotheses with the Student's t-test. You can do it in a more statistical manner.
#
# `st.ttest_ind` has special argument `nan_policy` that can specified as `omit`, so it helps to drop NaN values too.
#
#
# https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.ttest_ind.html

# %% [markdown]
# <div class="alert alert-info" >
# <h2> Student's comment</h2>
# <div>o.k. i changed it to the "relevant" dataframe, there aren't missing values</div>
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
#     <h2>Reviewer's commentary: second iteration of the review <a class="tocSkip"> </h2>
#     <br/>
# <b>Well done!👍:</b>
#
# This time your decision is correct, you are doing great!

# %% [markdown]
# ## Step 6. Write a general conclusion

# %% [markdown]
# * __we got a DB with data about video games sales and ratings of them.__
# * __there were many missing values, in some columns more than 50%, we made our best to fill them based on features we know.__
# * __than we checked platforms. the db has data from the 80's to 2017 , some of the data isn't relevant, some of the platforms are decrepted, so we filtered the data and used the relevant data only in our research.__
# * __from the platforms used right now, some are shrink, some are grows, some are stable.__
# * __we saw that wii,x360,ps3 are shrinking , ps4,3ds are growing, pc,xone,wiiu,psv stay stable.__
# * __is there is a connection between user/critic score to sales ? the answer is that good reviews dont ensure good sales, but if there are bad reviews scores it's pretty sure there wouldn't be good sales!__
# * __than we checked are there differences between regions ? are there speciphic features which influencing the sales in every region ? we found that every region has unique features: in the platforms, genres, and even ESRB rating.__
# **(you could see the speciphic differences above)**
# * __by the end we checked two hypothesis -__
#     1. __Average user ratings of the Xbox One and PC platforms are the same.__
#     2. __Average user ratings for the Action and Sports genres are different.__
# __on both cases we rejected the null hypothesis, means that there is a difference between the average user rating.__
# ### recommendations:
# * __i recommend to invest in these genres: action, shooter, sports in NA and EU, while in japan to invest in role-playing, action and misc.__
# * __i recommend to invest in NA and EU with more ESRB "m" ratings, while in japan "e10+" and "t" rating.__
# * __i recommend to invest in ps4 platform on NA and EU, while in japan 3ds.__
# * __don't take too seriously "user score" or "critic score", there isn't a good correlation between it and high sales(but if there is a negative score, it should alarm you).__

# %% [markdown]
# <div class="alert alert-block alert-danger">
#     <h2>Reviewer's commentary <a class="tocSkip"> </h2>
#     <br/>
# <b>Needs fixing!🤔:</b>
#
#
# In the final conclusion it is important apart from summarizing your actions, provide some recommendations for the client! It is important to remember about the main aim of the analysis!
#
# `You need to identify patterns that determine whether a game succeeds or not. This will allow you to spot potential big winners and plan advertising campaigns.`

# %% [markdown]
# <div class="alert alert-block alert-success">
#     <h2>Reviewer's commentary: second iteration of the review <a class="tocSkip"> </h2>
#     <br/>
# <b>Well done!👍:</b>
#
# Yes, agree with your recommendations for client.

# %% [markdown]
# <div style="border:solid Chocolate 2px; padding: 40px">
#
# **The overall review conclusion**
#
# Yosef, thank you for submitting your project! I can see that you've worked really hard on it! I'm really impressed this the amount of work you have done. But there are several things in your project which I suppose it is important to fix in order to make your project really ideal! My comments will navigate you!
#
#
# **Good things and practices in your project I want to highlight🙂**:
#
# * You use different methods for working with your data. It is really great that you can apply these methods on practice, keep it up!
# * You worked with the visualization, it is really good that you use plots in your work and formatted them correctly!
# * You have formulated conclusions after the each step of the analysis, good job!
# * You correctly used test for statistical hypotheses testing.
#
# **What is worth working on👀**:
#
# * It is better to pay more attention to the formatting of the plots.
# * It is better to add the correlation analysis for total_sales/user and critic score for one popular platform from actual period.
# * It is important to correct the current period
# * Fix the final conclusion.
#
#
# **Good luck! I will wait for your work for a second iteration of the review!😉**
# ![gif](https://media.giphy.com/media/W23aKzDl1OFRAcki9z/giphy.gif)

# %% [markdown]
# <div style="border:solid Chocolate 2px; padding: 40px">
#
# **The overall review conclusion: second iteration of the review**
#
# Yosef, thank you for submitting your project with corrections! I can see your progress and all your corrections, I am totally agree with them! You managed to significantly improve your project!
#
# I hasten to say that your project has been accepted and you can proceed to the next sprint!
#
# **I wish you exciting and cool projects in the next sprints😉**
#
# ![gif](https://media.giphy.com/media/26uf44C6g1mcYoSaY/giphy.gif)
